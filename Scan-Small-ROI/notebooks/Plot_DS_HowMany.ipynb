# %%
import sys
sys.path.append("../")

import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from tqdm import *
from plot_skylocs import LimitPlot

# %matplotlib inline
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
plots_dir = "/tigress/nrodd/DM-Catalog-Scan/Scan-Small-ROI/plots_darksky/"

# %% [markdown]
# # Initialize

# %%
plot_mc_sl0 = LimitPlot(data_dir='/tigress/nrodd/DM-Catalog-Scan/Scan-Small-ROI/data/DarkSky_sid_loc0/',
                        elephant=True, 
                        nmc=50, 
                        halos_ran=1000, 
                        halos_to_keep=1000,
                        data_type="mc",
                        bcut=0,
                        nonoverlap=False,
                        nonoverlapradius=2.,
                        cut_0p5=False,
                        xsecslim=10,
                        TS100=9,
                        TS1000=9)

# %%
plot_mc_sl0 = LimitPlot(data_dir='/tigress/nrodd/DM-Catalog-Scan/Scan-Small-ROI/data/DarkSky_sid_loc0_inj10000_dm' + str(9)+'/',
                        elephant=True, 
                        nmc=1, 
                        halos_ran=300, 
                        halos_to_keep=300,
                        data_type="mc",
                        bcut=0,
                        nonoverlap=False,
                        nonoverlapradius=2.,
                        cut_0p5=False,
                        xsecslim=10,
                        TS100=9,
                        TS1000=9,
                        file_prefix='LL2_TSmx_lim_b_noJprof_emin4_emax30_o',)

# %%
mc_ary = plot_mc_sl0.return_limits()

# %%
np.median(plot_mc_sl0.halos_that_passed)
# Out:
# 966.0

# %%
np.percentile((plot_mc_sl0.halos_that_passed),[16,50,84])
# Out:
# array([ 961.,  966.,  974.])

# %% [markdown]
# # Plot

# %%
# Loc 0
mc_ary = plot_mc_sl0.return_limits()

for midx in [0,11,52]:
    plt.plot(np.arange(len(mc_ary[0][:,midx,:])) + 1,np.percentile(mc_ary[0][:,midx,:],[50],axis=1)[0], color='cornflowerblue', ls='--')

    plt.fill_between(np.arange(len(mc_ary[0][:,midx,:])) + 1,np.percentile(mc_ary[0][:,midx,:],[16],axis=1)[0],np.percentile(mc_ary[0][:,midx,:],[84],axis=1)[0], alpha=0.1, color='cornflowerblue')
    plt.fill_between(np.arange(len(mc_ary[0][:,midx,:])) + 1,np.percentile(mc_ary[0][:,midx,:],[2.5],axis=1)[0],np.percentile(mc_ary[0][:,midx,:],[97.5],axis=1)[0], alpha=0.2, color='cornflowerblue')

    plt.title("$M_\chi$ = " + str(int(plot_mc_sl0.marr[midx])) + " GeV")
    
    plt.xlabel("$N_h$")
    plt.ylabel("$\langle \sigma v \\rangle$ [cm$^3$s$^{-1}$]")
    
    plt.xscale("log")
    plt.show()

np.save("mc_ary_loc0.npy",mc_ary)

# %%
# Loc 1
mc_ary = plot_mc_sl1.return_limits()

for midx in [0,11,52]:
    plt.plot(np.arange(len(mc_ary[0][:,midx,:])) + 1,np.percentile(mc_ary[0][:,midx,:],[50],axis=1)[0], color='cornflowerblue', ls='--')

    plt.fill_between(np.arange(len(mc_ary[0][:,midx,:])) + 1,np.percentile(mc_ary[0][:,midx,:],[16],axis=1)[0],np.percentile(mc_ary[0][:,midx,:],[84],axis=1)[0], alpha=0.1, color='cornflowerblue')
    plt.fill_between(np.arange(len(mc_ary[0][:,midx,:])) + 1,np.percentile(mc_ary[0][:,midx,:],[2.5],axis=1)[0],np.percentile(mc_ary[0][:,midx,:],[97.5],axis=1)[0], alpha=0.2, color='cornflowerblue')

    plt.title("$M_\chi$ = " + str(int(plot_mc_sl1.marr[midx])) + " GeV")
    
    plt.xlabel("$N_h$")
    plt.ylabel("$\langle \sigma v \\rangle$ [cm$^3$s$^{-1}$]")
    
    plt.xscale("log")
    plt.show()

np.save("mc_ary_loc1.npy",mc_ary)

# %%
# Loc 2
mc_ary = plot_mc_sl2.return_limits()

for midx in [0,11,52]:
    plt.plot(np.arange(len(mc_ary[0][:,midx,:])) + 1,np.percentile(mc_ary[0][:,midx,:],[50],axis=1)[0], color='cornflowerblue', ls='--')

    plt.fill_between(np.arange(len(mc_ary[0][:,midx,:])) + 1,np.percentile(mc_ary[0][:,midx,:],[16],axis=1)[0],np.percentile(mc_ary[0][:,midx,:],[84],axis=1)[0], alpha=0.1, color='cornflowerblue')
    plt.fill_between(np.arange(len(mc_ary[0][:,midx,:])) + 1,np.percentile(mc_ary[0][:,midx,:],[2.5],axis=1)[0],np.percentile(mc_ary[0][:,midx,:],[97.5],axis=1)[0], alpha=0.2, color='cornflowerblue')

    plt.title("$M_\chi$ = " + str(int(plot_mc_sl2.marr[midx])) + " GeV")
    
    plt.xlabel("$N_h$")
    plt.ylabel("$\langle \sigma v \\rangle$ [cm$^3$s$^{-1}$]")
    
    plt.xscale("log")
    plt.show()
    
np.save("mc_ary_loc2.npy",mc_ary)

# %%
# Loc 3
mc_ary = plot_mc_sl3.return_limits()

for midx in [0,11,52]:
    plt.plot(np.arange(len(mc_ary[0][:,midx,:])) + 1,np.percentile(mc_ary[0][:,midx,:],[50],axis=1)[0], color='cornflowerblue', ls='--')

    plt.fill_between(np.arange(len(mc_ary[0][:,midx,:])) + 1,np.percentile(mc_ary[0][:,midx,:],[16],axis=1)[0],np.percentile(mc_ary[0][:,midx,:],[84],axis=1)[0], alpha=0.1, color='cornflowerblue')
    plt.fill_between(np.arange(len(mc_ary[0][:,midx,:])) + 1,np.percentile(mc_ary[0][:,midx,:],[2.5],axis=1)[0],np.percentile(mc_ary[0][:,midx,:],[97.5],axis=1)[0], alpha=0.2, color='cornflowerblue')

    plt.title("$M_\chi$ = " + str(int(plot_mc_sl3.marr[midx])) + " GeV")
    
    plt.xlabel("$N_h$")
    plt.ylabel("$\langle \sigma v \\rangle$ [cm$^3$s$^{-1}$]")
    
    plt.xscale("log")
    plt.show()

np.save("mc_ary_loc3.npy",mc_ary)

# %%
marr = np.array([1.00000000e+01,1.50000000e+01,2.00000000e+01,2.50000000e+01,3.00000000e+01,4.00000000e+01,5.00000000e+01,6.00000000e+01,7.00000000e+01,8.00000000e+01,9.00000000e+01,1.00000000e+02,1.10000000e+02,1.20000000e+02,1.30000000e+02,1.40000000e+02,1.50000000e+02,1.60000000e+02,1.80000000e+02,2.00000000e+02,2.20000000e+02,2.40000000e+02,2.60000000e+02,2.80000000e+02,3.00000000e+02,3.30000000e+02,3.60000000e+02,4.00000000e+02,4.50000000e+02,5.00000000e+02,5.50000000e+02,6.00000000e+02,6.50000000e+02,7.00000000e+02,7.50000000e+02,8.00000000e+02,9.00000000e+02,1.00000000e+03,1.10000000e+03,1.20000000e+03,1.30000000e+03,1.50000000e+03,1.70000000e+03,2.00000000e+03,2.50000000e+03,3.00000000e+03,4.00000000e+03,5.00000000e+03,6.00000000e+03,7.00000000e+03,8.00000000e+03,9.00000000e+03,1.00000000e+04])

# %%
save_dir = '/tigress/bsafdi/github/NPTF-working/NPTF-ID-Catalog/runs_sid/notebooks/DataArrays/'

oFig1 = plt.figure(1,figsize=(15,10))

for iloc in range(4):
    mc_ary = np.load("mc_ary_loc"+str(iloc)+".npy")
    for imass, midx in enumerate([0,11,52]):
        oFig1.add_subplot(4,3,3*iloc+imass+1)
        
        plt.plot(np.arange(len(mc_ary[0][:,midx,:])) + 1,10**np.percentile(mc_ary[0][:,midx,:],[50],axis=1)[0], color='tomato', ls='--')

        plt.fill_between(np.arange(len(mc_ary[0][:,midx,:])) + 1,10**np.percentile(mc_ary[0][:,midx,:],[16],axis=1)[0],10**np.percentile(mc_ary[0][:,midx,:],[84],axis=1)[0], alpha=0.1, color='tomato')
        plt.fill_between(np.arange(len(mc_ary[0][:,midx,:])) + 1,10**np.percentile(mc_ary[0][:,midx,:],[2.5],axis=1)[0],10**np.percentile(mc_ary[0][:,midx,:],[97.5],axis=1)[0], alpha=0.2, color='tomato')

        if iloc == 0:
            if imass == 2: 
                plt.title("\\textbf{\emph{m}}$\mathbf{_\chi}$ \\textbf{= 10 TeV}",fontsize=25, y=1.08)
            else:
                plt.title("\\textbf{\emph{m}}$\mathbf{_\chi}$ \\textbf{= " + str(int(marr[midx])) + " GeV}",fontsize=25, y=1.11) 
        if iloc == 3:
            plt.xlabel("$N_h$")
            
        if imass == 0:
            plt.ylabel(r"\textbf{Location "+str(iloc +1) + "}\n\cdot\n$\langle \sigma v \\rangle$ [cm$^3$\,s$^{-1}$]",fontsize=25)

        plt.xscale("log")
        plt.yscale("log")

        plt.xticks(fontsize=23);
        plt.yticks(fontsize=23);
        
        plt.xlim(1, 400)
        
        if imass == 0:
            plt.ylim(1e-26,1e-24)
        elif imass ==1:
            plt.ylim(1e-25,1e-23)
        elif imass ==2:
            plt.ylim(1e-22,1e-20)
            

        plt.tight_layout()

plt.savefig(plots_dir + "darksky_elephants.pdf")
