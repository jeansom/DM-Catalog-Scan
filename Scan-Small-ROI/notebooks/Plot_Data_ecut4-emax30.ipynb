# %%
import sys
import shutil
sys.path.append("../")

import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from tqdm import *
from plot_skylocs import LimitPlot
from astropy.cosmology import Planck15
import corner

# %matplotlib inline
# %load_ext autoreload
# %autoreload 2

catalog = pd.read_csv("/tigress/nrodd/DM-Catalog-Scan/DataFiles/Catalogs/2MRSLocalTully_ALL_DATAPAPER_Planck15_v7.csv")
# Out:
# /tigress/smsharma/anaconda2/lib/python2.7/site-packages/IPython/core/interactiveshell.py:2717: DtypeWarning: Columns (21,22,23) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %% [markdown]
# # Move Skylocs

# %%
# This has been run!

nobj = 1000
for imc in tqdm_notebook(range(200)):
    for iobj in tqdm_notebook(range(nobj)):
        shutil.move("/tigress/nrodd/DM-Catalog-Scan/Scan-Small-ROI/data/Tully_skylocs_no0p5mask"+str(imc)+"/LL2_TSmx_lim_b_emin4_emax30_o"+str(iobj)+"_data.npz",\
                    "/tigress/nrodd/DM-Catalog-Scan/Scan-Small-ROI/data/Tully_skylocs_no0p5mask_emin4_emax30/LL2_TSmx_lim_b_emin4_emax30_o"+str(iobj)+"_data_skyloc"+str(imc)+".npz")

# %%
# # This has been run!

# nobj = 1000
# for imc in tqdm_notebook(range(200)):
#     for iobj in tqdm_notebook(range(nobj)):
#         shutil.move("/tigress/nrodd/DM-Catalog-Scan/Scan-Small-ROI/data/Tully_skylocs_no0p5mask/LL2_TSmx_lim_b_emin4_emax30_o"+str(iobj)+"_data_skyloc"+str(imc)+".npz",\
#                     "/tigress/nrodd/DM-Catalog-Scan/Scan-Small-ROI/data/Tully_skylocs_no0p5mask_emin4/LL2_TSmx_lim_b_emin4_emax30_o"+str(iobj)+"_data_skyloc"+str(imc)+".npz")

# %%
# This has not been run!

catalog = pd.read_csv("/tigress/nrodd/DM-Catalog-Scan/DataFiles/Catalogs/2MRSLocalTully_ALL_DATAPAPER_Planck15_v7.csv")

nmc = 200
nobj = 1000
for imc in tqdm_notebook(range(nmc)):
    lb_temp = []
    for iobj in tqdm_notebook(range(nobj)):
        rep_angext = np.array([0.02785567,0.12069876,0.21354185,0.30638494,0.39922802,0.49207111,0.5849142,0.67775728,0.77060037,0.86344346,0.95628654,1.04912963,1.14197272,1.2348158,1.32765889,1.42050198,1.51334507,1.60618815,1.69903124,1.79187433])
        obj_angext = 2*catalog[u'rs'].values[iobj] / \
                     (Planck15.angular_diameter_distance(catalog[u'z'].values[iobj]).value*1000) \
                     * 180./np.pi
        rep_index = (np.abs(rep_angext-obj_angext)).argmin()

        lb_temp.append(np.loadtxt("../data/Tully_randlocs"+str(int(np.loadtxt("../data/Tully_skylocs_no0p5mask"+str(imc)+"/skyloc_obj"+str(iobj)+".txt")))+"/lb_obj"+str(rep_index)+".dat"))
    np.save("../data/Tully_skylocs_no0p5mask_emin4_emax30/lb_cat_mc"+str(imc)+".npy", lb_temp)

# %%
nobj = 1000

for iobj in tqdm_notebook(range(nobj)):
    shutil.move("/tigress/nrodd/DM-Catalog-Scan/Scan-Small-ROI/data/Tully_lowermasses_tau/LL2_TSmx_lim_\[Tau]_emin4_emax30_o"+str(iobj)+"_data.npz",\
                "/tigress/nrodd/DM-Catalog-Scan/Scan-Small-ROI/data/Tully_lowermasses_tau/LL2_TSmx_lim_tau_emin4_emax30_o"+str(iobj)+"_data.npz")

# %%
for iobj in tqdm_notebook(range(nobj)):
    shutil.move("/tigress/nrodd/DM-Catalog-Scan/Scan-Small-ROI/data/Tully_lowermasses_mu/LL2_TSmx_lim_\[Mu]_emin4_emax30_o"+str(iobj)+"_data.npz",\
                "/tigress/nrodd/DM-Catalog-Scan/Scan-Small-ROI/data/Tully_lowermasses_mu/LL2_TSmx_lim_mu_emin4_emax30_o"+str(iobj)+"_data.npz")

# %% [markdown]
# # Figure 1

# %%
work_dir = '/tigress/bsafdi/github/NPTF-working/NPTF-ID-Catalog/runs_sid/notebooks/LimitPlot//'
plots_dir = '/tigress/nrodd/DM-Catalog-Scan/Scan-Small-ROI/plots/'
data_dir = work_dir + 'data/'

data_file_names =[ data_dir + f for f in ['stath_max-lim.dat','stath_min-lim.dat','statp_q16-lim.dat','statp_q84-lim.dat',
                  'Jcm_q16-lim.dat','Jcm_q84-lim.dat','GCE.dat','FermiDwarf.dat','nominal-data.dat','gce-abazajian.dat',
                                         'gce-calore.dat','gce-gordon.dat','thermal-relic.dat'  ] ]

data_files = [np.loadtxt(f) for f in data_file_names]

####Poisson error bands
massP = 10**data_files[2][::,0]
Lim16 = 10**data_files[2][::,1]
Lim84 = 10**data_files[3][::,1]
LimP_disp = (np.log10(Lim84) - np.log10(Lim16))/2.0

####Halo Stat error bands
massH = 10**data_files[4][::,0]
LimH16 = 10**data_files[4][::,1]
LimH84 = 10**data_files[5][::,1]
LimH_disp = (np.log10(LimH84) - np.log10(LimH16))/2.0


#####Combine the uncertainties
Lim_uncert = np.sqrt(LimP_disp**2 + LimH_disp**2)

###GCE
GCE = data_files[6]
GCE_ab = data_files[9]
GCE_calore = data_files[10]
GCE_gordan = data_files[11]

###Fermi Dwarf
massD = 10**data_files[8][::,0]
LimD = 10**data_files[8][::,1]

#####thermal
thermal = 10**data_files[12]

###Cross Corr
mDM_ary = [10,20,50,100,200,300,400,500,700,1000,10000]
lim_ary = np.array(np.array([[  3.47613312e-25,   3.19993932e-25,   4.09432255e-25,
          5.74111275e-25,   8.19273323e-25,   1.11412925e-24,
          1.54077804e-24,   1.88342427e-24,   2.45742289e-24,
          3.51413849e-24,   1.88285952e-23],
       [  6.84653178e-25,   6.11339438e-25,   8.88586835e-25,
          1.46856813e-24,   2.37706561e-24,   3.06228027e-24,
          3.78778553e-24,   4.28537842e-24,   5.06539081e-24,
          6.20444331e-24,   3.37611100e-23]]))

# %%
ab_mean = GCE_ab[0]
ab_up = GCE_ab[-1,1]
ab_low = GCE_ab[1,1]
ab_L = GCE_ab[3,0]
ab_R = GCE_ab[2,0]

# %%
plot_data_skylocs = LimitPlot(data_dir='/tigress/nrodd/DM-Catalog-Scan/Scan-Small-ROI/data/Tully_skylocs_no0p5mask_emin4_emax30/',
                        elephant=False, 
                        nmc=200,
                        bcut=20,
                        nonoverlap=True,
                        nonoverlapradius=2.,
                        xsecslim=10,
                        TS100=9,
                        TS1000=9,
                        halos_ran=1000, 
                        halos_to_keep=1000,
                        file_prefix='LL2_TSmx_lim_b_emin4_emax30_o',
                        data_type="skylocs",
                        skip_halos=[0])

# data_skylocs_ary, _, _ = plot_data_skylocs.return_limits()
# np.save("data_skylocs_ary_ecut4",data_skylocs_ary)
#data_skylocs_ary = np.load("data_skylocs_ary_ecut4.npy")

# %%
data_skylocs_ary = np.load("data_skylocs_ary_ecut4_emax30_200.npy")

# %%
plot_data = LimitPlot(data_dir='/tigress/nrodd/DM-Catalog-Scan/Scan-Small-ROI/data/Tully//',
                        elephant=False, 
                        nmc=1,
                        bcut=20,
                        nonoverlap=True,
                        nonoverlapradius=2.,
                        cut_0p5=False,
                        xsecslim=10,
                        TS100=9,
                        TS1000=9,
                        halos_ran=1000, 
                        halos_to_keep=1000,
                        data_type="data",
                        catalog_file="/tigress/nrodd/DM-Catalog-Scan/DataFiles/Catalogs/2MRSLocalTully_ALL_DATAPAPER_Planck15_v7.csv",
                        file_prefix='LL2_TSmx_lim_b_emin4_emax30_o',
                        skip_halos=[0])

data_ary, _, maxTS_ary = plot_data.return_limits()
# Out:
# /tigress/smsharma/anaconda2/lib/python2.7/site-packages/IPython/core/interactiveshell.py:2821: DtypeWarning: Columns (21,22,23) have mixed types. Specify dtype option on import or set low_memory=False.
#   if self.run_code(code, result):

# %%
# !pwd
# Out:
# /tigress/nrodd/DM-Catalog-Scan/Scan-Small-ROI/notebooks

# %%
np.save("data_passed_halos.npy",plot_data.passed_halos)

# %%
plot_data.halos_that_were_removed_TSxsec
# Out:
# array([ 95.])

# %%
plot_data.halos_that_were_removed_overlap
# Out:
# array([ 134.])

# %%
# np.save("included_halos", plot_data.passed_halos)

# %%
724 - 134 - 95
# Out:
# 495

# %%
1000- 724
# Out:
# 276

# %%
plot_data.n_good_halos
# Out:
# 724

# %%
len(plot_data.passed_halos)
# Out:
# 495

# %%
plot_data_nb = LimitPlot(data_dir='/tigress/nrodd/DM-Catalog-Scan/Scan-Small-ROI/data/Tully/////',
                        elephant=False, 
                        nmc=1,
                        bcut=20,
                        nonoverlap=True,
                        nonoverlapradius=2.,
                        cut_0p5=False,
                        xsecslim=10,
                        TS100=9,
                        TS1000=9,
                        halos_ran=1000, 
                        halos_to_keep=1000,
                        data_type="data",
                        catalog_file="/tigress/nrodd/DM-Catalog-Scan/DataFiles/Catalogs/2MRSLocalTully_ALL_DATAPAPER_Planck15_v7.csv",
                        file_prefix='LL2_TSmx_lim_b_nb_emin4_emax30_o',
                        skip_halos=[0])

data_ary_nb, _, _ = plot_data_nb.return_limits()

# %%
plot_h = 10/1.2
plot_w = 8/1.2

fig, ax = plt.subplots(1, figsize=(plot_h, plot_w))

fudge = 1.02

# plt.fill_between(plot_data.marr,10**np.percentile(data_skylocs_ary[len(data_ary)], 2.5, axis=1),10**np.percentile(data_skylocs_ary[len(data_ary)], 97.5, axis=1),color='yellow',label=r'95\% containment',alpha=0.6,lw=2)
# plt.fill_between(plot_data.marr,10**np.percentile(data_skylocs_ary[len(data_ary)], 16, axis=1),10**np.percentile(data_skylocs_ary[len(data_ary)], 84, axis=1),color='limegreen',label=r'68\% containment',alpha=0.7,lw=2)

# plt.plot(plot_data.marr,10**np.percentile(data_ary[-1], 2.5, axis=1), alpha=1, color='k',label=r'Galaxy groups (this work)',lw=2.5)
# plt.plot(plot_data.marr,10**np.percentile(data_ary_nb[-1], 2.5, axis=1), alpha=1, color='k',ls='--',label=r'Galaxy groups (no boost)',lw=2.5)


plt.plot(10**GCE[::,0],10**GCE[::,1],color='darkorange',alpha= 1.0,lw=1.4)
plt.plot(10**GCE[[0,-1],0],10**GCE[[0,-1],1],color='darkorange',alpha= 1.0,lw=1.4)
plt.plot(10**GCE_calore[::,0],10**GCE_calore[::,1],color='blue',alpha = 1.0,lw=1.4) #label = r'Daylan et. al. 2014 (2$\sigma$)',alpha=0.5)
plt.plot(10**GCE_calore[[0,-1],0],10**GCE_calore[[0,-1],1],color='blue',alpha = 1.0,lw=1.4)
plt.plot(10**GCE_gordan[::,0],10**GCE_gordan[::,1],color='magenta',alpha = 1.0,lw=1.4)
plt.plot(10**GCE_gordan[[0,-1],0],10**GCE_gordan[[0,-1],1],color='magenta',alpha = 1.0,lw=1.4)
plt.errorbar([10**ab_mean[0]],[10**ab_mean[1]],yerr = [ np.array([10**ab_mean[1] - 10**ab_low]), np.array([10**ab_up - 10**ab_mean[1] ]) ],
            xerr = [ np.array([10**ab_mean[0] - 10**ab_L]), np.array([10**ab_R - 10**ab_mean[0] ]) ],color='red',
            linewidth=2.0, capsize=6,capthick=.6,markersize=6,marker='o',alpha=0.7,mec='k')

plt.plot(massD,LimD,color='grey',label = r'$\mathit{Fermi}$ dwarfs (2016)',alpha=0.5)

plt.plot(thermal[::,0],thermal[::,1],linestyle='dotted',color='dimgrey',linewidth=1)

# handles,labels = ax.get_legend_handles_labels()
# handles = [handles[0],handles[4], handles[3],handles[1],handles[2]] #, handles[2]]
# labels = [labels[0], handles[1],labels[4],labels[3],labels[2]] #, labels[2]]

# labels = [u'Galaxy groups (this work)',
#  u'95\\% containment',
#  u'68\\% containment',
#           u'Galaxy groups, no boost',
#  u'$\\mathit{Fermi}$ dwarfs (2016)']

# leg = plt.legend(handles,labels,loc=2,fontsize=17,fancybox=True,facecolor='none',frameon=False)

plt.xscale('log')
plt.yscale('log')
plt.xticks(fontsize=23);
plt.yticks(fontsize=23);
plt.xlabel(r"$m_\chi$ [GeV]",fontsize=23)
plt.ylabel(r"$\langle \sigma v \rangle$ [cm$^3$ s$^{-1}$]",fontsize=23)

plt.xlim([1e1,1e4])
plt.ylim([8e-28,2e-22])

plt.text(200, 3.5e-27, r'\textbf{Stacked Galaxy Groups}',fontsize=22,color='black')
plt.text(950.3, 1.5e-27, r'Tully Catalogs, $b\bar b$',fontsize=20,color='black')
plt.text(380, 3.e-26, r'\emph{Thermal relic cross section}',fontsize=19.,color='dimgrey')

plt.tight_layout()

# plt.savefig(plots_dir + 'dwarfs_ecut4.pdf',bbox_inches='tight')

# %%
fig, ax = plt.subplots(1, figsize=(plot_h, plot_w))

fudge = 1.02

plt.fill_between(plot_data.marr,10**np.percentile(data_skylocs_ary[len(data_ary)], 2.5, axis=1),10**np.percentile(data_skylocs_ary[len(data_ary)], 97.5, axis=1),color='yellow',label=r'95\% containment',alpha=0.6,lw=2)
plt.fill_between(plot_data.marr,10**np.percentile(data_skylocs_ary[len(data_ary)], 16, axis=1),10**np.percentile(data_skylocs_ary[len(data_ary)], 84, axis=1),color='limegreen',label=r'68\% containment',alpha=0.7,lw=2)

plt.plot(plot_data.marr,10**np.percentile(data_ary[-1], 2.5, axis=1), alpha=1, color='k',label=r'Galaxy groups (this work)',lw=3)
plt.plot(plot_data.marr,10**np.percentile(data_ary_nb[-1], 2.5, axis=1), alpha=1, color='k',ls='--',label=r'Galaxy groups (no boost)',lw=2.5)


plt.plot(10**GCE[::,0],10**GCE[::,1],color='darkorange',alpha= 1.0,lw=1.4)
plt.plot(10**GCE[[0,-1],0],10**GCE[[0,-1],1],color='darkorange',alpha= 1.0,lw=1.4)
plt.plot(10**GCE_calore[::,0],10**GCE_calore[::,1],color='blue',alpha = 1.0,lw=1.4) #label = r'Daylan et. al. 2014 (2$\sigma$)',alpha=0.5)
plt.plot(10**GCE_calore[[0,-1],0],10**GCE_calore[[0,-1],1],color='blue',alpha = 1.0,lw=1.4)
plt.plot(10**GCE_gordan[::,0],10**GCE_gordan[::,1],color='magenta',alpha = 1.0,lw=1.4)
plt.plot(10**GCE_gordan[[0,-1],0],10**GCE_gordan[[0,-1],1],color='magenta',alpha = 1.0,lw=1.4)
plt.errorbar([10**ab_mean[0]],[10**ab_mean[1]],yerr = [ np.array([10**ab_mean[1] - 10**ab_low]), np.array([10**ab_up - 10**ab_mean[1] ]) ],
            xerr = [ np.array([10**ab_mean[0] - 10**ab_L]), np.array([10**ab_R - 10**ab_mean[0] ]) ],color='red',
            linewidth=2.0, capsize=6,capthick=.6,markersize=6,marker='o',alpha=0.7,mec='k')

plt.plot(massD,LimD,color='grey',label = r'$\mathit{Fermi}$ dwarfs (2016)',alpha=0.5)

plt.plot(thermal[::,0],thermal[::,1],linestyle='dotted',color='dimgrey',linewidth=1)


m3, = plt.plot([], [], c='limegreen' , marker='s', markersize=20,
              fillstyle='left', linestyle='none',alpha=0.6)

m4, = plt.plot([], [], c='yellow' , marker='s', markersize=20,
              fillstyle='right', linestyle='none',alpha=0.6)


handles,labels = ax.get_legend_handles_labels()
handles = [handles[0],(m3,m4),handles[1],handles[2]] #, handles[2]]
labels = [labels[0], '$68/95\%$ containment','Galaxy groups, no boost',labels[2]] #, labels[2]]

labels = [u'Galaxy groups (this work)',
'$68/95\%$ containment',
          u'Galaxy groups, no boost',
 u'$\\mathit{Fermi}$ dwarfs (2016)']

leg = plt.legend(handles,labels,loc=2,fontsize=17,fancybox=True,facecolor='none',frameon=False)

plt.xscale('log')
plt.yscale('log')
plt.xticks(fontsize=23);
plt.yticks(fontsize=23);
plt.xlabel(r"$m_\chi$ [GeV]",fontsize=23)
plt.ylabel(r"$\langle \sigma v \rangle$ [cm$^3$ s$^{-1}$]",fontsize=23)

plt.xlim([1e1,1e4])
plt.ylim([8e-28,2e-22])

plt.text(200, 3.5e-27, r'\textbf{Stacked Galaxy Groups}',fontsize=22,color='black')
plt.text(320., 1.5e-27, r'\emph{Fermi}-LAT Pass 8 Data, $b\bar b$',fontsize=20,color='black')
plt.text(380, 3.e-26, r'\emph{Thermal relic cross section}',fontsize=19.,color='dimgrey')

plt.tight_layout()

# plt.savefig(plots_dir + 'bounds.pdf',bbox_inches='tight')

# %%
midx = 11
fig, ax = plt.subplots(1, figsize=(plot_h, plot_w))

plt.plot(np.arange(len(data_ary[:,midx,:])) + 1,10**np.percentile(data_ary[:,midx,:],[50],axis=1)[0], color='k',lw=2)
plt.fill_between(np.arange(len(data_skylocs_ary[:,midx,:])) + 1,10**np.percentile(data_skylocs_ary[:,midx,:],[2.5],axis=1)[0],10**np.percentile(data_skylocs_ary[:,midx,:],[97.5],axis=1)[0], alpha=0.3, color='salmon')
plt.fill_between(np.arange(len(data_skylocs_ary[:,midx,:])) + 1,10**np.percentile(data_skylocs_ary[:,midx,:],[16],axis=1)[0],10**np.percentile(data_skylocs_ary[:,midx,:],[84],axis=1)[0], alpha=0.4, color='salmon')

plt.xscale('log')
plt.yscale('log')
plt.xticks(fontsize=23);
plt.yticks(fontsize=23);
plt.xlabel(r"$N_\mathrm{H}$ (halo number)",fontsize=23)
plt.ylabel(r"$\langle \sigma v \rangle$ [cm$^3$ s$^{-1}$]",fontsize=23)
plt.xlim(1,len(data_ary[:,midx,:]) + 1) 
#     plt.xlim([1e1,1e4])
plt.ylim([1.e-26,5.e-24])

plt.text(1.3, 2e-26, r'\textbf{Cumulative Galaxy Groups}',fontsize=22,color='black')
plt.text(1.3, 1.2e-26, r'$b\bar b, m_\chi = 100$ GeV',fontsize=20,color='black')
plt.tight_layout()

plt.savefig(plots_dir + 'elephant.pdf',bbox_inches='tight')

# %% [markdown]
# ## Other elephants

# %%
midx = 0
fig, ax = plt.subplots(1, figsize=(plot_h, plot_w))

plt.plot(np.arange(len(data_ary[:,midx,:])) + 1,10**np.percentile(data_ary[:,midx,:],[50],axis=1)[0], color='k',lw=2)
plt.fill_between(np.arange(len(data_skylocs_ary[:,midx,:])) + 1,10**np.percentile(data_skylocs_ary[:,midx,:],[2.5],axis=1)[0],10**np.percentile(data_skylocs_ary[:,midx,:],[97.5],axis=1)[0], alpha=0.3, color='salmon')
plt.fill_between(np.arange(len(data_skylocs_ary[:,midx,:])) + 1,10**np.percentile(data_skylocs_ary[:,midx,:],[16],axis=1)[0],10**np.percentile(data_skylocs_ary[:,midx,:],[84],axis=1)[0], alpha=0.4, color='salmon')

plt.xscale('log')
plt.yscale('log')
plt.xticks(fontsize=23);
plt.yticks(fontsize=23);
plt.xlabel(r"$N_\mathrm{H}$ (halo number)",fontsize=23)
plt.ylabel(r"$\langle \sigma v \rangle$ [cm$^3$ s$^{-1}$]",fontsize=23)
plt.xlim(1,len(data_ary[:,midx,:]) + 1) 
#     plt.xlim([1e1,1e4])
plt.ylim([1.e-27,5e-25])

plt.text(1.3, 2.e-27, r'\textbf{Cumulative Galaxy Groups}',fontsize=22,color='black')
plt.text(1.3, 1.2e-27, r'$b\bar b, m_\chi = 10$ GeV',fontsize=20,color='black')
plt.tight_layout()

plt.savefig(plots_dir + 'elephant10.pdf',bbox_inches='tight')

# %%
midx = 52
fig, ax = plt.subplots(1, figsize=(plot_h, plot_w))

plt.plot(np.arange(len(data_ary[:,midx,:])) + 1,10**np.percentile(data_ary[:,midx,:],[50],axis=1)[0], color='k',lw=2)
plt.fill_between(np.arange(len(data_skylocs_ary[:,midx,:])) + 1,10**np.percentile(data_skylocs_ary[:,midx,:],[2.5],axis=1)[0],10**np.percentile(data_skylocs_ary[:,midx,:],[97.5],axis=1)[0], alpha=0.3, color='salmon')
plt.fill_between(np.arange(len(data_skylocs_ary[:,midx,:])) + 1,10**np.percentile(data_skylocs_ary[:,midx,:],[16],axis=1)[0],10**np.percentile(data_skylocs_ary[:,midx,:],[84],axis=1)[0], alpha=0.4, color='salmon')

plt.xscale('log')
plt.yscale('log')
plt.xticks(fontsize=23);
plt.yticks(fontsize=23);
plt.xlabel(r"$N_\mathrm{H}$ (halo number)",fontsize=23)
plt.ylabel(r"$\langle \sigma v \rangle$ [cm$^3$ s$^{-1}$]",fontsize=23)
plt.xlim(1,len(data_ary[:,midx,:]) + 1) 
#     plt.xlim([1e1,1e4])
plt.ylim([5e-24,1e-21])

plt.text(1.3, 9e-24, r'\textbf{Cumulative Galaxy Groups}',fontsize=22,color='black')
plt.text(1.3, 5.8e-24, r'$b\bar b, m_\chi = 10$ TeV',fontsize=20,color='black')
plt.tight_layout()

plt.savefig(plots_dir + 'elephant10000.pdf',bbox_inches='tight')

# %% [markdown]
# # Tables

# %%
catalog = pd.read_csv("/tigress/nrodd/DM-Catalog-Scan/DataFiles/Catalogs/2MRSLocalTully_ALL_DATAPAPER_Planck15_extra2_v7.csv")

# %%
catalog.columns.values
# Out:
# array(['Unnamed: 0', 'Name', 'mulog10J_inf', 'siglog10J_inf',
#        'mulog10Jnb_inf', 'siglog10Jnb_inf', 'mulog10JB_inf',
#        'siglog10JB_inf', 'mulog10JBnb_inf', 'siglog10JBnb_inf',
#        'mulog10D_inf', 'siglog10D_inf', 'log10Mvir_inf',
#        'sigmalog10Mvir_inf', 'z', 'Nest', 'Ng', 'l', 'b', 'cvir_inf',
#        'sigmalog10cvir_inf', 'rvir_inf', 'rs', 'ID_2MASXJ', 'Bib_z',
#        'GName', '3FGL 0.5', '3FGL 1', '3FGL 2', '3FGL 5', '3FGL 10',
#        'N3FGL 5', 'ang_ext', 'theta_vir', 'log10M200_inf', 'ra', 'dec',
#        'dA'], dtype=object)

# %%
catalog['zred'] = catalog['z']*1000
catalog['log10cvir_inf'] = np.log10(catalog['cvir_inf'])
catalog['theta_s'] = catalog['ang_ext']/2.
catalog['bsh'] = 10**catalog['mulog10J_inf']/10**catalog['mulog10Jnb_inf'] - 1
catalog['paperName'] = [catalog['GName'][i] if isinstance(catalog['GName'][i], str) else catalog['Name'][i] for i in range(len(catalog))]

# %%
catalog['log10Jerr'] = [str(catalog['mulog10J_inf'].values[i]) [:5] +str('$\\pm$') + str(catalog['siglog10J_inf'].values[i]) [:4] for i in range(len(catalog))]#[:4]

# %%
catalog['log10cerr'] = [str(catalog['log10cvir_inf'].values[i]) [:4] +str('$\\pm$') + str(catalog['sigmalog10cvir_inf'].values[i]) [:4] for i in range(len(catalog))]#[:4]

# %%
catalog['log10Merr'] = [str(catalog['log10Mvir_inf'].values[i]) [:4] +str('$\\pm$') + str(catalog['sigmalog10Mvir_inf'].values[i]) [:4] for i in range(len(catalog))]#[:4]

# %%
catalog['in'] = ['\checkmark' if i in plot_data.passed_halos else '' for i in range(len(catalog))]#[:4]

# %%
catalog_paper = catalog.iloc[plot_data.passed_halos][['paperName','log10Jerr','log10Merr','zred','l','b','log10cerr','theta_s','bsh']].round(2).to_latex(index = False)

# %%
print catalog_paper
# Out:
# \begin{tabular}{lllrrrlrr}
# \toprule
#             paperName &       log10Jerr &      log10Merr &   zred &       l &      b &      log10cerr &  theta\_s &   bsh \\
# \midrule
#                 Virgo &  19.11\$\textbackslashpm\$0.35 &  14.6\$\textbackslashpm\$0.14 &   3.58 &  283.78 &  74.49 &  0.80\$\textbackslashpm\$0.18 &     1.16 &  4.53 \\
#               NGC0253 &  18.76\$\textbackslashpm\$0.37 &  12.7\$\textbackslashpm\$0.12 &   0.79 &   98.24 & -87.89 &  1.00\$\textbackslashpm\$0.17 &     0.77 &  2.90 \\
#               NGC3031 &  18.58\$\textbackslashpm\$0.36 &  12.6\$\textbackslashpm\$0.12 &   0.83 &  141.88 &  40.87 &  1.02\$\textbackslashpm\$0.17 &     0.64 &  2.76 \\
#             Centaurus &  18.34\$\textbackslashpm\$0.35 &  14.6\$\textbackslashpm\$0.14 &   8.44 &  302.22 &  21.65 &  0.80\$\textbackslashpm\$0.18 &     0.48 &  4.50 \\
#               NGC1399 &  18.31\$\textbackslashpm\$0.37 &  13.8\$\textbackslashpm\$0.13 &   4.11 &  236.62 & -53.88 &  0.89\$\textbackslashpm\$0.17 &     0.45 &  3.87 \\
#               NGC4594 &  18.26\$\textbackslashpm\$0.35 &  13.3\$\textbackslashpm\$0.13 &   2.56 &  299.01 &  51.30 &  0.94\$\textbackslashpm\$0.17 &     0.43 &  3.36 \\
#               IC 1613 &  18.17\$\textbackslashpm\$0.37 &  10.6\$\textbackslashpm\$0.10 &   0.17 &  129.74 & -60.58 &  1.18\$\textbackslashpm\$0.17 &     0.48 &  1.67 \\
#               NGC4736 &  18.12\$\textbackslashpm\$0.36 &  12.2\$\textbackslashpm\$0.12 &   1.00 &  124.83 &  75.76 &  1.05\$\textbackslashpm\$0.17 &     0.38 &  2.58 \\
#               NGC4565 &  17.97\$\textbackslashpm\$0.35 &  13.1\$\textbackslashpm\$0.13 &   2.98 &  229.92 &  86.07 &  0.96\$\textbackslashpm\$0.17 &     0.31 &  3.28 \\
#                 Hydra &  17.95\$\textbackslashpm\$0.34 &  14.4\$\textbackslashpm\$0.14 &  10.87 &  269.55 &  26.41 &  0.82\$\textbackslashpm\$0.17 &     0.30 &  4.32 \\
#                Dorado &  17.94\$\textbackslashpm\$0.36 &  13.4\$\textbackslashpm\$0.13 &   4.02 &  265.56 & -43.51 &  0.94\$\textbackslashpm\$0.17 &     0.30 &  3.41 \\
#               NGC3379 &  17.94\$\textbackslashpm\$0.37 &  12.9\$\textbackslashpm\$0.12 &   2.42 &  233.64 &  57.77 &  0.99\$\textbackslashpm\$0.17 &     0.29 &  3.11 \\
#               NGC5194 &  17.93\$\textbackslashpm\$0.37 &  12.6\$\textbackslashpm\$0.12 &   1.84 &  104.86 &  68.53 &  1.01\$\textbackslashpm\$0.17 &     0.30 &  2.81 \\
#               NGC4258 &  17.92\$\textbackslashpm\$0.36 &  12.5\$\textbackslashpm\$0.12 &   1.64 &  139.02 &  68.89 &  1.03\$\textbackslashpm\$0.17 &     0.30 &  2.71 \\
#               NGC1068 &  17.91\$\textbackslashpm\$0.35 &  13.3\$\textbackslashpm\$0.13 &   3.60 &  171.99 & -51.86 &  0.95\$\textbackslashpm\$0.17 &     0.29 &  3.33 \\
#               NGC4826 &  17.88\$\textbackslashpm\$0.36 &  12.1\$\textbackslashpm\$0.12 &   1.16 &  315.69 &  84.42 &  1.06\$\textbackslashpm\$0.17 &     0.29 &  2.53 \\
#               NGC4527 &  17.84\$\textbackslashpm\$0.35 &  13.1\$\textbackslashpm\$0.13 &   3.25 &  293.05 &  64.93 &  0.97\$\textbackslashpm\$0.17 &     0.26 &  3.26 \\
#               NGC5054 &  17.82\$\textbackslashpm\$0.36 &  13.7\$\textbackslashpm\$0.13 &   6.35 &  310.93 &  45.97 &  0.90\$\textbackslashpm\$0.17 &     0.26 &  3.70 \\
#               NGC6744 &  17.80\$\textbackslashpm\$0.36 &  12.6\$\textbackslashpm\$0.12 &   2.08 &  331.52 & -25.40 &  1.01\$\textbackslashpm\$0.17 &     0.26 &  2.78 \\
#               NGC5846 &  17.80\$\textbackslashpm\$0.36 &  13.6\$\textbackslashpm\$0.13 &   6.09 &    0.28 &  49.12 &  0.91\$\textbackslashpm\$0.17 &     0.25 &  3.62 \\
#               NGC0055 &  17.78\$\textbackslashpm\$0.36 &  11.1\$\textbackslashpm\$0.11 &   0.45 &  332.87 & -75.73 &  1.14\$\textbackslashpm\$0.17 &     0.28 &  1.96 \\
#               NGC4697 &  17.78\$\textbackslashpm\$0.37 &  12.9\$\textbackslashpm\$0.12 &   3.01 &  301.96 &  57.00 &  0.99\$\textbackslashpm\$0.17 &     0.24 &  3.16 \\
#               NGC4373 &  17.77\$\textbackslashpm\$0.36 &  13.7\$\textbackslashpm\$0.13 &   6.48 &  297.56 &  23.08 &  0.91\$\textbackslashpm\$0.17 &     0.24 &  3.65 \\
#               NGC5055 &  17.74\$\textbackslashpm\$0.36 &  12.4\$\textbackslashpm\$0.12 &   1.75 &  106.06 &  74.27 &  1.04\$\textbackslashpm\$0.17 &     0.24 &  2.63 \\
#               NGC0988 &  17.73\$\textbackslashpm\$0.35 &  13.1\$\textbackslashpm\$0.13 &   3.91 &  181.53 & -58.61 &  0.96\$\textbackslashpm\$0.17 &     0.23 &  3.28 \\
#               NGC1395 &  17.73\$\textbackslashpm\$0.35 &  13.3\$\textbackslashpm\$0.13 &   4.58 &  216.58 & -52.00 &  0.95\$\textbackslashpm\$0.17 &     0.23 &  3.34 \\
#               NGC5353 &  17.72\$\textbackslashpm\$0.36 &  13.7\$\textbackslashpm\$0.13 &   7.30 &   82.88 &  71.62 &  0.90\$\textbackslashpm\$0.17 &     0.23 &  3.72 \\
#               NGC4725 &  17.71\$\textbackslashpm\$0.37 &  12.8\$\textbackslashpm\$0.12 &   2.75 &  295.19 &  88.37 &  1.00\$\textbackslashpm\$0.17 &     0.23 &  2.94 \\
#               NGC5078 &  17.70\$\textbackslashpm\$0.36 &  13.4\$\textbackslashpm\$0.13 &   5.41 &  310.62 &  35.23 &  0.93\$\textbackslashpm\$0.17 &     0.22 &  3.42 \\
#               NGC1291 &  17.69\$\textbackslashpm\$0.36 &  12.5\$\textbackslashpm\$0.12 &   2.09 &  247.53 & -57.08 &  1.03\$\textbackslashpm\$0.17 &     0.23 &  2.69 \\
#               NGC6753 &  17.69\$\textbackslashpm\$0.36 &  13.6\$\textbackslashpm\$0.13 &   6.84 &  340.14 & -25.25 &  0.91\$\textbackslashpm\$0.17 &     0.22 &  3.60 \\
#               NGC7331 &  17.68\$\textbackslashpm\$0.37 &  12.9\$\textbackslashpm\$0.12 &   3.23 &   93.70 & -20.74 &  0.99\$\textbackslashpm\$0.17 &     0.22 &  3.11 \\
#               NGC3557 &  17.68\$\textbackslashpm\$0.36 &  13.6\$\textbackslashpm\$0.13 &   7.04 &  281.46 &  21.23 &  0.91\$\textbackslashpm\$0.17 &     0.22 &  3.63 \\
#                AS851A &  17.67\$\textbackslashpm\$0.36 &  13.7\$\textbackslashpm\$0.13 &   7.72 &  350.91 & -32.35 &  0.90\$\textbackslashpm\$0.17 &     0.22 &  3.73 \\
#       g1349053-301745 &  17.66\$\textbackslashpm\$0.34 &  14.5\$\textbackslashpm\$0.14 &  16.44 &  317.44 &  30.95 &  0.81\$\textbackslashpm\$0.18 &     0.22 &  4.38 \\
#              NGC\_0708 &  17.66\$\textbackslashpm\$0.34 &  14.4\$\textbackslashpm\$0.14 &  15.63 &  136.57 & -25.09 &  0.82\$\textbackslashpm\$0.18 &     0.22 &  4.34 \\
#                   Leo &  17.66\$\textbackslashpm\$0.35 &  14.8\$\textbackslashpm\$0.14 &  23.31 &  234.29 &  72.99 &  0.77\$\textbackslashpm\$0.18 &     0.22 &  4.78 \\
#               NGC5005 &  17.64\$\textbackslashpm\$0.37 &  12.9\$\textbackslashpm\$0.12 &   3.41 &  100.28 &  79.35 &  0.99\$\textbackslashpm\$0.17 &     0.21 &  3.11 \\
#               NGC3923 &  17.62\$\textbackslashpm\$0.35 &  13.3\$\textbackslashpm\$0.13 &   5.13 &  287.03 &  32.26 &  0.95\$\textbackslashpm\$0.17 &     0.20 &  3.34 \\
#                NGC507 &  17.60\$\textbackslashpm\$0.34 &  14.3\$\textbackslashpm\$0.14 &  15.43 &  130.64 & -29.13 &  0.83\$\textbackslashpm\$0.17 &     0.20 &  4.29 \\
#               NGC7814 &  17.60\$\textbackslashpm\$0.36 &  12.4\$\textbackslashpm\$0.12 &   2.23 &  106.44 & -45.18 &  1.03\$\textbackslashpm\$0.17 &     0.21 &  2.67 \\
#               NGC5322 &  17.60\$\textbackslashpm\$0.35 &  13.3\$\textbackslashpm\$0.13 &   5.29 &  110.02 &  55.44 &  0.95\$\textbackslashpm\$0.17 &     0.20 &  3.34 \\
#               NGC4105 &  17.60\$\textbackslashpm\$0.35 &  13.2\$\textbackslashpm\$0.13 &   4.88 &  291.66 &  31.88 &  0.96\$\textbackslashpm\$0.17 &     0.20 &  3.30 \\
#               NGC4437 &  17.59\$\textbackslashpm\$0.36 &  12.3\$\textbackslashpm\$0.12 &   2.03 &  292.73 &  62.63 &  1.04\$\textbackslashpm\$0.17 &     0.21 &  2.62 \\
#                Pisces &  17.58\$\textbackslashpm\$0.34 &  14.4\$\textbackslashpm\$0.14 &  16.34 &  127.63 & -29.54 &  0.82\$\textbackslashpm\$0.17 &     0.20 &  4.31 \\
#               NGC4039 &  17.58\$\textbackslashpm\$0.35 &  13.2\$\textbackslashpm\$0.13 &   4.91 &  286.29 &  42.15 &  0.96\$\textbackslashpm\$0.17 &     0.20 &  3.30 \\
#               NGC4414 &  17.58\$\textbackslashpm\$0.37 &  12.9\$\textbackslashpm\$0.12 &   3.70 &  191.25 &  83.05 &  0.99\$\textbackslashpm\$0.17 &     0.19 &  3.13 \\
#               NGC0584 &  17.58\$\textbackslashpm\$0.35 &  13.3\$\textbackslashpm\$0.13 &   5.34 &  151.42 & -67.62 &  0.95\$\textbackslashpm\$0.17 &     0.19 &  3.33 \\
#               NGC5084 &  17.58\$\textbackslashpm\$0.35 &  13.1\$\textbackslashpm\$0.13 &   4.53 &  312.13 &  41.02 &  0.97\$\textbackslashpm\$0.17 &     0.19 &  3.26 \\
#               NGC0157 &  17.57\$\textbackslashpm\$0.36 &  12.6\$\textbackslashpm\$0.12 &   2.74 &  110.28 & -70.86 &  1.01\$\textbackslashpm\$0.17 &     0.20 &  2.78 \\
#               NGC7582 &  17.55\$\textbackslashpm\$0.35 &  13.2\$\textbackslashpm\$0.13 &   4.97 &  347.83 & -65.50 &  0.96\$\textbackslashpm\$0.17 &     0.19 &  3.29 \\
#               NGC4958 &  17.53\$\textbackslashpm\$0.37 &  12.7\$\textbackslashpm\$0.12 &   3.33 &  309.62 &  54.72 &  1.00\$\textbackslashpm\$0.17 &     0.19 &  2.92 \\
#               NGC2974 &  17.51\$\textbackslashpm\$0.35 &  13.1\$\textbackslashpm\$0.13 &   5.02 &  239.53 &  35.01 &  0.96\$\textbackslashpm\$0.17 &     0.18 &  3.27 \\
#               NGC0300 &  17.51\$\textbackslashpm\$0.37 &  10.8\$\textbackslashpm\$0.10 &   0.45 &  299.21 & -79.42 &  1.16\$\textbackslashpm\$0.17 &     0.22 &  1.80 \\
#       g1253072-102939 &  17.50\$\textbackslashpm\$0.34 &  14.2\$\textbackslashpm\$0.14 &  15.21 &  303.61 &  52.38 &  0.84\$\textbackslashpm\$0.17 &     0.18 &  4.22 \\
#               NGC0697 &  17.50\$\textbackslashpm\$0.35 &  13.3\$\textbackslashpm\$0.13 &   6.33 &  140.52 & -38.80 &  0.94\$\textbackslashpm\$0.17 &     0.18 &  3.37 \\
#               NGC0524 &  17.49\$\textbackslashpm\$0.36 &  13.4\$\textbackslashpm\$0.13 &   7.11 &  136.38 & -52.52 &  0.93\$\textbackslashpm\$0.17 &     0.18 &  3.44 \\
#               NGC2787 &  17.48\$\textbackslashpm\$0.36 &  12.0\$\textbackslashpm\$0.12 &   1.68 &  144.07 &  38.08 &  1.07\$\textbackslashpm\$0.17 &     0.18 &  2.51 \\
#                IC1459 &  17.48\$\textbackslashpm\$0.35 &  13.2\$\textbackslashpm\$0.13 &   5.55 &    4.69 & -64.13 &  0.96\$\textbackslashpm\$0.17 &     0.17 &  3.30 \\
#              Eridanus &  17.48\$\textbackslashpm\$0.35 &  13.3\$\textbackslashpm\$0.13 &   6.30 &  209.71 & -50.33 &  0.94\$\textbackslashpm\$0.17 &     0.17 &  3.36 \\
#       g1914438-621621 &  17.48\$\textbackslashpm\$0.34 &  14.1\$\textbackslashpm\$0.14 &  14.10 &  334.07 & -26.46 &  0.86\$\textbackslashpm\$0.17 &     0.17 &  4.18 \\
#               NGC4666 &  17.48\$\textbackslashpm\$0.37 &  12.7\$\textbackslashpm\$0.12 &   3.46 &  299.40 &  62.40 &  1.00\$\textbackslashpm\$0.17 &     0.18 &  2.90 \\
#               IC\_4296 &  17.48\$\textbackslashpm\$0.34 &  14.1\$\textbackslashpm\$0.14 &  14.03 &  313.54 &  27.97 &  0.86\$\textbackslashpm\$0.17 &     0.17 &  4.17 \\
#               NGC1332 &  17.47\$\textbackslashpm\$0.35 &  13.0\$\textbackslashpm\$0.13 &   4.75 &  212.26 & -54.02 &  0.97\$\textbackslashpm\$0.17 &     0.17 &  3.24 \\
#               NGC0134 &  17.45\$\textbackslashpm\$0.37 &  12.9\$\textbackslashpm\$0.12 &   4.41 &  338.36 & -82.42 &  0.98\$\textbackslashpm\$0.17 &     0.17 &  3.17 \\
#              UGC05373 &  17.45\$\textbackslashpm\$0.37 &  10.4\$\textbackslashpm\$0.10 &   0.31 &  233.20 &  43.78 &  1.19\$\textbackslashpm\$0.17 &     0.22 &  1.60 \\
#               NGC3109 &  17.45\$\textbackslashpm\$0.37 &  10.4\$\textbackslashpm\$0.10 &   0.31 &  262.14 &  23.04 &  1.19\$\textbackslashpm\$0.17 &     0.22 &  1.59 \\
#        ESO\_185-\_G\_054 &  17.45\$\textbackslashpm\$0.34 &  14.2\$\textbackslashpm\$0.14 &  15.99 &  341.90 & -32.13 &  0.85\$\textbackslashpm\$0.17 &     0.17 &  4.21 \\
#               NGC1097 &  17.44\$\textbackslashpm\$0.37 &  12.9\$\textbackslashpm\$0.12 &   4.16 &  226.37 & -64.77 &  0.99\$\textbackslashpm\$0.17 &     0.17 &  3.06 \\
#               NGC4936 &  17.43\$\textbackslashpm\$0.36 &  13.7\$\textbackslashpm\$0.13 &  10.07 &  306.04 &  32.57 &  0.90\$\textbackslashpm\$0.17 &     0.17 &  3.71 \\
#               NGC0488 &  17.43\$\textbackslashpm\$0.36 &  13.4\$\textbackslashpm\$0.13 &   7.50 &  137.15 & -57.48 &  0.93\$\textbackslashpm\$0.17 &     0.16 &  3.43 \\
#                IC4797 &  17.42\$\textbackslashpm\$0.35 &  13.3\$\textbackslashpm\$0.13 &   6.45 &  342.07 & -22.44 &  0.95\$\textbackslashpm\$0.17 &     0.16 &  3.34 \\
#              NGC\_2320 &  17.42\$\textbackslashpm\$0.34 &  14.4\$\textbackslashpm\$0.14 &  20.22 &  166.36 &  22.79 &  0.82\$\textbackslashpm\$0.17 &     0.16 &  4.32 \\
#             UrsaMajor &  17.42\$\textbackslashpm\$0.37 &  12.9\$\textbackslashpm\$0.12 &   4.56 &  140.53 &  62.41 &  0.99\$\textbackslashpm\$0.17 &     0.16 &  3.16 \\
#               NGC4111 &  17.42\$\textbackslashpm\$0.36 &  12.6\$\textbackslashpm\$0.12 &   3.26 &  148.78 &  71.62 &  1.01\$\textbackslashpm\$0.17 &     0.17 &  2.78 \\
#               NGC7176 &  17.40\$\textbackslashpm\$0.36 &  13.4\$\textbackslashpm\$0.13 &   7.74 &   14.88 & -53.09 &  0.93\$\textbackslashpm\$0.17 &     0.16 &  3.43 \\
#               NGC4157 &  17.40\$\textbackslashpm\$0.37 &  12.7\$\textbackslashpm\$0.12 &   3.75 &  140.40 &  65.14 &  1.00\$\textbackslashpm\$0.17 &     0.16 &  2.89 \\
#                 A2877 &  17.39\$\textbackslashpm\$0.34 &  14.5\$\textbackslashpm\$0.14 &  23.01 &  293.10 & -70.84 &  0.81\$\textbackslashpm\$0.18 &     0.16 &  4.39 \\
#        NGC\_1128\_NED02 &  17.38\$\textbackslashpm\$0.34 &  14.5\$\textbackslashpm\$0.14 &  24.11 &  170.26 & -44.93 &  0.81\$\textbackslashpm\$0.18 &     0.16 &  4.42 \\
#               NGC3521 &  17.38\$\textbackslashpm\$0.36 &  12.5\$\textbackslashpm\$0.12 &   3.00 &  255.53 &  52.83 &  1.03\$\textbackslashpm\$0.17 &     0.16 &  2.70 \\
#               NGC4036 &  17.37\$\textbackslashpm\$0.37 &  12.8\$\textbackslashpm\$0.12 &   4.33 &  133.81 &  54.51 &  0.99\$\textbackslashpm\$0.17 &     0.15 &  3.01 \\
#               NGC2300 &  17.36\$\textbackslashpm\$0.35 &  13.3\$\textbackslashpm\$0.13 &   7.08 &  127.90 &  28.08 &  0.95\$\textbackslashpm\$0.17 &     0.15 &  3.35 \\
#      12040617+2014063 &  17.36\$\textbackslashpm\$0.34 &  14.5\$\textbackslashpm\$0.14 &  24.92 &  242.89 &  77.17 &  0.80\$\textbackslashpm\$0.18 &     0.15 &  4.43 \\
#            ESO507-025 &  17.35\$\textbackslashpm\$0.36 &  13.5\$\textbackslashpm\$0.13 &   9.11 &  302.93 &  36.41 &  0.92\$\textbackslashpm\$0.17 &     0.15 &  3.51 \\
#               NGC1532 &  17.35\$\textbackslashpm\$0.37 &  12.7\$\textbackslashpm\$0.12 &   3.90 &  232.61 & -46.44 &  1.01\$\textbackslashpm\$0.17 &     0.15 &  2.87 \\
#               NGC7049 &  17.34\$\textbackslashpm\$0.35 &  13.1\$\textbackslashpm\$0.13 &   6.25 &  350.47 & -43.96 &  0.96\$\textbackslashpm\$0.17 &     0.15 &  3.28 \\
#               NGC0404 &  17.33\$\textbackslashpm\$0.36 &  11.0\$\textbackslashpm\$0.11 &   0.68 &  127.03 & -27.01 &  1.15\$\textbackslashpm\$0.17 &     0.17 &  1.94 \\
#               NGC7793 &  17.33\$\textbackslashpm\$0.37 &  11.2\$\textbackslashpm\$0.11 &   0.81 &    4.52 & -77.17 &  1.14\$\textbackslashpm\$0.17 &     0.17 &  1.97 \\
#               NGC4636 &  17.31\$\textbackslashpm\$0.36 &  12.6\$\textbackslashpm\$0.12 &   3.68 &  297.60 &  65.83 &  1.01\$\textbackslashpm\$0.17 &     0.15 &  2.78 \\
#               NGC0628 &  17.30\$\textbackslashpm\$0.36 &  12.1\$\textbackslashpm\$0.12 &   2.21 &  138.64 & -45.70 &  1.06\$\textbackslashpm\$0.17 &     0.15 &  2.53 \\
#          Pegasus dIrr &  17.30\$\textbackslashpm\$0.37 &  10.1\$\textbackslashpm\$0.10 &   0.27 &   94.78 & -43.55 &  1.21\$\textbackslashpm\$0.17 &     0.19 &  1.53 \\
#               NGC5102 &  17.30\$\textbackslashpm\$0.37 &  11.2\$\textbackslashpm\$0.11 &   0.84 &  309.73 &  25.84 &  1.14\$\textbackslashpm\$0.17 &     0.16 &  1.97 \\
#        ESO\_443-\_G\_024 &  17.29\$\textbackslashpm\$0.34 &  14.1\$\textbackslashpm\$0.14 &  17.69 &  305.27 &  30.39 &  0.86\$\textbackslashpm\$0.17 &     0.14 &  4.18 \\
#               NGC4699 &  17.28\$\textbackslashpm\$0.37 &  12.7\$\textbackslashpm\$0.12 &   4.43 &  301.87 &  54.20 &  1.00\$\textbackslashpm\$0.17 &     0.14 &  2.92 \\
#               NGC0936 &  17.27\$\textbackslashpm\$0.37 &  12.9\$\textbackslashpm\$0.12 &   5.34 &  168.71 & -55.19 &  0.99\$\textbackslashpm\$0.17 &     0.14 &  3.15 \\
#               NGC5473 &  17.26\$\textbackslashpm\$0.35 &  13.1\$\textbackslashpm\$0.13 &   6.42 &  102.64 &  58.98 &  0.97\$\textbackslashpm\$0.17 &     0.13 &  3.26 \\
#               NGC5566 &  17.26\$\textbackslashpm\$0.37 &  12.9\$\textbackslashpm\$0.12 &   5.37 &  349.05 &  58.31 &  0.99\$\textbackslashpm\$0.17 &     0.13 &  3.13 \\
#               NGC3610 &  17.26\$\textbackslashpm\$0.35 &  13.1\$\textbackslashpm\$0.13 &   6.50 &  143.85 &  54.86 &  0.97\$\textbackslashpm\$0.17 &     0.13 &  3.26 \\
#               NGC7507 &  17.25\$\textbackslashpm\$0.37 &  12.7\$\textbackslashpm\$0.12 &   4.50 &   23.52 & -68.07 &  1.00\$\textbackslashpm\$0.17 &     0.14 &  2.91 \\
#               NGC3390 &  17.25\$\textbackslashpm\$0.37 &  12.7\$\textbackslashpm\$0.12 &   4.33 &  274.27 &  24.40 &  1.01\$\textbackslashpm\$0.17 &     0.14 &  2.87 \\
#               NGC3621 &  17.25\$\textbackslashpm\$0.37 &  11.7\$\textbackslashpm\$0.11 &   1.52 &  281.21 &  26.10 &  1.10\$\textbackslashpm\$0.17 &     0.15 &  2.21 \\
#               NGC4753 &  17.24\$\textbackslashpm\$0.36 &  12.4\$\textbackslashpm\$0.12 &   3.12 &  303.47 &  61.69 &  1.04\$\textbackslashpm\$0.17 &     0.14 &  2.63 \\
#               NGC2442 &  17.24\$\textbackslashpm\$0.37 &  12.8\$\textbackslashpm\$0.12 &   4.81 &  281.03 & -21.70 &  1.00\$\textbackslashpm\$0.17 &     0.13 &  2.96 \\
#               NGC0972 &  17.24\$\textbackslashpm\$0.36 &  12.5\$\textbackslashpm\$0.12 &   3.47 &  148.40 & -28.43 &  1.03\$\textbackslashpm\$0.17 &     0.14 &  2.68 \\
#               NGC4291 &  17.23\$\textbackslashpm\$0.37 &  12.9\$\textbackslashpm\$0.12 &   5.36 &  125.58 &  41.64 &  0.99\$\textbackslashpm\$0.17 &     0.13 &  3.09 \\
#               NGC2903 &  17.23\$\textbackslashpm\$0.36 &  12.0\$\textbackslashpm\$0.12 &   2.11 &  208.71 &  44.54 &  1.07\$\textbackslashpm\$0.17 &     0.14 &  2.50 \\
#               NGC5898 &  17.23\$\textbackslashpm\$0.35 &  13.1\$\textbackslashpm\$0.13 &   6.77 &  341.06 &  27.69 &  0.97\$\textbackslashpm\$0.17 &     0.13 &  3.26 \\
#               IC\_4931 &  17.23\$\textbackslashpm\$0.34 &  14.1\$\textbackslashpm\$0.14 &  19.39 &    1.92 & -29.46 &  0.85\$\textbackslashpm\$0.17 &     0.13 &  4.18 \\
#               NGC7213 &  17.23\$\textbackslashpm\$0.37 &  12.8\$\textbackslashpm\$0.12 &   4.93 &  349.57 & -52.62 &  1.00\$\textbackslashpm\$0.17 &     0.13 &  2.97 \\
#               NGC0676 &  17.22\$\textbackslashpm\$0.37 &  12.6\$\textbackslashpm\$0.12 &   4.17 &  147.95 & -54.10 &  1.01\$\textbackslashpm\$0.17 &     0.13 &  2.80 \\
#      19574910-3148380 &  17.22\$\textbackslashpm\$0.34 &  14.1\$\textbackslashpm\$0.14 &  19.19 &    9.18 & -27.15 &  0.86\$\textbackslashpm\$0.17 &     0.13 &  4.18 \\
#                Cancer &  17.21\$\textbackslashpm\$0.34 &  14.0\$\textbackslashpm\$0.14 &  17.01 &  202.53 &  28.61 &  0.87\$\textbackslashpm\$0.17 &     0.13 &  4.14 \\
#              NGC\_1060 &  17.21\$\textbackslashpm\$0.37 &  13.9\$\textbackslashpm\$0.13 &  15.97 &  148.77 & -24.78 &  0.88\$\textbackslashpm\$0.17 &     0.13 &  4.02 \\
#        ESO\_511-\_G\_023 &  17.21\$\textbackslashpm\$0.34 &  14.3\$\textbackslashpm\$0.14 &  24.14 &  325.67 &  31.62 &  0.83\$\textbackslashpm\$0.17 &     0.13 &  4.28 \\
#               NGC1461 &  17.20\$\textbackslashpm\$0.36 &  12.0\$\textbackslashpm\$0.12 &   2.30 &  207.62 & -47.82 &  1.07\$\textbackslashpm\$0.17 &     0.13 &  2.51 \\
#               NGC3115 &  17.19\$\textbackslashpm\$0.36 &  12.1\$\textbackslashpm\$0.12 &   2.39 &  247.76 &  36.79 &  1.07\$\textbackslashpm\$0.17 &     0.13 &  2.52 \\
#               NGC5253 &  17.19\$\textbackslashpm\$0.36 &  11.0\$\textbackslashpm\$0.11 &   0.80 &  314.86 &  30.11 &  1.15\$\textbackslashpm\$0.17 &     0.14 &  1.94 \\
#                IC5267 &  17.18\$\textbackslashpm\$0.37 &  12.7\$\textbackslashpm\$0.12 &   4.75 &  350.57 & -61.80 &  1.01\$\textbackslashpm\$0.17 &     0.13 &  2.88 \\
#               NGC0772 &  17.18\$\textbackslashpm\$0.35 &  13.1\$\textbackslashpm\$0.13 &   7.45 &  144.39 & -41.02 &  0.96\$\textbackslashpm\$0.17 &     0.12 &  3.28 \\
#       g0346273-035808 &  17.18\$\textbackslashpm\$0.36 &  13.7\$\textbackslashpm\$0.13 &  13.16 &  191.78 & -42.29 &  0.90\$\textbackslashpm\$0.17 &     0.12 &  3.68 \\
#               NGC4125 &  17.18\$\textbackslashpm\$0.37 &  12.8\$\textbackslashpm\$0.12 &   5.31 &  130.25 &  51.38 &  1.00\$\textbackslashpm\$0.17 &     0.12 &  2.99 \\
#              NGC\_6876 &  17.18\$\textbackslashpm\$0.36 &  13.7\$\textbackslashpm\$0.13 &  13.54 &  324.13 & -32.60 &  0.90\$\textbackslashpm\$0.17 &     0.12 &  3.71 \\
#               NGC3877 &  17.18\$\textbackslashpm\$0.36 &  12.5\$\textbackslashpm\$0.12 &   3.81 &  148.99 &  65.82 &  1.03\$\textbackslashpm\$0.17 &     0.13 &  2.70 \\
#               NGC7727 &  17.17\$\textbackslashpm\$0.37 &  12.9\$\textbackslashpm\$0.12 &   6.03 &   70.19 & -67.74 &  0.99\$\textbackslashpm\$0.17 &     0.12 &  3.15 \\
#               NGC2768 &  17.17\$\textbackslashpm\$0.37 &  12.8\$\textbackslashpm\$0.12 &   5.24 &  155.51 &  40.37 &  1.00\$\textbackslashpm\$0.17 &     0.12 &  2.97 \\
#      11524261+2037527 &  17.17\$\textbackslashpm\$0.34 &  14.2\$\textbackslashpm\$0.14 &  24.05 &  235.63 &  75.10 &  0.83\$\textbackslashpm\$0.17 &     0.12 &  4.25 \\
#               NGC3147 &  17.17\$\textbackslashpm\$0.35 &  13.3\$\textbackslashpm\$0.13 &   9.25 &  136.09 &  39.41 &  0.94\$\textbackslashpm\$0.17 &     0.12 &  3.37 \\
#      08154484+5819156 &  17.16\$\textbackslashpm\$0.34 &  14.4\$\textbackslashpm\$0.14 &  27.68 &  159.06 &  33.79 &  0.82\$\textbackslashpm\$0.18 &     0.12 &  4.33 \\
#              NGC\_0194 &  17.16\$\textbackslashpm\$0.37 &  13.8\$\textbackslashpm\$0.13 &  16.09 &  116.92 & -59.69 &  0.88\$\textbackslashpm\$0.17 &     0.12 &  3.93 \\
#      09160392+1737421 &  17.15\$\textbackslashpm\$0.34 &  14.4\$\textbackslashpm\$0.14 &  29.70 &  211.95 &  39.68 &  0.81\$\textbackslashpm\$0.18 &     0.12 &  4.37 \\
#              UGC07577 &  17.15\$\textbackslashpm\$0.37 &  10.7\$\textbackslashpm\$0.10 &   0.59 &  137.47 &  72.84 &  1.17\$\textbackslashpm\$0.17 &     0.15 &  1.71 \\
#               VirgoWp &  17.15\$\textbackslashpm\$0.37 &  12.7\$\textbackslashpm\$0.12 &   5.08 &  283.01 &  70.06 &  1.00\$\textbackslashpm\$0.17 &     0.12 &  2.91 \\
#               NGC0908 &  17.14\$\textbackslashpm\$0.37 &  12.7\$\textbackslashpm\$0.12 &   4.86 &  201.96 & -68.31 &  1.01\$\textbackslashpm\$0.17 &     0.12 &  2.85 \\
#                  7S21 &  17.14\$\textbackslashpm\$0.37 &  13.9\$\textbackslashpm\$0.13 &  18.36 &  113.79 & -39.98 &  0.87\$\textbackslashpm\$0.17 &     0.12 &  4.12 \\
#               NGC1398 &  17.14\$\textbackslashpm\$0.35 &  13.0\$\textbackslashpm\$0.13 &   6.70 &  221.56 & -52.78 &  0.98\$\textbackslashpm\$0.17 &     0.12 &  3.23 \\
#             0016+2947 &  17.14\$\textbackslashpm\$0.34 &  14.1\$\textbackslashpm\$0.14 &  22.05 &  114.47 & -32.25 &  0.85\$\textbackslashpm\$0.17 &     0.12 &  4.19 \\
#               NGC1672 &  17.13\$\textbackslashpm\$0.36 &  12.3\$\textbackslashpm\$0.12 &   3.18 &  268.81 & -38.99 &  1.05\$\textbackslashpm\$0.17 &     0.12 &  2.58 \\
#               NGC1201 &  17.13\$\textbackslashpm\$0.36 &  12.5\$\textbackslashpm\$0.12 &   3.97 &  218.52 & -60.40 &  1.03\$\textbackslashpm\$0.17 &     0.12 &  2.69 \\
#               IC5250A &  17.12\$\textbackslashpm\$0.35 &  13.4\$\textbackslashpm\$0.13 &  10.36 &  321.45 & -47.40 &  0.93\$\textbackslashpm\$0.17 &     0.12 &  3.41 \\
#               Zw180-6 &  17.12\$\textbackslashpm\$0.34 &  14.2\$\textbackslashpm\$0.14 &  23.52 &  191.09 &  44.39 &  0.84\$\textbackslashpm\$0.17 &     0.12 &  4.21 \\
#               NGC2775 &  17.11\$\textbackslashpm\$0.36 &  12.6\$\textbackslashpm\$0.12 &   4.37 &  223.26 &  33.99 &  1.02\$\textbackslashpm\$0.17 &     0.12 &  2.74 \\
#               NGC5719 &  17.11\$\textbackslashpm\$0.37 &  12.8\$\textbackslashpm\$0.12 &   5.87 &  351.72 &  51.75 &  0.99\$\textbackslashpm\$0.17 &     0.11 &  3.02 \\
#               NGC5746 &  17.11\$\textbackslashpm\$0.35 &  13.0\$\textbackslashpm\$0.13 &   6.95 &  354.87 &  52.95 &  0.98\$\textbackslashpm\$0.17 &     0.11 &  3.23 \\
#               NGC3607 &  17.11\$\textbackslashpm\$0.37 &  12.7\$\textbackslashpm\$0.12 &   5.03 &  230.66 &  66.59 &  1.01\$\textbackslashpm\$0.17 &     0.12 &  2.85 \\
#               NGC3941 &  17.11\$\textbackslashpm\$0.36 &  12.1\$\textbackslashpm\$0.12 &   2.81 &  170.66 &  74.18 &  1.06\$\textbackslashpm\$0.17 &     0.12 &  2.53 \\
#       g1325440-295001 &  17.10\$\textbackslashpm\$0.36 &  13.7\$\textbackslashpm\$0.13 &  14.96 &  311.75 &  32.45 &  0.90\$\textbackslashpm\$0.17 &     0.11 &  3.73 \\
#               NGC3585 &  17.10\$\textbackslashpm\$0.36 &  12.6\$\textbackslashpm\$0.12 &   4.53 &  277.26 &  31.15 &  1.02\$\textbackslashpm\$0.17 &     0.12 &  2.75 \\
#               NGC2841 &  17.10\$\textbackslashpm\$0.36 &  12.3\$\textbackslashpm\$0.12 &   3.31 &  166.94 &  44.15 &  1.05\$\textbackslashpm\$0.17 &     0.12 &  2.58 \\
#               Zw74-23 &  17.10\$\textbackslashpm\$0.34 &  14.1\$\textbackslashpm\$0.14 &  22.11 &  349.74 &  65.50 &  0.85\$\textbackslashpm\$0.17 &     0.11 &  4.18 \\
#              NGC\_0533 &  17.09\$\textbackslashpm\$0.36 &  13.8\$\textbackslashpm\$0.13 &  16.92 &  140.15 & -59.97 &  0.88\$\textbackslashpm\$0.17 &     0.11 &  3.89 \\
#               NGC6925 &  17.09\$\textbackslashpm\$0.38 &  12.9\$\textbackslashpm\$0.12 &   6.79 &   11.27 & -34.69 &  0.98\$\textbackslashpm\$0.17 &     0.11 &  3.20 \\
#               NGC4559 &  17.09\$\textbackslashpm\$0.37 &  11.7\$\textbackslashpm\$0.11 &   1.91 &  198.42 &  86.47 &  1.09\$\textbackslashpm\$0.17 &     0.12 &  2.25 \\
#               NGC1964 &  17.09\$\textbackslashpm\$0.36 &  12.6\$\textbackslashpm\$0.12 &   4.58 &  225.78 & -26.63 &  1.02\$\textbackslashpm\$0.17 &     0.11 &  2.76 \\
#               NGC5248 &  17.09\$\textbackslashpm\$0.36 &  12.3\$\textbackslashpm\$0.12 &   3.37 &  335.90 &  68.75 &  1.05\$\textbackslashpm\$0.17 &     0.12 &  2.58 \\
#      12042706+0153455 &  17.09\$\textbackslashpm\$0.34 &  14.0\$\textbackslashpm\$0.14 &  21.28 &  276.91 &  62.37 &  0.86\$\textbackslashpm\$0.17 &     0.11 &  4.16 \\
#               NGC0613 &  17.09\$\textbackslashpm\$0.36 &  12.6\$\textbackslashpm\$0.12 &   4.71 &  229.08 & -80.29 &  1.02\$\textbackslashpm\$0.17 &     0.11 &  2.77 \\
#             PGC009140 &  17.08\$\textbackslashpm\$0.37 &  10.1\$\textbackslashpm\$0.10 &   0.33 &  294.24 & -42.00 &  1.21\$\textbackslashpm\$0.17 &     0.15 &  1.52 \\
#               NGC3998 &  17.08\$\textbackslashpm\$0.36 &  12.5\$\textbackslashpm\$0.12 &   4.35 &  138.43 &  60.11 &  1.02\$\textbackslashpm\$0.17 &     0.11 &  2.71 \\
#               NGC4970 &  17.07\$\textbackslashpm\$0.35 &  13.2\$\textbackslashpm\$0.13 &   8.69 &  307.80 &  38.93 &  0.96\$\textbackslashpm\$0.17 &     0.11 &  3.29 \\
#               NGC2683 &  17.07\$\textbackslashpm\$0.37 &  11.8\$\textbackslashpm\$0.11 &   2.06 &  190.46 &  38.76 &  1.09\$\textbackslashpm\$0.17 &     0.12 &  2.29 \\
#               NGC7144 &  17.07\$\textbackslashpm\$0.37 &  12.7\$\textbackslashpm\$0.12 &   5.45 &  349.36 & -49.67 &  1.00\$\textbackslashpm\$0.17 &     0.11 &  2.88 \\
#               NGC5982 &  17.07\$\textbackslashpm\$0.35 &  13.3\$\textbackslashpm\$0.13 &  10.49 &   93.08 &  46.89 &  0.94\$\textbackslashpm\$0.17 &     0.11 &  3.37 \\
#              NGC\_5223 &  17.07\$\textbackslashpm\$0.34 &  14.2\$\textbackslashpm\$0.14 &  25.77 &   74.96 &  78.09 &  0.84\$\textbackslashpm\$0.17 &     0.11 &  4.22 \\
#       g0452312-030622 &  17.07\$\textbackslashpm\$0.36 &  13.7\$\textbackslashpm\$0.13 &  15.05 &  201.36 & -27.74 &  0.90\$\textbackslashpm\$0.17 &     0.11 &  3.68 \\
#               NGC3718 &  17.06\$\textbackslashpm\$0.36 &  12.6\$\textbackslashpm\$0.12 &   4.86 &  147.07 &  59.79 &  1.02\$\textbackslashpm\$0.17 &     0.11 &  2.77 \\
#               NGC1433 &  17.06\$\textbackslashpm\$0.36 &  12.0\$\textbackslashpm\$0.12 &   2.70 &  255.69 & -51.19 &  1.07\$\textbackslashpm\$0.17 &     0.11 &  2.51 \\
#             UGC\_03353 &  17.06\$\textbackslashpm\$0.36 &  13.6\$\textbackslashpm\$0.13 &  14.17 &  133.84 &  24.04 &  0.91\$\textbackslashpm\$0.17 &     0.11 &  3.60 \\
#               NGC0625 &  17.06\$\textbackslashpm\$0.37 &  10.9\$\textbackslashpm\$0.10 &   0.80 &  273.67 & -73.12 &  1.16\$\textbackslashpm\$0.17 &     0.13 &  1.84 \\
#               NGC2950 &  17.05\$\textbackslashpm\$0.36 &  12.3\$\textbackslashpm\$0.12 &   3.47 &  155.19 &  44.67 &  1.05\$\textbackslashpm\$0.17 &     0.11 &  2.58 \\
#            ESO380-006 &  17.05\$\textbackslashpm\$0.35 &  13.0\$\textbackslashpm\$0.13 &   7.84 &  294.70 &  26.80 &  0.97\$\textbackslashpm\$0.17 &     0.11 &  3.25 \\
#               NGC5557 &  17.05\$\textbackslashpm\$0.35 &  13.3\$\textbackslashpm\$0.13 &  10.64 &   65.36 &  69.59 &  0.94\$\textbackslashpm\$0.17 &     0.11 &  3.37 \\
#       g0044591-562248 &  17.04\$\textbackslashpm\$0.34 &  14.2\$\textbackslashpm\$0.14 &  27.55 &  304.76 & -60.73 &  0.83\$\textbackslashpm\$0.17 &     0.11 &  4.24 \\
#        MCG\_-02-28-045 &  17.04\$\textbackslashpm\$0.34 &  14.3\$\textbackslashpm\$0.14 &  28.28 &  264.63 &  44.94 &  0.83\$\textbackslashpm\$0.17 &     0.11 &  4.25 \\
#                   J33 &  17.04\$\textbackslashpm\$0.34 &  14.3\$\textbackslashpm\$0.14 &  29.49 &  195.18 & -58.31 &  0.83\$\textbackslashpm\$0.17 &     0.11 &  4.27 \\
#                 MKW11 &  17.04\$\textbackslashpm\$0.34 &  14.1\$\textbackslashpm\$0.14 &  23.97 &  333.75 &  71.57 &  0.85\$\textbackslashpm\$0.17 &     0.10 &  4.18 \\
#              NGC\_0777 &  17.03\$\textbackslashpm\$0.36 &  13.7\$\textbackslashpm\$0.13 &  16.64 &  139.73 & -29.19 &  0.89\$\textbackslashpm\$0.17 &     0.10 &  3.76 \\
#              NGC\_1550 &  17.03\$\textbackslashpm\$0.36 &  13.4\$\textbackslashpm\$0.13 &  12.03 &  190.98 & -31.85 &  0.93\$\textbackslashpm\$0.17 &     0.10 &  3.43 \\
#      10135051+3845536 &  17.02\$\textbackslashpm\$0.34 &  14.1\$\textbackslashpm\$0.14 &  23.97 &  183.21 &  55.26 &  0.85\$\textbackslashpm\$0.17 &     0.10 &  4.17 \\
#               NGC4244 &  17.02\$\textbackslashpm\$0.36 &  11.1\$\textbackslashpm\$0.11 &   1.08 &  154.49 &  77.26 &  1.14\$\textbackslashpm\$0.17 &     0.12 &  1.96 \\
#                IC2035 &  17.02\$\textbackslashpm\$0.37 &  11.8\$\textbackslashpm\$0.11 &   2.17 &  251.69 & -46.98 &  1.09\$\textbackslashpm\$0.17 &     0.11 &  2.29 \\
#              NGC\_2256 &  17.02\$\textbackslashpm\$0.36 &  13.8\$\textbackslashpm\$0.13 &  18.18 &  140.48 &  25.75 &  0.89\$\textbackslashpm\$0.17 &     0.10 &  3.86 \\
#              NGC\_0665 &  17.02\$\textbackslashpm\$0.36 &  13.7\$\textbackslashpm\$0.13 &  16.93 &  143.78 & -50.27 &  0.89\$\textbackslashpm\$0.17 &     0.10 &  3.76 \\
#               NGC3166 &  17.02\$\textbackslashpm\$0.36 &  12.6\$\textbackslashpm\$0.12 &   5.21 &  238.19 &  45.56 &  1.01\$\textbackslashpm\$0.17 &     0.11 &  2.79 \\
#               NGC2964 &  17.01\$\textbackslashpm\$0.36 &  12.3\$\textbackslashpm\$0.12 &   3.96 &  194.55 &  49.06 &  1.04\$\textbackslashpm\$0.17 &     0.11 &  2.62 \\
#              NGC\_6332 &  17.01\$\textbackslashpm\$0.34 &  14.2\$\textbackslashpm\$0.14 &  28.20 &   68.93 &  35.29 &  0.84\$\textbackslashpm\$0.17 &     0.10 &  4.23 \\
#                IC4633 &  17.01\$\textbackslashpm\$0.37 &  12.9\$\textbackslashpm\$0.12 &   6.88 &  315.21 & -21.51 &  0.99\$\textbackslashpm\$0.17 &     0.10 &  3.07 \\
#               NGC3717 &  17.00\$\textbackslashpm\$0.36 &  12.4\$\textbackslashpm\$0.12 &   4.37 &  283.14 &  29.48 &  1.03\$\textbackslashpm\$0.17 &     0.10 &  2.66 \\
#              NGC\_1208 &  17.00\$\textbackslashpm\$0.36 &  13.6\$\textbackslashpm\$0.13 &  14.75 &  190.43 & -53.69 &  0.91\$\textbackslashpm\$0.17 &     0.10 &  3.57 \\
#               NGC2986 &  17.00\$\textbackslashpm\$0.37 &  12.9\$\textbackslashpm\$0.12 &   7.01 &  254.88 &  23.84 &  0.99\$\textbackslashpm\$0.17 &     0.10 &  3.08 \\
#                P597-1 &  17.00\$\textbackslashpm\$0.36 &  13.6\$\textbackslashpm\$0.13 &  14.95 &  199.22 & -25.08 &  0.91\$\textbackslashpm\$0.17 &     0.10 &  3.58 \\
#               NGC1559 &  16.99\$\textbackslashpm\$0.36 &  12.0\$\textbackslashpm\$0.12 &   2.75 &  274.52 & -41.19 &  1.07\$\textbackslashpm\$0.17 &     0.10 &  2.50 \\
#               NGC1209 &  16.99\$\textbackslashpm\$0.35 &  13.0\$\textbackslashpm\$0.13 &   7.99 &  199.49 & -56.91 &  0.98\$\textbackslashpm\$0.17 &     0.10 &  3.23 \\
#               NGC4203 &  16.98\$\textbackslashpm\$0.36 &  12.2\$\textbackslashpm\$0.12 &   3.47 &  173.03 &  80.08 &  1.05\$\textbackslashpm\$0.17 &     0.10 &  2.55 \\
#               Zw180-6 &  16.98\$\textbackslashpm\$0.34 &  14.0\$\textbackslashpm\$0.14 &  23.55 &  195.94 &  42.54 &  0.86\$\textbackslashpm\$0.17 &     0.10 &  4.15 \\
#               NGC1448 &  16.98\$\textbackslashpm\$0.36 &  12.3\$\textbackslashpm\$0.12 &   4.01 &  251.26 & -52.00 &  1.04\$\textbackslashpm\$0.17 &     0.10 &  2.60 \\
#              UGC04305 &  16.98\$\textbackslashpm\$0.37 &  10.7\$\textbackslashpm\$0.10 &   0.76 &  144.29 &  32.78 &  1.17\$\textbackslashpm\$0.17 &     0.12 &  1.75 \\
#       g1944023-282402 &  16.98\$\textbackslashpm\$0.36 &  13.8\$\textbackslashpm\$0.13 &  18.87 &   11.74 & -23.27 &  0.89\$\textbackslashpm\$0.17 &     0.10 &  3.85 \\
#       g0113473-314450 &  16.98\$\textbackslashpm\$0.36 &  13.8\$\textbackslashpm\$0.13 &  18.45 &  257.78 & -83.29 &  0.89\$\textbackslashpm\$0.17 &     0.10 &  3.81 \\
#                IC5096 &  16.98\$\textbackslashpm\$0.35 &  13.2\$\textbackslashpm\$0.13 &  10.35 &  330.69 & -39.68 &  0.95\$\textbackslashpm\$0.17 &     0.10 &  3.32 \\
#               NGC6673 &  16.98\$\textbackslashpm\$0.37 &  11.8\$\textbackslashpm\$0.11 &   2.44 &  333.28 & -23.10 &  1.08\$\textbackslashpm\$0.17 &     0.10 &  2.35 \\
#      14302558+1155407 &  16.98\$\textbackslashpm\$0.34 &  14.2\$\textbackslashpm\$0.14 &  27.77 &    4.56 &  62.26 &  0.84\$\textbackslashpm\$0.17 &     0.10 &  4.21 \\
#               NGC1421 &  16.97\$\textbackslashpm\$0.36 &  12.6\$\textbackslashpm\$0.12 &   5.37 &  202.52 & -47.74 &  1.02\$\textbackslashpm\$0.17 &     0.10 &  2.77 \\
#      14180922+0733523 &  16.97\$\textbackslashpm\$0.34 &  14.1\$\textbackslashpm\$0.14 &  26.02 &  353.34 &  61.63 &  0.85\$\textbackslashpm\$0.17 &     0.10 &  4.18 \\
#                IC4889 &  16.97\$\textbackslashpm\$0.37 &  12.7\$\textbackslashpm\$0.12 &   6.13 &  343.53 & -29.42 &  1.00\$\textbackslashpm\$0.17 &     0.10 &  2.89 \\
#              UGC03816 &  16.97\$\textbackslashpm\$0.37 &  12.9\$\textbackslashpm\$0.12 &   7.21 &  158.92 &  26.92 &  0.99\$\textbackslashpm\$0.17 &     0.10 &  3.07 \\
#               NGC4593 &  16.97\$\textbackslashpm\$0.35 &  13.0\$\textbackslashpm\$0.13 &   8.36 &  297.69 &  57.52 &  0.98\$\textbackslashpm\$0.17 &     0.10 &  3.24 \\
#               NGC3184 &  16.97\$\textbackslashpm\$0.37 &  11.7\$\textbackslashpm\$0.11 &   2.02 &  178.34 &  55.64 &  1.10\$\textbackslashpm\$0.17 &     0.11 &  2.18 \\
#               NGC6501 &  16.97\$\textbackslashpm\$0.35 &  13.1\$\textbackslashpm\$0.13 &   9.18 &   43.74 &  20.34 &  0.97\$\textbackslashpm\$0.17 &     0.10 &  3.26 \\
#               NGC7332 &  16.96\$\textbackslashpm\$0.36 &  12.5\$\textbackslashpm\$0.12 &   5.13 &   87.42 & -29.69 &  1.02\$\textbackslashpm\$0.17 &     0.10 &  2.73 \\
#               NGC4856 &  16.96\$\textbackslashpm\$0.36 &  12.3\$\textbackslashpm\$0.12 &   4.11 &  305.81 &  47.78 &  1.04\$\textbackslashpm\$0.17 &     0.10 &  2.61 \\
#               NGC1947 &  16.96\$\textbackslashpm\$0.36 &  12.0\$\textbackslashpm\$0.12 &   2.97 &  273.28 & -33.44 &  1.07\$\textbackslashpm\$0.17 &     0.10 &  2.50 \\
#               IC4837A &  16.96\$\textbackslashpm\$0.35 &  13.0\$\textbackslashpm\$0.13 &   8.79 &  342.87 & -25.08 &  0.97\$\textbackslashpm\$0.17 &     0.10 &  3.25 \\
#                IC4351 &  16.96\$\textbackslashpm\$0.37 &  12.8\$\textbackslashpm\$0.12 &   7.14 &  319.77 &  31.44 &  0.99\$\textbackslashpm\$0.17 &     0.10 &  3.05 \\
#               NGC7083 &  16.96\$\textbackslashpm\$0.35 &  13.1\$\textbackslashpm\$0.13 &   9.75 &  329.10 & -42.06 &  0.96\$\textbackslashpm\$0.17 &     0.10 &  3.28 \\
#              NGC\_1589 &  16.96\$\textbackslashpm\$0.35 &  13.4\$\textbackslashpm\$0.13 &  12.08 &  194.27 & -30.38 &  0.94\$\textbackslashpm\$0.17 &     0.10 &  3.38 \\
#               NGC1512 &  16.95\$\textbackslashpm\$0.38 &  11.9\$\textbackslashpm\$0.11 &   2.78 &  248.31 & -48.70 &  1.08\$\textbackslashpm\$0.17 &     0.10 &  2.46 \\
#               NGC1340 &  16.95\$\textbackslashpm\$0.36 &  12.4\$\textbackslashpm\$0.12 &   4.43 &  229.74 & -55.71 &  1.04\$\textbackslashpm\$0.17 &     0.10 &  2.63 \\
#       g0133577-362936 &  16.95\$\textbackslashpm\$0.34 &  14.2\$\textbackslashpm\$0.14 &  29.51 &  261.66 & -77.01 &  0.84\$\textbackslashpm\$0.17 &     0.10 &  4.22 \\
#                Mcloud &  16.95\$\textbackslashpm\$0.37 &  12.9\$\textbackslashpm\$0.12 &   7.60 &  267.61 &  73.65 &  0.99\$\textbackslashpm\$0.17 &     0.09 &  3.11 \\
#               NGC4684 &  16.94\$\textbackslashpm\$0.36 &  12.0\$\textbackslashpm\$0.12 &   3.16 &  300.84 &  60.14 &  1.07\$\textbackslashpm\$0.17 &     0.10 &  2.51 \\
#               NGC3706 &  16.94\$\textbackslashpm\$0.38 &  12.9\$\textbackslashpm\$0.12 &   8.19 &  285.03 &  23.61 &  0.98\$\textbackslashpm\$0.17 &     0.09 &  3.21 \\
#              UGC09240 &  16.94\$\textbackslashpm\$0.37 &  10.5\$\textbackslashpm\$0.10 &   0.64 &   82.01 &  64.48 &  1.18\$\textbackslashpm\$0.17 &     0.12 &  1.64 \\
#               NGC3091 &  16.94\$\textbackslashpm\$0.36 &  13.4\$\textbackslashpm\$0.13 &  13.59 &  256.69 &  27.46 &  0.93\$\textbackslashpm\$0.17 &     0.09 &  3.44 \\
#               NGC7541 &  16.94\$\textbackslashpm\$0.37 &  12.9\$\textbackslashpm\$0.12 &   7.48 &   82.83 & -50.66 &  0.99\$\textbackslashpm\$0.17 &     0.09 &  3.07 \\
#              NGC\_1218 &  16.93\$\textbackslashpm\$0.34 &  14.1\$\textbackslashpm\$0.14 &  28.62 &  174.86 & -44.51 &  0.84\$\textbackslashpm\$0.17 &     0.09 &  4.20 \\
#               NGC7457 &  16.93\$\textbackslashpm\$0.38 &  11.9\$\textbackslashpm\$0.11 &   2.74 &   96.22 & -26.93 &  1.08\$\textbackslashpm\$0.17 &     0.10 &  2.42 \\
#              NGC\_1239 &  16.93\$\textbackslashpm\$0.34 &  14.1\$\textbackslashpm\$0.14 &  27.90 &  182.60 & -48.58 &  0.85\$\textbackslashpm\$0.17 &     0.09 &  4.19 \\
#               NGC7184 &  16.93\$\textbackslashpm\$0.37 &  12.9\$\textbackslashpm\$0.12 &   8.10 &   32.89 & -51.11 &  0.98\$\textbackslashpm\$0.17 &     0.09 &  3.17 \\
#               NGC0672 &  16.92\$\textbackslashpm\$0.37 &  11.4\$\textbackslashpm\$0.11 &   1.69 &  137.99 & -33.84 &  1.12\$\textbackslashpm\$0.17 &     0.10 &  2.06 \\
#               NGC3783 &  16.92\$\textbackslashpm\$0.35 &  13.1\$\textbackslashpm\$0.13 &   9.62 &  287.03 &  22.66 &  0.97\$\textbackslashpm\$0.17 &     0.09 &  3.26 \\
#               NGC0289 &  16.92\$\textbackslashpm\$0.36 &  12.5\$\textbackslashpm\$0.12 &   5.31 &  304.33 & -85.84 &  1.02\$\textbackslashpm\$0.17 &     0.09 &  2.71 \\
#               NGC0821 &  16.91\$\textbackslashpm\$0.36 &  12.5\$\textbackslashpm\$0.12 &   5.28 &  151.56 & -47.56 &  1.02\$\textbackslashpm\$0.17 &     0.09 &  2.71 \\
#        ESO\_576-\_G\_066 &  16.91\$\textbackslashpm\$0.36 &  13.8\$\textbackslashpm\$0.13 &  19.72 &  314.94 &  41.29 &  0.89\$\textbackslashpm\$0.17 &     0.09 &  3.79 \\
#       g1326375-121926 &  16.91\$\textbackslashpm\$0.37 &  13.9\$\textbackslashpm\$0.13 &  23.33 &  316.27 &  49.63 &  0.87\$\textbackslashpm\$0.17 &     0.09 &  4.06 \\
#            ESO512-018 &  16.91\$\textbackslashpm\$0.37 &  12.8\$\textbackslashpm\$0.12 &   7.45 &  333.14 &  31.76 &  0.99\$\textbackslashpm\$0.17 &     0.09 &  3.02 \\
#               NGC7377 &  16.91\$\textbackslashpm\$0.35 &  13.0\$\textbackslashpm\$0.13 &   8.96 &   35.65 & -61.52 &  0.98\$\textbackslashpm\$0.17 &     0.09 &  3.24 \\
#               NGC3300 &  16.90\$\textbackslashpm\$0.36 &  12.6\$\textbackslashpm\$0.12 &   5.64 &  228.71 &  55.87 &  1.02\$\textbackslashpm\$0.17 &     0.09 &  2.75 \\
#              NGC\_6370 &  16.90\$\textbackslashpm\$0.34 &  14.1\$\textbackslashpm\$0.14 &  29.51 &   85.20 &  34.34 &  0.84\$\textbackslashpm\$0.17 &     0.09 &  4.20 \\
#               NGC6438 &  16.90\$\textbackslashpm\$0.37 &  12.8\$\textbackslashpm\$0.12 &   7.62 &  308.03 & -26.46 &  0.99\$\textbackslashpm\$0.17 &     0.09 &  3.05 \\
#              NGC\_0932 &  16.90\$\textbackslashpm\$0.35 &  13.4\$\textbackslashpm\$0.13 &  13.21 &  151.64 & -37.10 &  0.93\$\textbackslashpm\$0.17 &     0.09 &  3.40 \\
#               NGC4605 &  16.90\$\textbackslashpm\$0.36 &  11.1\$\textbackslashpm\$0.11 &   1.26 &  125.33 &  55.47 &  1.14\$\textbackslashpm\$0.17 &     0.10 &  1.96 \\
#              NGC\_5490 &  16.89\$\textbackslashpm\$0.36 &  13.7\$\textbackslashpm\$0.13 &  17.87 &    9.14 &  69.51 &  0.90\$\textbackslashpm\$0.17 &     0.09 &  3.65 \\
#               NGC3686 &  16.89\$\textbackslashpm\$0.36 &  12.1\$\textbackslashpm\$0.12 &   3.47 &  235.93 &  68.13 &  1.06\$\textbackslashpm\$0.17 &     0.09 &  2.52 \\
#              NGC\_1726 &  16.89\$\textbackslashpm\$0.35 &  13.4\$\textbackslashpm\$0.13 &  13.16 &  206.96 & -28.34 &  0.94\$\textbackslashpm\$0.17 &     0.09 &  3.39 \\
#              NGC\_4169 &  16.89\$\textbackslashpm\$0.36 &  13.4\$\textbackslashpm\$0.13 &  14.12 &  197.27 &  81.14 &  0.93\$\textbackslashpm\$0.17 &     0.09 &  3.43 \\
#               NGC1255 &  16.89\$\textbackslashpm\$0.36 &  12.1\$\textbackslashpm\$0.12 &   3.51 &  218.38 & -58.23 &  1.06\$\textbackslashpm\$0.17 &     0.09 &  2.52 \\
#               NGC7205 &  16.89\$\textbackslashpm\$0.36 &  12.3\$\textbackslashpm\$0.12 &   4.31 &  334.82 & -48.36 &  1.04\$\textbackslashpm\$0.17 &     0.09 &  2.59 \\
#              NGC\_3822 &  16.89\$\textbackslashpm\$0.37 &  13.8\$\textbackslashpm\$0.13 &  22.06 &  255.56 &  66.55 &  0.88\$\textbackslashpm\$0.17 &     0.09 &  3.92 \\
#       g1336083-082952 &  16.89\$\textbackslashpm\$0.37 &  13.9\$\textbackslashpm\$0.13 &  23.82 &  321.40 &  52.76 &  0.87\$\textbackslashpm\$0.17 &     0.09 &  4.05 \\
#               NGC2698 &  16.89\$\textbackslashpm\$0.37 &  12.8\$\textbackslashpm\$0.12 &   7.16 &  231.19 &  25.66 &  1.00\$\textbackslashpm\$0.17 &     0.09 &  2.95 \\
#               NGC5792 &  16.89\$\textbackslashpm\$0.36 &  12.6\$\textbackslashpm\$0.12 &   5.88 &  355.33 &  48.43 &  1.02\$\textbackslashpm\$0.17 &     0.09 &  2.76 \\
#      20405650-2028130 &  16.88\$\textbackslashpm\$0.34 &  14.0\$\textbackslashpm\$0.14 &  27.37 &   25.07 & -32.88 &  0.86\$\textbackslashpm\$0.17 &     0.09 &  4.16 \\
#               NGC0720 &  16.88\$\textbackslashpm\$0.36 &  12.6\$\textbackslashpm\$0.12 &   5.91 &  173.11 & -70.38 &  1.02\$\textbackslashpm\$0.17 &     0.09 &  2.77 \\
#       g1928170-293144 &  16.88\$\textbackslashpm\$0.37 &  13.9\$\textbackslashpm\$0.13 &  24.12 &    9.34 & -20.41 &  0.87\$\textbackslashpm\$0.17 &     0.09 &  4.06 \\
#              NGC\_0434 &  16.88\$\textbackslashpm\$0.36 &  13.6\$\textbackslashpm\$0.13 &  16.52 &  297.67 & -58.67 &  0.91\$\textbackslashpm\$0.17 &     0.09 &  3.55 \\
#               NGC3672 &  16.88\$\textbackslashpm\$0.36 &  12.6\$\textbackslashpm\$0.12 &   5.95 &  269.93 &  47.14 &  1.02\$\textbackslashpm\$0.17 &     0.09 &  2.77 \\
#              NGC\_1723 &  16.88\$\textbackslashpm\$0.35 &  13.3\$\textbackslashpm\$0.13 &  13.03 &  210.25 & -29.80 &  0.94\$\textbackslashpm\$0.17 &     0.09 &  3.38 \\
#        MCG\_-01-29-015 &  16.88\$\textbackslashpm\$0.37 &  13.9\$\textbackslashpm\$0.13 &  25.02 &  268.09 &  49.10 &  0.87\$\textbackslashpm\$0.17 &     0.09 &  4.13 \\
#       g2013532-443136 &  16.88\$\textbackslashpm\$0.36 &  13.7\$\textbackslashpm\$0.13 &  18.47 &  355.56 & -32.90 &  0.90\$\textbackslashpm\$0.17 &     0.09 &  3.66 \\
#             UGC\_10693 &  16.88\$\textbackslashpm\$0.34 &  14.1\$\textbackslashpm\$0.14 &  28.16 &   66.50 &  36.98 &  0.85\$\textbackslashpm\$0.17 &     0.09 &  4.17 \\
#               NGC7007 &  16.88\$\textbackslashpm\$0.36 &  12.5\$\textbackslashpm\$0.12 &   5.21 &  345.42 & -41.36 &  1.03\$\textbackslashpm\$0.17 &     0.09 &  2.68 \\
#               NGC6412 &  16.87\$\textbackslashpm\$0.37 &  11.7\$\textbackslashpm\$0.11 &   2.29 &  107.25 &  31.27 &  1.10\$\textbackslashpm\$0.17 &     0.10 &  2.19 \\
#               NGC1232 &  16.87\$\textbackslashpm\$0.36 &  12.4\$\textbackslashpm\$0.12 &   5.11 &  208.79 & -57.80 &  1.03\$\textbackslashpm\$0.17 &     0.09 &  2.66 \\
#               NGC2633 &  16.87\$\textbackslashpm\$0.37 &  12.6\$\textbackslashpm\$0.12 &   6.34 &  139.81 &  33.93 &  1.01\$\textbackslashpm\$0.17 &     0.09 &  2.81 \\
#              NGC\_5444 &  16.87\$\textbackslashpm\$0.35 &  13.4\$\textbackslashpm\$0.13 &  13.62 &   64.87 &  72.68 &  0.93\$\textbackslashpm\$0.17 &     0.09 &  3.39 \\
#               NGC3245 &  16.86\$\textbackslashpm\$0.36 &  12.5\$\textbackslashpm\$0.12 &   5.67 &  201.42 &  58.62 &  1.02\$\textbackslashpm\$0.17 &     0.09 &  2.72 \\
#                   J25 &  16.86\$\textbackslashpm\$0.34 &  14.0\$\textbackslashpm\$0.14 &  27.58 &   91.82 &  30.22 &  0.86\$\textbackslashpm\$0.17 &     0.09 &  4.16 \\
#          VV\_820\_NED02 &  16.86\$\textbackslashpm\$0.37 &  13.9\$\textbackslashpm\$0.13 &  24.03 &   15.74 &  25.01 &  0.87\$\textbackslashpm\$0.17 &     0.09 &  4.02 \\
#              NGC\_2513 &  16.86\$\textbackslashpm\$0.36 &  13.5\$\textbackslashpm\$0.13 &  15.76 &  212.42 &  20.01 &  0.92\$\textbackslashpm\$0.17 &     0.09 &  3.49 \\
#               NGC7079 &  16.86\$\textbackslashpm\$0.36 &  12.5\$\textbackslashpm\$0.12 &   5.77 &  356.31 & -46.96 &  1.02\$\textbackslashpm\$0.17 &     0.09 &  2.73 \\
#               NGC4179 &  16.86\$\textbackslashpm\$0.36 &  12.1\$\textbackslashpm\$0.12 &   3.68 &  281.48 &  62.62 &  1.06\$\textbackslashpm\$0.17 &     0.09 &  2.53 \\
#               NGC4915 &  16.85\$\textbackslashpm\$0.37 &  12.7\$\textbackslashpm\$0.12 &   6.88 &  307.62 &  58.24 &  1.01\$\textbackslashpm\$0.17 &     0.09 &  2.86 \\
#              NGC\_0432 &  16.85\$\textbackslashpm\$0.34 &  14.0\$\textbackslashpm\$0.14 &  27.66 &  298.66 & -55.43 &  0.86\$\textbackslashpm\$0.17 &     0.08 &  4.15 \\
#              NGC\_3022 &  16.85\$\textbackslashpm\$0.36 &  13.8\$\textbackslashpm\$0.13 &  22.26 &  242.26 &  35.51 &  0.88\$\textbackslashpm\$0.17 &     0.08 &  3.86 \\
#               IC\_0357 &  16.85\$\textbackslashpm\$0.36 &  13.8\$\textbackslashpm\$0.13 &  20.92 &  171.05 & -22.26 &  0.89\$\textbackslashpm\$0.17 &     0.08 &  3.77 \\
#       g1403357-252541 &  16.85\$\textbackslashpm\$0.37 &  13.8\$\textbackslashpm\$0.13 &  23.04 &  322.81 &  34.64 &  0.88\$\textbackslashpm\$0.17 &     0.08 &  3.92 \\
#               IC\_1867 &  16.85\$\textbackslashpm\$0.37 &  13.9\$\textbackslashpm\$0.13 &  25.82 &  166.86 & -42.70 &  0.87\$\textbackslashpm\$0.17 &     0.08 &  4.12 \\
#      16251690-0910520 &  16.85\$\textbackslashpm\$0.34 &  14.0\$\textbackslashpm\$0.14 &  28.72 &    5.60 &  26.76 &  0.86\$\textbackslashpm\$0.17 &     0.08 &  4.16 \\
#               NGC5916 &  16.85\$\textbackslashpm\$0.36 &  12.3\$\textbackslashpm\$0.12 &   4.39 &  349.88 &  35.72 &  1.05\$\textbackslashpm\$0.17 &     0.09 &  2.58 \\
#       g0058016-050416 &  16.84\$\textbackslashpm\$0.36 &  13.6\$\textbackslashpm\$0.13 &  17.09 &  127.29 & -67.89 &  0.91\$\textbackslashpm\$0.17 &     0.08 &  3.54 \\
#       g0456563-045157 &  16.84\$\textbackslashpm\$0.35 &  13.3\$\textbackslashpm\$0.13 &  13.19 &  203.70 & -27.61 &  0.94\$\textbackslashpm\$0.17 &     0.08 &  3.36 \\
#       g2018233-410301 &  16.84\$\textbackslashpm\$0.36 &  13.6\$\textbackslashpm\$0.13 &  17.54 &  359.81 & -33.23 &  0.91\$\textbackslashpm\$0.17 &     0.08 &  3.56 \\
# ...
#              NGC\_0266 &  16.67\$\textbackslashpm\$0.35 &  13.2\$\textbackslashpm\$0.13 &  14.74 &  122.53 & -30.59 &  0.95\$\textbackslashpm\$0.17 &     0.07 &  3.31 \\
#             PGC045146 &  16.67\$\textbackslashpm\$0.37 &  12.9\$\textbackslashpm\$0.12 &  10.53 &  307.82 &  51.25 &  0.99\$\textbackslashpm\$0.17 &     0.07 &  3.12 \\
#             PGC025886 &  16.67\$\textbackslashpm\$0.36 &  12.5\$\textbackslashpm\$0.12 &   6.85 &  238.90 &  25.59 &  1.03\$\textbackslashpm\$0.17 &     0.07 &  2.69 \\
#               NGC6181 &  16.66\$\textbackslashpm\$0.36 &  12.6\$\textbackslashpm\$0.12 &   7.51 &   37.22 &  39.24 &  1.02\$\textbackslashpm\$0.17 &     0.07 &  2.76 \\
#               NGC7097 &  16.66\$\textbackslashpm\$0.36 &  12.5\$\textbackslashpm\$0.12 &   7.28 &  358.34 & -48.44 &  1.02\$\textbackslashpm\$0.17 &     0.07 &  2.73 \\
#              NGC\_0765 &  16.66\$\textbackslashpm\$0.35 &  13.3\$\textbackslashpm\$0.13 &  15.97 &  141.77 & -35.50 &  0.94\$\textbackslashpm\$0.17 &     0.07 &  3.35 \\
#              NGC\_0841 &  16.66\$\textbackslashpm\$0.35 &  13.2\$\textbackslashpm\$0.13 &  14.41 &  140.01 & -22.71 &  0.95\$\textbackslashpm\$0.17 &     0.07 &  3.30 \\
#              NGC\_2523 &  16.66\$\textbackslashpm\$0.35 &  13.0\$\textbackslashpm\$0.13 &  12.31 &  141.04 &  31.81 &  0.97\$\textbackslashpm\$0.17 &     0.07 &  3.25 \\
#             UGC\_02252 &  16.66\$\textbackslashpm\$0.36 &  13.7\$\textbackslashpm\$0.13 &  24.60 &  159.79 & -39.04 &  0.90\$\textbackslashpm\$0.17 &     0.07 &  3.69 \\
#              NGC\_2446 &  16.66\$\textbackslashpm\$0.36 &  13.5\$\textbackslashpm\$0.13 &  19.96 &  163.29 &  29.94 &  0.92\$\textbackslashpm\$0.17 &     0.07 &  3.49 \\
#              UGC08651 &  16.66\$\textbackslashpm\$0.37 &  10.3\$\textbackslashpm\$0.10 &   0.71 &   89.73 &  73.12 &  1.20\$\textbackslashpm\$0.17 &     0.09 &  1.57 \\
#       g1550438-073338 &  16.66\$\textbackslashpm\$0.36 &  13.8\$\textbackslashpm\$0.13 &  27.48 &    0.87 &  34.46 &  0.88\$\textbackslashpm\$0.17 &     0.07 &  3.84 \\
#               NGC2681 &  16.66\$\textbackslashpm\$0.38 &  11.9\$\textbackslashpm\$0.11 &   3.74 &  167.33 &  39.68 &  1.08\$\textbackslashpm\$0.17 &     0.07 &  2.41 \\
#              NGC\_0128 &  16.65\$\textbackslashpm\$0.35 &  13.1\$\textbackslashpm\$0.13 &  13.07 &  111.96 & -59.53 &  0.97\$\textbackslashpm\$0.17 &     0.07 &  3.26 \\
#               NGC0059 &  16.65\$\textbackslashpm\$0.37 &  10.7\$\textbackslashpm\$0.10 &   1.11 &   65.71 & -80.02 &  1.17\$\textbackslashpm\$0.17 &     0.08 &  1.75 \\
#               NGC6920 &  16.65\$\textbackslashpm\$0.37 &  12.7\$\textbackslashpm\$0.12 &   8.68 &  313.27 & -31.46 &  1.01\$\textbackslashpm\$0.17 &     0.07 &  2.87 \\
#        ESO\_575-\_G\_043 &  16.65\$\textbackslashpm\$0.36 &  13.7\$\textbackslashpm\$0.13 &  24.72 &  305.47 &  40.66 &  0.90\$\textbackslashpm\$0.17 &     0.07 &  3.69 \\
#               NGC5665 &  16.65\$\textbackslashpm\$0.38 &  11.9\$\textbackslashpm\$0.11 &   4.00 &  359.08 &  59.44 &  1.08\$\textbackslashpm\$0.17 &     0.07 &  2.48 \\
#              NGC\_4914 &  16.65\$\textbackslashpm\$0.35 &  13.3\$\textbackslashpm\$0.13 &  16.55 &  112.63 &  79.63 &  0.94\$\textbackslashpm\$0.17 &     0.07 &  3.36 \\
#              NGC\_1328 &  16.65\$\textbackslashpm\$0.36 &  13.5\$\textbackslashpm\$0.13 &  19.55 &  187.80 & -46.63 &  0.92\$\textbackslashpm\$0.17 &     0.07 &  3.46 \\
#             PGC045084 &  16.64\$\textbackslashpm\$0.38 &  10.9\$\textbackslashpm\$0.10 &   1.40 &  306.84 &  45.43 &  1.15\$\textbackslashpm\$0.17 &     0.08 &  1.92 \\
#               NGC4800 &  16.64\$\textbackslashpm\$0.37 &  11.8\$\textbackslashpm\$0.11 &   3.26 &  121.28 &  70.59 &  1.09\$\textbackslashpm\$0.17 &     0.07 &  2.26 \\
#               NGC3922 &  16.64\$\textbackslashpm\$0.37 &  11.4\$\textbackslashpm\$0.11 &   2.23 &  145.69 &  64.29 &  1.12\$\textbackslashpm\$0.17 &     0.07 &  2.04 \\
#             UGC\_04122 &  16.64\$\textbackslashpm\$0.36 &  13.5\$\textbackslashpm\$0.13 &  20.25 &  158.15 &  31.61 &  0.92\$\textbackslashpm\$0.17 &     0.07 &  3.48 \\
#               NGC4750 &  16.64\$\textbackslashpm\$0.36 &  12.4\$\textbackslashpm\$0.12 &   6.51 &  123.04 &  44.24 &  1.03\$\textbackslashpm\$0.17 &     0.07 &  2.65 \\
#               NGC3175 &  16.64\$\textbackslashpm\$0.37 &  11.9\$\textbackslashpm\$0.11 &   3.72 &  265.96 &  22.42 &  1.08\$\textbackslashpm\$0.17 &     0.07 &  2.38 \\
#       g0125285-381603 &  16.64\$\textbackslashpm\$0.36 &  13.5\$\textbackslashpm\$0.13 &  19.94 &  272.42 & -76.77 &  0.92\$\textbackslashpm\$0.17 &     0.07 &  3.47 \\
#             UGC\_10778 &  16.64\$\textbackslashpm\$0.36 &  13.6\$\textbackslashpm\$0.13 &  22.79 &   27.85 &  24.10 &  0.91\$\textbackslashpm\$0.17 &     0.07 &  3.59 \\
#               NGC1888 &  16.64\$\textbackslashpm\$0.37 &  12.7\$\textbackslashpm\$0.12 &   8.70 &  213.47 & -24.88 &  1.01\$\textbackslashpm\$0.17 &     0.07 &  2.85 \\
#               NGC6278 &  16.63\$\textbackslashpm\$0.37 &  12.7\$\textbackslashpm\$0.12 &   8.68 &   43.53 &  34.05 &  1.01\$\textbackslashpm\$0.17 &     0.07 &  2.85 \\
#               NGC2537 &  16.63\$\textbackslashpm\$0.36 &  11.1\$\textbackslashpm\$0.11 &   1.59 &  173.81 &  32.96 &  1.15\$\textbackslashpm\$0.17 &     0.08 &  1.94 \\
#       g0042368-013144 &  16.63\$\textbackslashpm\$0.35 &  13.3\$\textbackslashpm\$0.13 &  17.45 &  117.84 & -64.31 &  0.94\$\textbackslashpm\$0.17 &     0.07 &  3.38 \\
#              NGC\_2554 &  16.63\$\textbackslashpm\$0.35 &  13.2\$\textbackslashpm\$0.13 &  14.75 &  199.71 &  28.84 &  0.96\$\textbackslashpm\$0.17 &     0.07 &  3.29 \\
#               NGC5377 &  16.63\$\textbackslashpm\$0.36 &  12.3\$\textbackslashpm\$0.12 &   5.93 &   94.91 &  66.21 &  1.04\$\textbackslashpm\$0.17 &     0.07 &  2.60 \\
#                IC5271 &  16.63\$\textbackslashpm\$0.36 &  12.2\$\textbackslashpm\$0.12 &   5.43 &   10.79 & -64.77 &  1.05\$\textbackslashpm\$0.17 &     0.07 &  2.56 \\
#      11043695+4507307 &  16.63\$\textbackslashpm\$0.36 &  13.6\$\textbackslashpm\$0.13 &  22.49 &  165.66 &  62.14 &  0.91\$\textbackslashpm\$0.17 &     0.07 &  3.56 \\
#              NGC\_4727 &  16.63\$\textbackslashpm\$0.36 &  13.7\$\textbackslashpm\$0.13 &  26.88 &  302.75 &  48.54 &  0.89\$\textbackslashpm\$0.17 &     0.07 &  3.76 \\
#               NGC3872 &  16.63\$\textbackslashpm\$0.37 &  12.8\$\textbackslashpm\$0.12 &  10.30 &  250.81 &  69.69 &  0.99\$\textbackslashpm\$0.17 &     0.07 &  3.02 \\
#            ESO383-087 &  16.63\$\textbackslashpm\$0.37 &  10.3\$\textbackslashpm\$0.10 &   0.72 &  315.84 &  25.35 &  1.20\$\textbackslashpm\$0.17 &     0.09 &  1.57 \\
#               NGC2305 &  16.63\$\textbackslashpm\$0.37 &  12.9\$\textbackslashpm\$0.12 &  10.76 &  274.41 & -24.60 &  0.99\$\textbackslashpm\$0.17 &     0.07 &  3.08 \\
#            ESO320-031 &  16.63\$\textbackslashpm\$0.37 &  12.7\$\textbackslashpm\$0.12 &   8.92 &  291.13 &  21.69 &  1.01\$\textbackslashpm\$0.17 &     0.07 &  2.86 \\
#              UGC07949 &  16.63\$\textbackslashpm\$0.37 &  10.3\$\textbackslashpm\$0.10 &   0.68 &  128.41 &  80.60 &  1.20\$\textbackslashpm\$0.17 &     0.09 &  1.55 \\
#       g0228373-103221 &  16.63\$\textbackslashpm\$0.35 &  13.2\$\textbackslashpm\$0.13 &  14.81 &  181.65 & -61.75 &  0.96\$\textbackslashpm\$0.17 &     0.07 &  3.29 \\
#               NGC6010 &  16.63\$\textbackslashpm\$0.36 &  12.1\$\textbackslashpm\$0.12 &   4.79 &    9.53 &  38.73 &  1.06\$\textbackslashpm\$0.17 &     0.07 &  2.53 \\
#             UGC\_03683 &  16.62\$\textbackslashpm\$0.36 &  13.5\$\textbackslashpm\$0.13 &  19.92 &  171.12 &  21.95 &  0.92\$\textbackslashpm\$0.17 &     0.07 &  3.46 \\
#              NGC\_0766 &  16.62\$\textbackslashpm\$0.36 &  13.7\$\textbackslashpm\$0.13 &  25.93 &  149.96 & -50.96 &  0.89\$\textbackslashpm\$0.17 &     0.07 &  3.71 \\
#               NGC4845 &  16.62\$\textbackslashpm\$0.38 &  11.9\$\textbackslashpm\$0.11 &   4.13 &  306.74 &  64.40 &  1.08\$\textbackslashpm\$0.17 &     0.07 &  2.48 \\
#              NGC\_1109 &  16.62\$\textbackslashpm\$0.36 &  13.8\$\textbackslashpm\$0.13 &  29.18 &  161.56 & -40.74 &  0.88\$\textbackslashpm\$0.17 &     0.07 &  3.87 \\
#               NGC7796 &  16.62\$\textbackslashpm\$0.37 &  12.9\$\textbackslashpm\$0.12 &  11.17 &  317.90 & -60.11 &  0.99\$\textbackslashpm\$0.17 &     0.06 &  3.12 \\
#        ESO\_341-\_G\_013 &  16.62\$\textbackslashpm\$0.36 &  13.6\$\textbackslashpm\$0.13 &  23.06 &    4.34 & -38.32 &  0.91\$\textbackslashpm\$0.17 &     0.07 &  3.57 \\
#               NGC5631 &  16.62\$\textbackslashpm\$0.36 &  12.4\$\textbackslashpm\$0.12 &   6.54 &   99.52 &  56.03 &  1.03\$\textbackslashpm\$0.17 &     0.07 &  2.64 \\
#            ESO245-005 &  16.62\$\textbackslashpm\$0.37 &  10.6\$\textbackslashpm\$0.10 &   1.03 &  273.08 & -70.29 &  1.18\$\textbackslashpm\$0.17 &     0.08 &  1.69 \\
#                IC4901 &  16.62\$\textbackslashpm\$0.36 &  12.0\$\textbackslashpm\$0.12 &   4.55 &  338.60 & -31.00 &  1.07\$\textbackslashpm\$0.17 &     0.07 &  2.51 \\
#      16445760-0815020 &  16.62\$\textbackslashpm\$0.36 &  13.5\$\textbackslashpm\$0.13 &  20.22 &    9.55 &  23.35 &  0.92\$\textbackslashpm\$0.17 &     0.07 &  3.46 \\
#       g0035339-025055 &  16.62\$\textbackslashpm\$0.35 &  13.4\$\textbackslashpm\$0.13 &  18.84 &  113.37 & -65.43 &  0.93\$\textbackslashpm\$0.17 &     0.07 &  3.41 \\
#               NGC3507 &  16.61\$\textbackslashpm\$0.37 &  11.6\$\textbackslashpm\$0.11 &   2.88 &  227.17 &  63.58 &  1.10\$\textbackslashpm\$0.17 &     0.07 &  2.15 \\
#               NGC4008 &  16.61\$\textbackslashpm\$0.37 &  12.9\$\textbackslashpm\$0.12 &  11.64 &  205.52 &  78.19 &  0.98\$\textbackslashpm\$0.17 &     0.06 &  3.16 \\
#               NGC3458 &  16.61\$\textbackslashpm\$0.36 &  12.1\$\textbackslashpm\$0.12 &   5.03 &  149.32 &  53.70 &  1.06\$\textbackslashpm\$0.17 &     0.07 &  2.53 \\
#              NGC\_6214 &  16.61\$\textbackslashpm\$0.36 &  13.7\$\textbackslashpm\$0.13 &  25.15 &   97.38 &  37.84 &  0.90\$\textbackslashpm\$0.17 &     0.06 &  3.66 \\
#               NGC2090 &  16.61\$\textbackslashpm\$0.37 &  11.6\$\textbackslashpm\$0.11 &   2.74 &  239.46 & -27.43 &  1.11\$\textbackslashpm\$0.17 &     0.07 &  2.12 \\
#       g1313459-130233 &  16.61\$\textbackslashpm\$0.36 &  13.6\$\textbackslashpm\$0.13 &  23.60 &  311.32 &  49.47 &  0.91\$\textbackslashpm\$0.17 &     0.06 &  3.59 \\
#               NGC3892 &  16.61\$\textbackslashpm\$0.36 &  12.2\$\textbackslashpm\$0.12 &   5.23 &  278.58 &  49.03 &  1.06\$\textbackslashpm\$0.17 &     0.07 &  2.55 \\
#               NGC6118 &  16.61\$\textbackslashpm\$0.36 &  12.1\$\textbackslashpm\$0.12 &   4.73 &   11.46 &  31.47 &  1.07\$\textbackslashpm\$0.17 &     0.07 &  2.52 \\
#               NGC4030 &  16.61\$\textbackslashpm\$0.36 &  12.4\$\textbackslashpm\$0.12 &   6.82 &  277.37 &  59.20 &  1.03\$\textbackslashpm\$0.17 &     0.07 &  2.65 \\
#              NGC\_0252 &  16.61\$\textbackslashpm\$0.35 &  13.2\$\textbackslashpm\$0.13 &  15.84 &  122.01 & -35.24 &  0.95\$\textbackslashpm\$0.17 &     0.06 &  3.31 \\
#               NGC3497 &  16.61\$\textbackslashpm\$0.37 &  12.9\$\textbackslashpm\$0.12 &  11.54 &  271.74 &  36.98 &  0.98\$\textbackslashpm\$0.17 &     0.06 &  3.14 \\
#            ESO442-026 &  16.60\$\textbackslashpm\$0.37 &  12.6\$\textbackslashpm\$0.12 &   8.65 &  303.13 &  33.03 &  1.01\$\textbackslashpm\$0.17 &     0.07 &  2.81 \\
#               IC\_0504 &  16.60\$\textbackslashpm\$0.35 &  13.2\$\textbackslashpm\$0.13 &  14.94 &  219.77 &  22.21 &  0.96\$\textbackslashpm\$0.17 &     0.06 &  3.29 \\
#            02468+2100 &  16.60\$\textbackslashpm\$0.36 &  13.5\$\textbackslashpm\$0.13 &  21.29 &  156.55 & -33.83 &  0.92\$\textbackslashpm\$0.17 &     0.06 &  3.49 \\
#       g0135365-392128 &  16.60\$\textbackslashpm\$0.35 &  13.4\$\textbackslashpm\$0.13 &  18.71 &  268.79 & -74.70 &  0.93\$\textbackslashpm\$0.17 &     0.06 &  3.40 \\
#             UGC\_02007 &  16.60\$\textbackslashpm\$0.36 &  13.8\$\textbackslashpm\$0.13 &  28.00 &  159.93 & -45.79 &  0.89\$\textbackslashpm\$0.17 &     0.06 &  3.77 \\
#               NGC5427 &  16.60\$\textbackslashpm\$0.36 &  12.6\$\textbackslashpm\$0.12 &   8.45 &  333.27 &  52.54 &  1.01\$\textbackslashpm\$0.17 &     0.07 &  2.79 \\
#      11101324+3657595 &  16.60\$\textbackslashpm\$0.36 &  13.8\$\textbackslashpm\$0.13 &  29.67 &  181.85 &  66.50 &  0.88\$\textbackslashpm\$0.17 &     0.06 &  3.85 \\
#              NGC\_5912 &  16.60\$\textbackslashpm\$0.36 &  13.6\$\textbackslashpm\$0.13 &  24.69 &  112.23 &  38.69 &  0.90\$\textbackslashpm\$0.17 &     0.06 &  3.62 \\
#               NGC0701 &  16.60\$\textbackslashpm\$0.36 &  12.0\$\textbackslashpm\$0.12 &   4.66 &  164.59 & -67.69 &  1.07\$\textbackslashpm\$0.17 &     0.07 &  2.51 \\
#            ESO154-023 &  16.60\$\textbackslashpm\$0.38 &  10.9\$\textbackslashpm\$0.10 &   1.36 &  271.81 & -54.31 &  1.16\$\textbackslashpm\$0.17 &     0.08 &  1.85 \\
#               NGC7744 &  16.60\$\textbackslashpm\$0.37 &  12.8\$\textbackslashpm\$0.12 &   9.90 &  339.15 & -69.24 &  1.00\$\textbackslashpm\$0.17 &     0.06 &  2.94 \\
#      04572210-7526420 &  16.60\$\textbackslashpm\$0.35 &  13.4\$\textbackslashpm\$0.13 &  18.38 &  287.62 & -33.24 &  0.93\$\textbackslashpm\$0.17 &     0.06 &  3.38 \\
#               NGC3900 &  16.60\$\textbackslashpm\$0.36 &  12.2\$\textbackslashpm\$0.12 &   5.66 &  210.15 &  76.17 &  1.05\$\textbackslashpm\$0.17 &     0.07 &  2.57 \\
#               NGC2685 &  16.60\$\textbackslashpm\$0.37 &  11.8\$\textbackslashpm\$0.11 &   3.50 &  157.78 &  38.90 &  1.09\$\textbackslashpm\$0.17 &     0.07 &  2.28 \\
#  ESO\_034-IG\_011\_NED02 &  16.60\$\textbackslashpm\$0.36 &  13.5\$\textbackslashpm\$0.13 &  22.24 &  285.26 & -26.59 &  0.91\$\textbackslashpm\$0.17 &     0.06 &  3.52 \\
#       g0303545-115931 &  16.60\$\textbackslashpm\$0.35 &  13.0\$\textbackslashpm\$0.13 &  12.65 &  193.49 & -55.48 &  0.98\$\textbackslashpm\$0.17 &     0.06 &  3.23 \\
#      13060443+5539219 &  16.59\$\textbackslashpm\$0.36 &  13.8\$\textbackslashpm\$0.13 &  29.76 &  118.63 &  61.35 &  0.88\$\textbackslashpm\$0.17 &     0.06 &  3.85 \\
#               NGC3198 &  16.59\$\textbackslashpm\$0.37 &  11.6\$\textbackslashpm\$0.11 &   3.00 &  171.22 &  54.83 &  1.10\$\textbackslashpm\$0.17 &     0.07 &  2.16 \\
#       g0507550-181124 &  16.59\$\textbackslashpm\$0.35 &  13.2\$\textbackslashpm\$0.13 &  16.16 &  218.86 & -30.76 &  0.95\$\textbackslashpm\$0.17 &     0.06 &  3.31 \\
#      13245144+3622427 &  16.59\$\textbackslashpm\$0.35 &  13.4\$\textbackslashpm\$0.13 &  19.23 &   87.54 &  78.35 &  0.93\$\textbackslashpm\$0.17 &     0.06 &  3.40 \\
#              NGC\_6609 &  16.59\$\textbackslashpm\$0.36 &  13.7\$\textbackslashpm\$0.13 &  27.43 &   90.49 &  28.18 &  0.89\$\textbackslashpm\$0.17 &     0.06 &  3.73 \\
#       g1916326-401233 &  16.59\$\textbackslashpm\$0.35 &  13.4\$\textbackslashpm\$0.13 &  18.64 &  357.68 & -21.63 &  0.93\$\textbackslashpm\$0.17 &     0.06 &  3.38 \\
#              NGC\_0527 &  16.59\$\textbackslashpm\$0.35 &  13.4\$\textbackslashpm\$0.13 &  18.87 &  263.89 & -79.41 &  0.93\$\textbackslashpm\$0.17 &     0.06 &  3.39 \\
#                IC4214 &  16.59\$\textbackslashpm\$0.36 &  12.5\$\textbackslashpm\$0.12 &   7.80 &  309.37 &  30.44 &  1.02\$\textbackslashpm\$0.17 &     0.06 &  2.72 \\
#               NGC7135 &  16.58\$\textbackslashpm\$0.37 &  12.6\$\textbackslashpm\$0.12 &   8.87 &   10.06 & -50.45 &  1.01\$\textbackslashpm\$0.17 &     0.06 &  2.82 \\
#               NGC1187 &  16.58\$\textbackslashpm\$0.36 &  12.1\$\textbackslashpm\$0.12 &   4.95 &  212.11 & -60.06 &  1.06\$\textbackslashpm\$0.17 &     0.06 &  2.52 \\
#      05293890-1933428 &  16.58\$\textbackslashpm\$0.36 &  13.7\$\textbackslashpm\$0.13 &  27.93 &  222.44 & -26.46 &  0.89\$\textbackslashpm\$0.17 &     0.06 &  3.74 \\
#             UGC\_10127 &  16.58\$\textbackslashpm\$0.35 &  13.2\$\textbackslashpm\$0.13 &  15.70 &   35.22 &  46.63 &  0.95\$\textbackslashpm\$0.17 &     0.06 &  3.30 \\
# \bottomrule
# \end{tabular}

# %%
catalog_app = catalog[:30][['paperName','log10Jerr','log10Merr','zred','l','b','log10cerr','theta_s','bsh']]

# %%
catalog_app['maxTS'] = [np.load("../data/Tully/LL2_TSmx_lim_b_emin4_emax30_o" + str(iobj) + "_data.npz")['TSmx'][0] for iobj in tqdm_notebook(range(len(catalog_app)))]

# %%
catalog_app['in'] = catalog['in']

# %%
print catalog_app.round(2).to_latex(index = False)
# Out:
# \begin{tabular}{lllrrrlrrrl}
# \toprule
#   paperName &       log10Jerr &      log10Merr &   zred &       l &      b &      log10cerr &  theta\_s &   bsh &  maxTS &          in \\
# \midrule
#   Andromeda &  19.79\$\textbackslashpm\$0.36 &  12.4\$\textbackslashpm\$0.12 &   0.17 &  121.51 & -21.79 &  1.04\$\textbackslashpm\$0.17 &     2.57 &  2.64 &   2.92 &             \\
#       Virgo &  19.11\$\textbackslashpm\$0.35 &  14.6\$\textbackslashpm\$0.14 &   3.58 &  283.78 &  74.49 &  0.80\$\textbackslashpm\$0.18 &     1.16 &  4.53 &   1.04 &  \textbackslashcheckmark \\
#     NGC5128 &  18.89\$\textbackslashpm\$0.37 &  12.9\$\textbackslashpm\$0.12 &   0.82 &  307.88 &  17.08 &  0.99\$\textbackslashpm\$0.17 &     0.88 &  3.14 &   0.00 &             \\
#     NGC0253 &  18.76\$\textbackslashpm\$0.37 &  12.7\$\textbackslashpm\$0.12 &   0.79 &   98.24 & -87.89 &  1.00\$\textbackslashpm\$0.17 &     0.77 &  2.90 &   0.63 &  \textbackslashcheckmark \\
#    Maffei 1 &  18.68\$\textbackslashpm\$0.37 &  12.6\$\textbackslashpm\$0.12 &   0.78 &  136.23 &  -0.44 &  1.01\$\textbackslashpm\$0.17 &     0.71 &  2.81 &   7.26 &             \\
#    NGC 6822 &  18.59\$\textbackslashpm\$0.37 &  10.7\$\textbackslashpm\$0.10 &   0.11 &   25.34 & -18.40 &  1.17\$\textbackslashpm\$0.17 &     0.77 &  1.70 &  16.65 &             \\
#     NGC3031 &  18.58\$\textbackslashpm\$0.36 &  12.6\$\textbackslashpm\$0.12 &   0.83 &  141.88 &  40.87 &  1.02\$\textbackslashpm\$0.17 &     0.64 &  2.76 &   0.00 &  \textbackslashcheckmark \\
#   Centaurus &  18.34\$\textbackslashpm\$0.35 &  14.6\$\textbackslashpm\$0.14 &   8.44 &  302.22 &  21.65 &  0.80\$\textbackslashpm\$0.18 &     0.48 &  4.50 &   6.60 &  \textbackslashcheckmark \\
#     NGC1399 &  18.31\$\textbackslashpm\$0.37 &  13.8\$\textbackslashpm\$0.13 &   4.11 &  236.62 & -53.88 &  0.89\$\textbackslashpm\$0.17 &     0.45 &  3.87 &   0.72 &  \textbackslashcheckmark \\
#      IC0356 &  18.27\$\textbackslashpm\$0.36 &  13.5\$\textbackslashpm\$0.13 &   3.14 &  138.06 &  12.70 &  0.92\$\textbackslashpm\$0.17 &     0.43 &  3.51 &   0.02 &             \\
#     NGC4594 &  18.26\$\textbackslashpm\$0.35 &  13.3\$\textbackslashpm\$0.13 &   2.56 &  299.01 &  51.30 &  0.94\$\textbackslashpm\$0.17 &     0.43 &  3.36 &   0.00 &  \textbackslashcheckmark \\
#       Norma &  18.18\$\textbackslashpm\$0.33 &  15.1\$\textbackslashpm\$0.15 &  17.07 &  325.29 &  -7.21 &  0.74\$\textbackslashpm\$0.18 &     0.39 &  5.17 &   1.72 &             \\
#     IC 1613 &  18.17\$\textbackslashpm\$0.37 &  10.6\$\textbackslashpm\$0.10 &   0.17 &  129.74 & -60.58 &  1.18\$\textbackslashpm\$0.17 &     0.48 &  1.67 &   0.00 &  \textbackslashcheckmark \\
#     Perseus &  18.13\$\textbackslashpm\$0.33 &  15.0\$\textbackslashpm\$0.15 &  17.62 &  150.58 & -13.26 &  0.75\$\textbackslashpm\$0.18 &     0.37 &  5.16 &   0.00 &             \\
#     NGC4736 &  18.12\$\textbackslashpm\$0.36 &  12.2\$\textbackslashpm\$0.12 &   1.00 &  124.83 &  75.76 &  1.05\$\textbackslashpm\$0.17 &     0.38 &  2.58 &   0.93 &  \textbackslashcheckmark \\
#     NGC3627 &  18.11\$\textbackslashpm\$0.35 &  13.0\$\textbackslashpm\$0.13 &   2.20 &  241.46 &  64.36 &  0.98\$\textbackslashpm\$0.17 &     0.35 &  3.23 &  27.24 &             \\
#      Fornax &  18.01\$\textbackslashpm\$0.36 &  13.5\$\textbackslashpm\$0.13 &   4.17 &  236.72 & -53.64 &  0.92\$\textbackslashpm\$0.17 &     0.32 &  3.49 &   2.33 &             \\
#     NGC5236 &  18.01\$\textbackslashpm\$0.36 &  12.2\$\textbackslashpm\$0.12 &   1.09 &  314.58 &  31.98 &  1.05\$\textbackslashpm\$0.17 &     0.33 &  2.56 &  22.08 &             \\
#      IC0342 &  18.01\$\textbackslashpm\$0.37 &  11.8\$\textbackslashpm\$0.11 &   0.73 &  138.52 &  10.69 &  1.09\$\textbackslashpm\$0.17 &     0.34 &  2.33 &   1.92 &             \\
#        Coma &  17.98\$\textbackslashpm\$0.33 &  15.2\$\textbackslashpm\$0.15 &  24.45 &   57.20 &  87.89 &  0.73\$\textbackslashpm\$0.18 &     0.32 &  5.21 &  41.15 &             \\
#     NGC4565 &  17.97\$\textbackslashpm\$0.35 &  13.1\$\textbackslashpm\$0.13 &   2.98 &  229.92 &  86.07 &  0.96\$\textbackslashpm\$0.17 &     0.31 &  3.28 &   2.35 &  \textbackslashcheckmark \\
#       Hydra &  17.95\$\textbackslashpm\$0.34 &  14.4\$\textbackslashpm\$0.14 &  10.87 &  269.55 &  26.41 &  0.82\$\textbackslashpm\$0.17 &     0.30 &  4.32 &   0.08 &  \textbackslashcheckmark \\
#      Dorado &  17.94\$\textbackslashpm\$0.36 &  13.4\$\textbackslashpm\$0.13 &   4.02 &  265.56 & -43.51 &  0.94\$\textbackslashpm\$0.17 &     0.30 &  3.41 &   0.04 &  \textbackslashcheckmark \\
#     NGC3379 &  17.94\$\textbackslashpm\$0.37 &  12.9\$\textbackslashpm\$0.12 &   2.42 &  233.64 &  57.77 &  0.99\$\textbackslashpm\$0.17 &     0.29 &  3.11 &   0.00 &  \textbackslashcheckmark \\
#     NGC5194 &  17.93\$\textbackslashpm\$0.37 &  12.6\$\textbackslashpm\$0.12 &   1.84 &  104.86 &  68.53 &  1.01\$\textbackslashpm\$0.17 &     0.30 &  2.81 &   4.94 &  \textbackslashcheckmark \\
#  ESO097-013 &  17.92\$\textbackslashpm\$0.37 &  11.6\$\textbackslashpm\$0.11 &   0.60 &  311.33 &  -3.81 &  1.11\$\textbackslashpm\$0.17 &     0.32 &  2.12 &  13.45 &             \\
#     NGC4258 &  17.92\$\textbackslashpm\$0.36 &  12.5\$\textbackslashpm\$0.12 &   1.64 &  139.02 &  68.89 &  1.03\$\textbackslashpm\$0.17 &     0.30 &  2.71 &   0.50 &  \textbackslashcheckmark \\
#     NGC1068 &  17.91\$\textbackslashpm\$0.35 &  13.3\$\textbackslashpm\$0.13 &   3.60 &  171.99 & -51.86 &  0.95\$\textbackslashpm\$0.17 &     0.29 &  3.33 &   6.95 &  \textbackslashcheckmark \\
#     NGC4261 &  17.91\$\textbackslashpm\$0.37 &  13.9\$\textbackslashpm\$0.13 &   7.16 &  281.87 &  67.45 &  0.88\$\textbackslashpm\$0.17 &     0.28 &  4.03 &  12.56 &             \\
#     NGC4826 &  17.88\$\textbackslashpm\$0.36 &  12.1\$\textbackslashpm\$0.12 &   1.16 &  315.69 &  84.42 &  1.06\$\textbackslashpm\$0.17 &     0.29 &  2.53 &   3.31 &  \textbackslashcheckmark \\
# \bottomrule
# \end{tabular}

# %%
catalog_lu = pd.read_csv("/tigress/nrodd/DM-Catalog-Scan/DataFiles/Catalogs/2MRSLu_ALL_DATAPAPER_Planck15_v5.csv")

# %%
catalog_lu['zred'] = catalog_lu['z']*1000
catalog_lu['log10cvir_inf'] = np.log10(catalog_lu['cvir_inf'])
catalog_lu['bsh'] = 10**catalog_lu['mulog10J_inf']/10**catalog_lu['mulog10Jnb_inf'] - 1
catalog_lu['paperName'] = [catalog_lu['Name'].values[i] for i in range(len(catalog_lu))]

# %%
catalog_lu_app = catalog_lu[:100][['paperName','mulog10J_inf','log10Mvir_inf','zred','l','b','log10cvir_inf', 'ang_ext','bsh']]

# %%
catalog_lu_app['maxTS'] = [np.load("../data/Lu/LL2_TSmx_lim_b_o" + str(iobj) + "_data.npz")['TSmx'][0] for iobj in range(len(catalog_lu_app))]

# %%
# print catalog_lu_app.round(2).to_latex(index = False)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-57-471424bd0b0f> in <module>()
# ----> 1 print catalog_lu_app.round(2).to_latex(index = False)
#
# NameError: name 'catalog_lu_app' is not defined

# %% [markdown]
# # Sky maps

# %%
l = catalog['l'][plot_data.passed_halos].values
b = catalog['b'][plot_data.passed_halos].values
s = 1000*10**catalog['mulog10J_inf'][plot_data.passed_halos].values/10**catalog['mulog10J_inf'][plot_data.passed_halos].values[0]

# %%
import healpy as hp
hp.mollview(np.zeros(hp.nside2npix(128)))
hp.projscatter(l, b, lonlat=True, coord='G', marker='o', color='orange',s = s)
# for i in tqdm_notebook(range(len(l))):
#     hp.projscatter(l[i], b[i], lonlat=True, coord='G', marker='o', color='orange',s = s[i])

# %%
oFig1 = plt.figure(1,figsize=(10,60))

lbrange = 5
from tools import lb2pix
    

for ie in tqdm(range(10)):
    
    the_map = hp.ma(f_global.CTB_count_maps[ie])
    the_map.mask = f_global.ps_mask_array[10] > 0
    nhalos = 1


    
    l = 283.7777978  
    b = 74.4911308

    hp.cartview(the_map, max = 8, rot=(l,b), lonra=[-lbrange,lbrange],latra=[-lbrange,lbrange], title=dftop['Name'].values[idx].replace("_", " "),sub=(5,2,ie+1))


    hp.projscatter(l, b, lonlat=True, coord='G', marker='x', color='k')

    hp.projscatter(286.922184 ,  70.196040, lonlat=True, coord='G', marker='x', color='k')



    l = source_3fg_df['_Lii']
    b =source_3fg_df['_Bii']

    hp.projscatter(l, b, lonlat=True, coord='G', marker='*', color='orange')

#     plt.savefig("Mask_Object_"+"%02d" % (idx+1,)+".pdf")

# %% [markdown]
# # Other channels

# %%
plot_data_channels = []

for channel in tqdm_notebook(['e','mu','tau','q','c','t','W','Z']):
# for channel in tqdm_notebook(['tau']):

    channel_str = channel

    plot_data_temp = LimitPlot(data_dir='/tigress/nrodd/DM-Catalog-Scan/Scan-Small-ROI/data/Tully_lowermasses_'+channel+'/////',
                            elephant=False, 
                            nmc=1,
                            bcut=20,
                            nonoverlap=True,
                            nonoverlapradius=2.,
                            cut_0p5=False,
                            xsecslim=10,
                            TS100=9,
                            TS1000=9,
                            halos_ran=1000, 
                            halos_to_keep=1000,
                            data_type="data",
                            catalog_file="/tigress/nrodd/DM-Catalog-Scan/DataFiles/Catalogs/2MRSLocalTully_ALL_DATAPAPER_Planck15_v7.csv",
                            file_prefix=r'LL2_TSmx_lim_'+channel_str+r'_emin4_emax30_o')

    plot_data_channels.append(plot_data_temp)

# %%
data_ary_channels = []

for i in range(len(tqdm_notebook(plot_data_channels))):
    data_ary_channels.append(plot_data_channels[i].return_limits())

# %%
plot_colors = ["forestgreen","forestgreen","forestgreen","goldenrod","goldenrod","goldenrod","lightcoral","lightcoral"]
plot_ls = ["-","--","-.","-","--","-.","-","--"]

# %%
fig,ax = plt.subplots(1,figsize=(10/1.2,8/1.2))

# plt.plot(m_arr,data_lim,color='k',label=r'Galaxy groups (this work)',linewidth=2,linestyle='solid')
# plt.plot(m_arr,data_lim_nb,color='black',label=r'Galaxy groups (no boost)',linewidth=1,linestyle='dashed')

# fudge=1.0 
# plt.fill_between(m_arr,fudge*rot_q2p5,fudge*rot_q97p5,color='yellow',label=r'95\% containment',alpha=0.6)
# plt.fill_between(m_arr,fudge*rot_q16,fudge*rot_q84,color='limegreen',label=r'68\% containment',alpha=0.7)

plt.plot(plot_data.marr,10**np.percentile(data_ary[-1], 2.5, axis=1), alpha=1, color='k',label=r'$b$', lw=2.5)



for i, label in enumerate((['e','mu','tau','q','c','t','W','Z'])):
    if label in ["mu","tau"]:
        label = "\\" + label
    label = "$" + label + "$"    
    plt.plot(plot_data_channels[i].marr,[None if v == 1.0 else v for v in 10**np.percentile(data_ary_channels[i][0][-1], 16, axis=1)], label=label, color=plot_colors[i],ls=plot_ls[i])

plt.plot(thermal[::,0],thermal[::,1],linestyle='dotted',color='dimgrey',linewidth=1)
plt.text(380, 3.e-26, r'\emph{Thermal relic cross section}',fontsize=19.,color='dimgrey')
# plt.text(7000, 1.0e-27, r'$b \bar b$',fontsize=20,color='black')

# set the alpha value of the legend: it will be translucent
# leg.get_frame().set_alpha(0.1)

plt.xscale('log')
plt.yscale('log')
plt.xticks(fontsize=23);
plt.yticks(fontsize=23);
plt.xlabel(r"$m_\chi$ [GeV]",fontsize=23)
plt.ylabel(r"$\langle \sigma v \rangle$ [cm$^3$ s$^{-1}$]",fontsize=23)
#plt.legend(fontsize=18,loc = 2)

plt.xlim([10,1e4])
plt.ylim([8e-28,2e-22])

plt.text(200.3, 3.5e-27, r'\textbf{Stacked Galaxy Groups}',fontsize=22,color='black')
plt.text(310.3, 1.5e-27, r'Other annihilation channels',fontsize=20,color='black')

plt.legend(ncol=2,fancybox=True,facecolor='none',frameon=False,loc='upper left')

plt.tight_layout()

plt.savefig(plots_dir + 'other_annh.pdf',bbox_inches='tight')

# %% [markdown]
# # Systematics

# %%
plot_data_Lu = LimitPlot(data_dir='/tigress/nrodd/DM-Catalog-Scan/Scan-Small-ROI/data/Lu//',
                        elephant=False, 
                        nmc=1,
                        bcut=20,
                        nonoverlap=True,
                        nonoverlapradius=2.,
                        cut_0p5=False,
                        xsecslim=10,
                        TS100=9,
                        TS1000=9,
                        halos_ran=1000, 
                        halos_to_keep=1000,
                        data_type="data",
                         file_prefix='LL2_TSmx_lim_b_emin4_emax30_o',
                         skip_halos=[],
                        catalog_file="/tigress/nrodd/DM-Catalog-Scan/DataFiles/Catalogs/2MRSLu_ALL_DATAPAPER_Planck15_v5.csv")

# %%
data_ary_Lu, _,_ = plot_data_Lu.return_limits()

# %%
plot_data_p7 = LimitPlot(data_dir='/tigress/nrodd/DM-Catalog-Scan/Scan-Small-ROI/data/Tully_p7///',
                        elephant=False, 
                        nmc=1,
                        bcut=20,
                        nonoverlap=True,
                        nonoverlapradius=2.,
                        cut_0p5=False,
                        xsecslim=10,
                        TS100=9,
                        TS1000=9,
                        halos_ran=1000, 
                        halos_to_keep=1000,
                        data_type="data",
                        file_prefix='LL2_TSmx_lim_b_emin4_emax30_o',
                        catalog_file="/tigress/nrodd/DM-Catalog-Scan/DataFiles/Catalogs/2MRSLocalTully_ALL_DATAPAPER_Planck15_v7.csv")

# %%
data_ary_p7, _, _ = plot_data_p7.return_limits()

# %%
plot_data_UCV3 = LimitPlot(data_dir='/tigress/nrodd/DM-Catalog-Scan/Scan-Small-ROI/data/Tully_UCV3///',
                        elephant=False, 
                        nmc=1,
                        bcut=20,
                        nonoverlap=True,
                        nonoverlapradius=2.,
                        cut_0p5=False,
                        xsecslim=10,
                        TS100=9,
                        TS1000=9,
                        halos_ran=1000, 
                        halos_to_keep=1000,
                        data_type="data",
                           file_prefix='LL2_TSmx_lim_b_emin4_emax30_o',
                        catalog_file="/tigress/nrodd/DM-Catalog-Scan/DataFiles/Catalogs/2MRSLocalTully_ALL_DATAPAPER_Planck15_v7.csv")

# %%
data_ary_UCV3, _,_ = plot_data_UCV3.return_limits()

# %%
plot_data_useboost = LimitPlot(data_dir='/tigress/nrodd/DM-Catalog-Scan/Scan-Small-ROI/data/Tully_useboost////',
                        elephant=False, 
                        nmc=1,
                        bcut=20,
                        nonoverlap=True,
                        nonoverlapradius=2.,
                        cut_0p5=False,
                        xsecslim=10,
                        TS100=9,
                        TS1000=9,
                        halos_ran=1000, 
                        halos_to_keep=1000,
                        data_type="data",
                        file_prefix='LL2_TSmx_lim_b_emin4_emax30_o',
                        catalog_file="/tigress/nrodd/DM-Catalog-Scan/DataFiles/Catalogs/2MRSLocalTully_ALL_DATAPAPER_Planck15_v7.csv")

# %%
data_ary_useboost, _,_ = plot_data_useboost.return_limits()

# %%
plot_data_Burkert = LimitPlot(data_dir='/tigress/nrodd/DM-Catalog-Scan/Scan-Small-ROI/data/Tully_Burkert///',
                        elephant=False, 
                        nmc=1,
                        bcut=20,
                        nonoverlap=True,
                        nonoverlapradius=2.,
                        cut_0p5=False,
                        xsecslim=10,
                        TS100=9,
                        TS1000=9,
                        halos_ran=1000, 
                        halos_to_keep=1000,
                        data_type="data",
                        catalog_file="/tigress/nrodd/DM-Catalog-Scan/DataFiles/Catalogs/2MRSLocalTully_ALL_DATAPAPER_Planck15_v7.csv",
                        file_prefix="LL2_TSmx_lim_b_Burk_emin4_emax30_o")

# %%
data_ary_Burkert, _,_ = plot_data_Burkert.return_limits()

# %%
catalog_file_og=pd.read_csv("/tigress/nrodd/DM-Catalog-Scan/DataFiles/Catalogs/2MRSLocalTully_ALL_DATAPAPER_Planck15_v7.csv")

# %%
catalog_file=pd.read_csv("/tigress/nrodd/DM-Catalog-Scan/DataFiles/Catalogs/2MRSLocalTully_ALL_DATAPAPER_Planck15_0p24cvirerr_v7.csv")

# %%
catalog_file_og
# Out:
#        Unnamed: 0                     Name  mulog10J_inf  siglog10J_inf  \
# 0            3072                Andromeda     19.793990       0.367214
# 1             210                  NGC4472     19.115659       0.352758
# 2            2565                  NGC5128     18.896069       0.378974
# 3            3211                  NGC0253     18.761680       0.372880
# 4            3239                 Maffei 1     18.688100       0.370669
# 5            3074                 NGC 6822     18.594351       0.375988
# 6            2809                  NGC3031     18.588134       0.369610
# 7               0                  NGC4696     18.346298       0.351851
# 8             906                  NGC1399     18.310999       0.370018
# 9            2153                   IC0356     18.271854       0.361928
# 10            211                  NGC4594     18.266314       0.359630
# 11          24625           ESO_137-_G_006     18.181355       0.335216
# 12           3075                  IC 1613     18.172924       0.375346
# 13          22884                 NGC_1275     18.137190       0.335297
# 14           2171                  NGC4736     18.126561       0.366199
# 15            214                  NGC3627     18.113302       0.359006
# 16            907                  NGC1316     18.017668       0.361676
# 17           2566                  NGC5236     18.012553       0.365978
# 18           3241                   IC0342     18.010387       0.378304
# 19          13004         13000812+2758370     17.985449       0.334483
# 20            212                  NGC4565     17.977258       0.358936
# 21            851                  NGC3311     17.952325       0.349074
# 22            908                  NGC1553     17.948257       0.360224
# 23            217                  NGC3379     17.941030       0.378227
# 24           2168                  NGC5194     17.939911       0.370496
# 25           2567               ESO097-013     17.929128       0.372927
# 26           2169                  NGC4258     17.923418       0.368440
# 27           1928                  NGC1068     17.918369       0.359242
# 28           1069                  NGC4261     17.913938       0.373773
# 29           2173                  NGC4826     17.880412       0.365727
# ...           ...                      ...           ...            ...
# 16990        8039               PGC3139929     14.530082       0.375053
# 16991        6094                PGC090776     14.525720       0.381212
# 16992         209               PGC5065966     14.525030       0.374480
# 16993        8231               PGC2801013     14.524877       0.374407
# 16994        2854  SDSSJ150654.39+553218.0     14.524399       0.375214
# 16995        6093               ESO567-006     14.524236       0.368971
# 16996        8227               PGC1042130     14.522352       0.374437
# 16997        5555  SDSSJ142645.04+564039.7     14.522333       0.374987
# 16998        8020                PGC989253     14.521085       0.375098
# 16999        8476  SDSSJ021629.26+011521.8     14.517159       0.373409
# 17000        8263                AGC258133     14.508763       0.374307
# 17001        6109  SDSSJ115937.48+414503.5     14.505703       0.374576
# 17002        8469  SDSSJ102347.79+564859.2     14.499796       0.373422
# 17003        8233  SDSSJ222917.74-003116.2     14.497791       0.374392
# 17004        2727  SDSSJ172730.51+622729.0     14.491895       0.374188
# 17005        8358                PGC135771     14.487003       0.373857
# 17006        8451  SDSSJ104247.04+043152.0     14.482864       0.373495
# 17007        1762  SDSSJ153844.84+564250.6     14.477307       0.374320
# 17008        4079  SDSSJ090004.16+483740.9     14.472498       0.373283
# 17009        8309               PGC3130829     14.467023       0.374068
# 17010        5584               ESO564-012     14.466540       0.368920
# 17011        8666  SDSSJ091416.59+570239.6     14.461571       0.372419
# 17012        8371               PGC2147507     14.454076       0.373813
# 17013        8506               PGC2816191     14.437717       0.373246
# 17014        6191                 UGC01054     14.417521       0.378769
# 17015        8552  SDSSJ132723.28+402204.1     14.364067       0.373023
# 17016        5142                PGC091091     14.359897       0.368818
# 17017        6797                PGC090815     14.307778       0.375177
# 17018        8633       6dFJ0410498-272959     14.267539       0.372615
# 17019        8733          [MBC2001]039119     14.181099       0.371919
#
#        mulog10Jnb_inf  siglog10Jnb_inf  mulog10JB_inf  siglog10JB_inf  \
# 0           19.233062         0.360742      19.585515        0.394558
# 1           18.372857         0.338266      18.864802        0.381959
# 2           18.279186         0.356886      18.679241        0.406024
# 3           18.170785         0.358277      18.547804        0.400180
# 4           18.106905         0.358768      18.475447        0.398041
# 5           18.163484         0.368982      18.408005        0.400740
# 6           18.012834         0.359326      18.376581        0.396991
# 7           17.606330         0.338428      18.095882        0.381128
# 8           17.623174         0.347762      18.076683        0.398209
# 9           17.618154         0.350952      18.043422        0.390607
# 10          17.626789         0.353051      18.041887        0.388360
# 11          17.391060         0.331861      17.920313        0.365150
# 12          17.746147         0.369123      17.987069        0.400083
# 13          17.347323         0.332112      17.876573        0.365258
# 14          17.573172         0.361640      17.920203        0.393458
# 15          17.486622         0.356164      17.895070        0.387521
# 16          17.364965         0.351015      17.789404        0.390367
# 17          17.461347         0.361959      17.806950        0.393194
# 18          17.488224         0.364190      17.810227        0.404259
# 19          17.192036         0.329866      17.721379        0.364192
# 20          17.345931         0.354777      17.756246        0.387585
# 21          17.226414         0.340868      17.706125        0.378706
# 22          17.303915         0.352176      17.722203        0.388961
# 23          17.326907         0.356942      17.724394        0.405314
# 24          17.359236         0.358735      17.727261        0.397877
# 25          17.435591         0.365532      17.732481        0.398918
# 26          17.354519         0.359876      17.713074        0.395824
# 27          17.282051         0.353622      17.695093        0.387959
# 28          17.211955         0.346646      17.677724        0.401704
# 29          17.332507         0.362511      17.676126        0.392858
# ...               ...              ...            ...             ...
# 16990       14.102154         0.368602      14.343513        0.399865
# 16991       14.060984         0.367350      14.335529        0.406020
# 16992       14.101059         0.368780      14.339008        0.399269
# 16993       14.101427         0.368805      14.338931        0.399192
# 16994       14.095372         0.368553      14.337684        0.400032
# 16995       14.057657         0.367282      14.333862        0.394568
# 16996       14.098681         0.368793      14.336372        0.399223
# 16997       14.094820         0.368615      14.335813        0.399798
# 16998       14.092823         0.368583      14.334466        0.399912
# 16999       14.101125         0.369178      14.332411        0.398124
# 17000       14.085972         0.368829      14.322906        0.399088
# 17001       14.080974         0.368733      14.319558        0.399372
# 17002       14.083587         0.369160      14.315006        0.398140
# 17003       14.074341         0.368790      14.311828        0.399180
# 17004       14.069893         0.368857      14.306146        0.398965
# 17005       14.067388         0.368969      14.301620        0.398613
# 17006       14.066006         0.369114      14.297946        0.398222
# 17007       14.054298         0.368801      14.291397        0.399106
# 17008       14.057319         0.369207      14.287885        0.397990
# 17009       14.045791         0.368880      14.281375        0.398840
# 17010       13.998835         0.367012      14.275508        0.394585
# 17011       14.052740         0.369471      14.278128        0.397041
# 17012       14.034657         0.368961      14.268704        0.398570
# 17013       14.022705         0.369200      14.253114        0.397953
# 17014       13.966075         0.367655      14.228323        0.403623
# 17015       13.950569         0.369249      14.179708        0.397715
# 17016       13.891439         0.366761      14.168362        0.394535
# 17017       13.878061         0.368380      14.120804        0.400019
# 17018       13.856805         0.369333      14.083649        0.397275
# 17019       13.776387         0.369679      13.998623        0.396456
#
#        mulog10JBnb_inf  siglog10JBnb_inf     ...      \
# 0            19.024586          0.388542     ...
# 1            18.121999          0.368616     ...
# 2            18.062358          0.385489     ...
# 3            17.956908          0.386610     ...
# 4            17.894252          0.386983     ...
# 5            17.977139          0.394174     ...
# 6            17.801281          0.387434     ...
# 7            17.355914          0.368773     ...
# 8            17.388858          0.377617     ...
# 9            17.389723          0.380459     ...
# 10           17.402363          0.382276     ...
# 11           17.130018          0.362072     ...
# 12           17.560292          0.394250     ...
# 13           17.086706          0.362336     ...
# 14           17.366813          0.389218     ...
# 15           17.268390          0.384890     ...
# 16           17.136701          0.380510     ...
# 17           17.255744          0.389456     ...
# 18           17.288064          0.391082     ...
# 19           16.927965          0.359956     ...
# 20           17.124920          0.383737     ...
# 21           16.980214          0.371156     ...
# 22           17.077860          0.381519     ...
# 23           17.110271          0.385528     ...
# 24           17.146586          0.386949     ...
# 25           17.238943          0.392014     ...
# 26           17.144175          0.387865     ...
# 27           17.058774          0.382760     ...
# 28           16.975741          0.376595     ...
# 29           17.128221          0.389865     ...
# ...                ...               ...     ...
# 16990        13.915585          0.393821     ...
# 16991        13.870793          0.393033     ...
# 16992        13.915037          0.393928     ...
# 16993        13.915482          0.393943     ...
# 16994        13.908657          0.393791     ...
# 16995        13.867283          0.392989     ...
# 16996        13.912701          0.393935     ...
# 16997        13.908300          0.393828     ...
# 16998        13.906204          0.393808     ...
# 16999        13.916377          0.394158     ...
# 17000        13.900115          0.393955     ...
# 17001        13.894830          0.393897     ...
# 17002        13.898797          0.394145     ...
# 17003        13.888379          0.393930     ...
# 17004        13.884144          0.393969     ...
# 17005        13.882005          0.394033     ...
# 17006        13.881089          0.394116     ...
# 17007        13.868388          0.393934     ...
# 17008        13.872706          0.394170     ...
# 17009        13.860142          0.393979     ...
# 17010        13.807803          0.392801     ...
# 17011        13.869297          0.394277     ...
# 17012        13.849285          0.394024     ...
# 17013        13.838103          0.394161     ...
# 17014        13.776878          0.393213     ...
# 17015        13.766211          0.394178     ...
# 17016        13.699903          0.392613     ...
# 17017        13.691086          0.393651     ...
# 17018        13.672915          0.394199     ...
# 17019        13.593911          0.394356     ...
#
#                                                   3FGL 2  \
# 0      ['3FGL J0048.0+3950' '3FGL J0040.3+4049' '3FGL...
# 1      ['3FGL J1223.2+1215' '3FGL J1230.9+1224' '3FGL...
# 2                                  ['3FGL J1326.2-4651']
# 3              ['3FGL J0047.5-2516' '3FGL J0054.8-2455']
# 4      ['3FGL J0254.2+5903' '3FGL J0248.5+6022' '3FGL...
# 5                                  ['3FGL J1949.5-1454']
# 6                                  ['3FGL J0955.4+6940']
# 7                                                     []
# 8                                  ['3FGL J0336.9-3622']
# 9                                                     []
# 10                                 ['3FGL J1239.1-1158']
# 11             ['3FGL J1630.3-6126' '3FGL J1603.7-6011']
# 12                                 ['3FGL J0108.7+0134']
# 13             ['3FGL J0316.6+4119' '3FGL J0319.8+4130']
# 14                                                    []
# 15                                                    []
# 16                                 ['3FGL J0336.9-3622']
# 17                                 ['3FGL J1335.4-2949']
# 18                                                    []
# 19                                                    []
# 20                                 ['3FGL J1230.3+2519']
# 21                                 ['3FGL J1037.5-2821']
# 22                                                    []
# 23                                 ['3FGL J1049.8+1425']
# 24                                 ['3FGL J1331.8+4718']
# 25     ['3FGL J1412.3-6635' '3FGL J1413.2-6518' '3FGL...
# 26                                                    []
# 27                                 ['3FGL J0242.7-0001']
# 28             ['3FGL J1222.4+0414' '3FGL J1226.8+0638']
# 29             ['3FGL J1258.4+2123' '3FGL J1254.5+2210']
# ...                                                  ...
# 16990                              ['3FGL J1032.5+6623']
# 16991                                                 []
# 16992                              ['3FGL J1249.1-2808']
# 16993                                                 []
# 16994          ['3FGL J1502.2+5553' '3FGL J1509.7+5556']
# 16995                                                 []
# 16996                                                 []
# 16997          ['3FGL J1436.8+5639' '3FGL J1422.8+5801']
# 16998                              ['3FGL J0039.1-0939']
# 16999          ['3FGL J0217.8+0143' '3FGL J0216.0+0300']
# 17000                                                 []
# 17001  ['3FGL J1153.4+4033' '3FGL J1209.4+4119' '3FGL...
# 17002  ['3FGL J1035.2+5545' '3FGL J1016.1+5555' '3FGL...
# 17003                              ['3FGL J2227.8+0040']
# 17004          ['3FGL J1729.0+6049' '3FGL J1722.7+6104']
# 17005                                                 []
# 17006          ['3FGL J1050.4+0435' '3FGL J1040.4+0615']
# 17007                              ['3FGL J1531.0+5737']
# 17008          ['3FGL J0903.1+4649' '3FGL J0850.0+4855']
# 17009                              ['3FGL J1616.4+4631']
# 17010                                                 []
# 17011                              ['3FGL J0915.0+5844']
# 17012  ['3FGL J1104.4+3812' '3FGL J1100.5+4020' '3FGL...
# 17013                                                 []
# 17014                              ['3FGL J0122.8+3423']
# 17015                                                 []
# 17016                              ['3FGL J1112.1+1034']
# 17017          ['3FGL J0757.0+0956' '3FGL J0802.0+1005']
# 17018                                                 []
# 17019                                                 []
#
#                                                   3FGL 5  \
# 0      ['3FGL J0041.9+3639' '3FGL J0032.5+3912' '3FGL...
# 1      ['3FGL J1223.3+0818' '3FGL J1223.2+1215' '3FGL...
# 2      ['3FGL J1305.4-4926' '3FGL J1328.5-4728' '3FGL...
# 3      ['3FGL J0032.3-2852' '3FGL J0047.5-2516' '3FGL...
# 4      ['3FGL J0250.6+5630' '3FGL J0235.7+5647' '3FGL...
# 5      ['3FGL J2001.0-1750' '3FGL J1955.0-1605' '3FGL...
# 6      ['3FGL J0958.6+6534' '3FGL J0919.4+6604' '3FGL...
# 7      ['3FGL J1238.3-4543' '3FGL J1254.9-4423' '3FGL...
# 8      ['3FGL J0334.3-4008' '3FGL J0334.3-3726' '3FGL...
# 9      ['3FGL J0333.9+6538' '3FGL J0419.1+6636' '3FGL...
# 10     ['3FGL J1241.6-1456' '3FGL J1231.2-1411' '3FGL...
# 11     ['3FGL J1558.9-6432' '3FGL J1630.3-6126' '3FGL...
# 12     ['3FGL J0059.2-0152' '3FGL J0108.5-0035' '3FGL...
# 13     ['3FGL J0310.8+3814' '3FGL J0342.2+3857' '3FGL...
# 14     ['3FGL J1256.9+3649' '3FGL J1249.7+3705' '3FGL...
# 15     ['3FGL J1132.8+1015' '3FGL J1112.1+1034' '3FGL...
# 16     ['3FGL J0334.3-4008' '3FGL J0334.3-3726' '3FGL...
# 17     ['3FGL J1345.9-3357' '3FGL J1346.9-2958' '3FGL...
# 18     ['3FGL J0333.9+6538' '3FGL J0419.1+6636' '3FGL...
# 19     ['3FGL J1303.0+2435' '3FGL J1310.6+2446' '3FGL...
# 20     ['3FGL J1224.5+2436' '3FGL J1230.3+2519' '3FGL...
# 21     ['3FGL J1037.0-2934' '3FGL J1045.7-2926' '3FGL...
# 22     ['3FGL J0420.4-6013' '3FGL J0434.0-5726' '3FGL...
# 23     ['3FGL J1052.0+0816' '3FGL J1103.1+1155' '3FGL...
# 24     ['3FGL J1340.6+4412' '3FGL J1330.0+4437' '3FGL...
# 25     ['3FGL J1342.4-6904' '3FGL J1424.6-6807' '3FGL...
# 26     ['3FGL J1224.6+4332' '3FGL J1231.6+4825' '3FGL...
# 27     ['3FGL J0240.0-0253' '3FGL J0253.0-0125' '3FGL...
# 28     ['3FGL J1229.1+0202' '3FGL J1205.4+0412' '3FGL...
# 29     ['3FGL J1258.4+2123' '3FGL J1254.5+2210' '3FGL...
# ...                                                  ...
# 16990  ['3FGL J1033.8+6051' '3FGL J1027.7+6316' '3FGL...
# 16991  ['3FGL J0724.1+2857' '3FGL J0719.3+3307' '3FGL...
# 16992  ['3FGL J1259.5-3231' '3FGL J1249.1-2808' '3FGL...
# 16993  ['3FGL J1351.4+1115' '3FGL J1403.1+1304' '3FGL...
# 16994  ['3FGL J1454.5+5124' '3FGL J1450.9+5200' '3FGL...
# 16995          ['3FGL J0958.6-2447' '3FGL J1006.7-2159']
# 16996                              ['3FGL J0339.5-0146']
# 16997  ['3FGL J1412.0+5249' '3FGL J1419.9+5425' '3FGL...
# 16998  ['3FGL J0043.7-1117' '3FGL J0039.1-0939' '3FGL...
# 16999  ['3FGL J0203.1-0227' '3FGL J0158.6+0102' '3FGL...
# 17000  ['3FGL J1546.0+0818' '3FGL J1541.8+1105' '3FGL...
# 17001  ['3FGL J1203.2+3847' '3FGL J1146.8+3958' '3FGL...
# 17002  ['3FGL J0957.6+5523' '3FGL J1035.2+5545' '3FGL...
# 17003  ['3FGL J2225.8-0454' '3FGL J2247.2-0004' '3FGL...
# 17004  ['3FGL J1725.3+5853' '3FGL J1732.7+5914' '3FGL...
# 17005  ['3FGL J1051.8+0105' '3FGL J1058.5+0133' '3FGL...
# 17006  ['3FGL J1051.8+0105' '3FGL J1058.5+0133' '3FGL...
# 17007  ['3FGL J1534.4+5323' '3FGL J1553.1+5437' '3FGL...
# 17008  ['3FGL J0854.2+4408' '3FGL J0903.1+4649' '3FGL...
# 17009  ['3FGL J1616.8+4111' '3FGL J1625.9+4125' '3FGL...
# 17010  ['3FGL J0905.8-2127' '3FGL J0912.9-2104' '3FGL...
# 17011  ['3FGL J0926.3+5409' '3FGL J0851.8+5531' '3FGL...
# 17012  ['3FGL J1112.4+3449' '3FGL J1109.6+3734' '3FGL...
# 17013  ['3FGL J2327.7+0941' '3FGL J2330.5+1104' '3FGL...
# 17014  ['3FGL J0112.8+3207' '3FGL J0122.8+3423' '3FGL...
# 17015  ['3FGL J1341.0+3955' '3FGL J1309.3+4304' '3FGL...
# 17016  ['3FGL J1112.1+0500' '3FGL J1120.6+0713' '3FGL...
# 17017  ['3FGL J0804.4+0418' '3FGL J0747.4+0904' '3FGL...
# 17018  ['3FGL J0401.8-3144' '3FGL J0351.0-2816' '3FGL...
# 17019  ['3FGL J1303.0+2435' '3FGL J1310.6+2446' '3FGL...
#
#                                                  3FGL 10  N3FGL 5   ang_ext  \
# 0      ['3FGL J0058.3+3315' '3FGL J0043.8+3425' '3FGL...        9  5.135987
# 1      ['3FGL J1222.4+0414' '3FGL J1239.5+0443' '3FGL...        7  2.311796
# 2      ['3FGL J1325.2-5411' '3FGL J1315.1-5329' '3FGL...       13  1.755233
# 3      ['3FGL J0058.0-3233' '3FGL J0032.3-2852' '3FGL...        9  1.534425
# 4      ['3FGL J0253.8+5104' '3FGL J0248.4+5130' '3FGL...       14  1.426288
# 5      ['3FGL J2006.0-2311' '3FGL J2010.0-2120' '3FGL...        7  1.545158
# 6      ['3FGL J0925.6+5959' '3FGL J1031.6+6021' '3FGL...        6  1.272105
# 7      ['3FGL J1244.3-4955' '3FGL J1251.0-4943' '3FGL...        7  0.955250
# 8      ['3FGL J0335.3-4459' '3FGL J0334.3-4008' '3FGL...        6  0.894083
# 9      ['3FGL J0358.8+6002' '3FGL J0348.4+6039' '3FGL...        5  0.863237
# 10     ['3FGL J1238.2-1958' '3FGL J1258.6-1800' '3FGL...        5  0.855684
# 11     ['3FGL J1557.4-7040' '3FGL J1610.8-6649' '3FGL...        8  0.785398
# 12     ['3FGL J0051.0-0649' '3FGL J0125.2-0627' '3FGL...        7  0.958842
# 13     ['3FGL J0336.5+3210' '3FGL J0325.2+3410' '3FGL...        7  0.745394
# 14     ['3FGL J1310.6+3222' '3FGL J1258.1+3233' '3FGL...        6  0.757171
# 15     ['3FGL J1112.1+0500' '3FGL J1120.6+0713' '3FGL...        5  0.709330
# 16     ['3FGL J0335.3-4459' '3FGL J0334.3-4008' '3FGL...        6  0.644809
# 17     ['3FGL J1323.2-3901' '3FGL J1330.0-3818' '3FGL...        6  0.664980
# 18     ['3FGL J0327.4+5828c' '3FGL J0358.8+6002' '3FG...        4  0.683014
# 19     ['3FGL J1258.4+2123' '3FGL J1254.5+2210' '3FGL...        4  0.633206
# 20     ['3FGL J1244.1+1615' '3FGL J1232.3+1701' '3FGL...        5  0.610114
# 21     ['3FGL J1007.4-3334' '3FGL J1024.1-3232' '3FGL...        8  0.603607
# 22     ['3FGL J0343.3-6443' '3FGL J0516.7-6207' '3FGL...        5  0.594820
# 23     ['3FGL J1050.4+0435' '3FGL J1112.1+0500' '3FGL...        5  0.586436
# 24     ['3FGL J1341.0+3955' '3FGL J1309.3+4304' '3FGL...        7  0.603731
# 25     ['3FGL J1348.5-7150' '3FGL J1444.0-7033' '3FGL...       15  0.644293
# 26     ['3FGL J1203.2+3847' '3FGL J1236.6+3901' '3FGL...        7  0.593810
# 27     ['3FGL J0234.2-0629' '3FGL J0242.1-0534' '3FGL...        5  0.572504
# 28     ['3FGL J1228.4-0317' '3FGL J1219.7-0314' '3FGL...        5  0.562920
# 29     ['3FGL J1304.6+1200' '3FGL J1232.8+1332' '3FGL...        5  0.572362
# ...                                                  ...      ...       ...
# 16990  ['3FGL J1035.2+5545' '3FGL J1058.6+5627' '3FGL...        6  0.014571
# 16991  ['3FGL J0723.7+2050' '3FGL J0708.9+2239' '3FGL...        3  0.013697
# 16992  ['3FGL J1259.8-3749' '3FGL J1232.5-3720' '3FGL...        3  0.014594
# 16993  ['3FGL J1351.1+0030' '3FGL J1357.5+0125' '3FGL...        3  0.014606
# 16994  ['3FGL J1531.8+4704' '3FGL J1500.6+4750' '3FGL...        8  0.014448
# 16995  ['3FGL J1008.9-2910' '3FGL J1002.0-2837' '3FGL...        2  0.013638
# 16996  ['3FGL J0324.5-1315' '3FGL J0405.5-1307' '3FGL...        1  0.014558
# 16997  ['3FGL J1415.2+4832' '3FGL J1440.1+4955' '3FGL...        6  0.014454
# 16998  ['3FGL J0033.6-1921' '3FGL J0022.1-1855' '3FGL...        5  0.014414
# 16999  ['3FGL J0217.1-0833' '3FGL J0211.2-0649' '3FGL...        6  0.014707
# 17000  ['3FGL J1534.5+0128' '3FGL J1549.4+0237' '3FGL...        4  0.014358
# 17001  ['3FGL J1205.9+3315' '3FGL J1136.4+3405' '3FGL...        7  0.014256
# 17002  ['3FGL J0954.2+4913' '3FGL J1015.0+4925' '3FGL...        8  0.014413
# 17003  ['3FGL J2229.7-0833' '3FGL J2225.8-0454' '3FGL...        5  0.014162
# 17004  ['3FGL J1740.4+5347' '3FGL J1731.9+5428' '3FGL...       10  0.014106
# 17005  ['3FGL J1125.8-0745' '3FGL J1115.0-0701' '3FGL...        5  0.014099
# 17006  ['3FGL J1028.5-0235' '3FGL J1022.8-0113' '3FGL...        7  0.014117
# 17007  ['3FGL J1531.8+4704' '3FGL J1544.0+4938' '3FGL...       10  0.013846
# 17008  ['3FGL J0910.7+3858' '3FGL J0928.5+4048' '3FGL...        5  0.014003
# 17009  ['3FGL J1626.1+3512' '3FGL J1630.2+3733' '3FGL...        7  0.013734
# 17010  ['3FGL J0846.8-2638' '3FGL J0846.9-2336' '3FGL...        3  0.012737
# 17011  ['3FGL J0850.0+4855' '3FGL J0954.2+4913' '3FGL...        5  0.014130
# 17012  ['3FGL J1136.4+3405' '3FGL J1112.4+3449' '3FGL...        8  0.013586
# 17013  ['3FGL J2344.4+0549' '3FGL J2346.7+0705' '3FGL...        7  0.013463
# 17014  ['3FGL J0115.8+2519' '3FGL J0127.9+2551' '3FGL...        3  0.012345
# 17015  ['3FGL J1330.5+3023' '3FGL J1310.6+3222' '3FGL...        4  0.012424
# 17016  ['3FGL J1132.7+0034' '3FGL J1051.8+0105' '3FGL...        5  0.011270
# 17017  ['3FGL J0805.2-0112' '3FGL J0739.4+0137' '3FGL...        7  0.011277
# 17018  ['3FGL J0353.0-3622' '3FGL J0403.9-3604' '3FGL...        7  0.011226
# 17019  ['3FGL J1258.4+2123' '3FGL J1254.5+2210' '3FGL...        3  0.010388
#
#        theta_vir  log10M200_inf          ra        dec          dA
# 0      28.262611      12.373503   11.102555  41.063681    0.749999
# 1       7.355798      14.567979  187.705935  12.391097   15.760002
# 2       8.628832      12.878869  199.624611 -45.529967    3.630004
# 3       7.847010      12.705191   11.885476 -25.208151    3.490001
# 4       7.415162      12.620733   39.905069  59.608401    3.460004
# 5      11.686972      10.650543  296.237312 -14.800367    0.480004
# 6       6.712719      12.561222  149.071762  69.216095    3.650005
# 7       3.056262      14.536811  191.984798 -41.220439   36.959993
# 8       3.502262      13.789868   54.318357 -35.389692   18.090007
# 9       3.645938      13.497669   60.297553  69.775669   13.860004
# 10      3.806401      13.290526  190.360654 -11.494487   11.310010
# 11      2.201042      15.011464  243.765304 -60.907172   73.990596
# 12      7.306475      10.602738   16.199159   2.117699    0.740000
# 13      2.100041      14.990772   49.951166  41.511588   76.296565
# 14      4.289759      12.232489  192.236737  41.363663    4.430001
# 15      3.422675      12.953364  169.884334  13.130944    9.690002
# 16      2.729278      13.485856   54.615768 -35.452772   18.339995
# 17      3.807021      12.181818  204.253781 -29.860148    4.799999
# 18      4.220214      11.802070   57.588567  67.967516    3.229999
# 19      1.708564      15.139735  195.033512  27.976967  105.037926
# 20      2.837921      13.106165  188.681077  25.918858   13.149994
# 21      2.035584      14.337423  159.086467 -27.562851   47.490002
# 22      2.590622      13.371901   64.371775 -55.781093   17.689996
# 23      2.890306      12.863110  162.115664  12.581576   10.700008
# 24      3.138885      12.615834  202.483704  47.222512    8.139996
# 25      4.185810      11.537499  213.291207 -65.338867    2.655259
# 26      3.185329      12.486827  184.417112  47.169910    7.259999
# 27      2.585161      13.227171   40.669406   0.090571   15.849997
# 28      2.152559      13.874240  184.897374   5.894650   31.389997
# 29      3.337313      12.092383  194.182766  21.681504    5.109998
# ...          ...            ...         ...        ...         ...
# 16990   0.109840      10.617336  160.244213  65.515150   49.598882
# 16991   0.097796      10.930336  109.174294  30.263444   70.789994
# 16992   0.110925      10.567502  192.020836 -28.309108   47.271712
# 16993   0.111144      10.560525  211.611294   9.359096   46.926684
# 16994   0.108670      10.630299  226.726506  55.538355   50.632190
# 16995   0.097110      10.945290  150.385118 -20.382800   72.110000
# 16996   0.110720      10.563517   54.690512  -5.645046   47.214212
# 16997   0.109039      10.612358  216.687830  56.677618   49.771142
# 16998   0.108570      10.621330    7.919830  -9.576287   50.330871
# 16999   0.113973      10.447892   34.121938   1.256044   41.973826
# 17000   0.109404      10.551566  232.737811  11.285415   47.343584
# 17001   0.108152      10.577484  179.906206  41.750905   48.852225
# 17002   0.111622      10.450893  155.948985  56.816356   42.953985
# 17003   0.107735      10.560545  337.323954  -0.521227   48.406951
# 17004   0.107665      10.540614  261.876846  62.457973   47.702902
# 17005   0.108213      10.505726  166.420972  -0.100246   46.207657
# 17006   0.109119      10.461869  160.696084   4.531108   44.308013
# 17007   0.105420      10.554580  234.686845  56.713997   49.239952
# 17008   0.108737      10.432969  135.017448  48.627952   43.487078
# 17009   0.104983      10.529666  245.707867  45.071352   48.507507
# 17010   0.089812      10.994201  135.742607 -18.029836   80.910004
# 17011   0.111712      10.303320  138.569243  57.044266   38.322262
# 17012   0.104286      10.502759  165.541865  39.312299   47.832238
# 17013   0.104563      10.430003  351.527878  14.264073   45.114173
# 17014   0.089453      10.838742   22.202881  34.345695   72.110000
# 17015   0.096858      10.402140  201.846988  40.367735   47.659788
# 17016   0.078877      11.024256  168.064318   8.628773   94.189997
# 17017   0.084490      10.638469  120.196146   8.638977   65.460000
# 17018   0.088146      10.346361   62.707502 -27.499882   50.158666
# 17019   0.083360      10.193839  194.922106  27.837325   47.171086
#
# [17020 rows x 36 columns]

# %%
catalog_file
# Out:
#        Unnamed: 0                     Name  mulog10J_inf  siglog10J_inf  \
# 0            3072                Andromeda     19.793990       0.484544
# 1             210                  NGC4472     19.115659       0.442160
# 2            2565                  NGC5128     18.896069       0.487509
# 3            3211                  NGC0253     18.761680       0.484926
# 4            3239                 Maffei 1     18.688100       0.484148
# 5            3074                 NGC 6822     18.594351       0.507664
# 6            2809                  NGC3031     18.588134       0.484121
# 7               0                  NGC4696     18.346298       0.441808
# 8             906                  NGC1399     18.310999       0.467987
# 9            2153                   IC0356     18.271854       0.465904
# 10            211                  NGC4594     18.266314       0.467055
# 11          24625           ESO_137-_G_006     18.181355       0.420443
# 12           3075                  IC 1613     18.172924       0.507565
# 13          22884                 NGC_1275     18.137190       0.420847
# 14           2171                  NGC4736     18.126561       0.485348
# 15            214                  NGC3627     18.113302       0.471131
# 16            907                  NGC1316     18.017668       0.465841
# 17           2566                  NGC5236     18.012553       0.485742
# 18           3241                   IC0342     18.010387       0.499073
# 19          13004         13000812+2758370     17.985449       0.417508
# 20            212                  NGC4565     17.977258       0.469035
# 21            851                  NGC3311     17.952325       0.442786
# 22            908                  NGC1553     17.948257       0.466332
# 23            217                  NGC3379     17.941030       0.487078
# 24           2168                  NGC5194     17.939911       0.484030
# 25           2567               ESO097-013     17.929128       0.497620
# 26           2169                  NGC4258     17.923418       0.484114
# 27           1928                  NGC1068     17.918369       0.467608
# 28           1069                  NGC4261     17.913938       0.469630
# 29           2173                  NGC4826     17.880412       0.486532
# ...           ...                      ...           ...            ...
# 16990        8039               PGC3139929     14.530082       0.506912
# 16991        6094                PGC090776     14.525720       0.508806
# 16992         209               PGC5065966     14.525030       0.506901
# 16993        8231               PGC2801013     14.524877       0.506904
# 16994        2854  SDSSJ150654.39+553218.0     14.524399       0.506922
# 16995        6093               ESO567-006     14.524236       0.499563
# 16996        8227               PGC1042130     14.522352       0.506901
# 16997        5555  SDSSJ142645.04+564039.7     14.522333       0.506902
# 16998        8020                PGC989253     14.521085       0.506909
# 16999        8476  SDSSJ021629.26+011521.8     14.517159       0.507077
# 17000        8263                AGC258133     14.508763       0.506899
# 17001        6109  SDSSJ115937.48+414503.5     14.505703       0.506882
# 17002        8469  SDSSJ102347.79+564859.2     14.499796       0.507057
# 17003        8233  SDSSJ222917.74-003116.2     14.497791       0.506884
# 17004        2727  SDSSJ172730.51+622729.0     14.491895       0.506895
# 17005        8358                PGC135771     14.487003       0.506929
# 17006        8451  SDSSJ104247.04+043152.0     14.482864       0.507015
# 17007        1762  SDSSJ153844.84+564250.6     14.477307       0.506872
# 17008        4079  SDSSJ090004.16+483740.9     14.472498       0.507091
# 17009        8309               PGC3130829     14.467023       0.506885
# 17010        5584               ESO564-012     14.466540       0.499045
# 17011        8666  SDSSJ091416.59+570239.6     14.461571       0.507380
# 17012        8371               PGC2147507     14.454076       0.506909
# 17013        8506               PGC2816191     14.437717       0.507075
# 17014        6191                 UGC01054     14.417521       0.507730
# 17015        8552  SDSSJ132723.28+402204.1     14.364067       0.507106
# 17016        5142                PGC091091     14.359897       0.498616
# 17017        6797                PGC090815     14.307778       0.506731
# 17018        8633       6dFJ0410498-272959     14.267539       0.507184
# 17019        8733          [MBC2001]039119     14.181099       0.507780
#
#        mulog10Jnb_inf  siglog10Jnb_inf  mulog10JB_inf  siglog10JB_inf  \
# 0           19.233062         0.479658      19.585515        0.523228
# 1           18.372857         0.430687      18.864802        0.483077
# 2           18.279186         0.470543      18.679241        0.526266
# 3           18.170785         0.473790      18.547804        0.523796
# 4           18.106905         0.475097      18.475447        0.523035
# 5           18.163484         0.502497      18.408005        0.543038
# 6           18.012834         0.476316      18.376581        0.522970
# 7           17.606330         0.431194      18.095882        0.482807
# 8           17.623174         0.450596      18.076683        0.508085
# 9           17.618154         0.457431      18.043422        0.506344
# 10          17.626789         0.462009      18.041887        0.507448
# 11          17.391060         0.417773      17.920313        0.461735
# 12          17.746147         0.502980      17.987069        0.542894
# 13          17.347323         0.418313      17.876573        0.462179
# 14          17.573172         0.481917      17.920203        0.523866
# 15          17.486622         0.468970      17.895070        0.511159
# 16          17.364965         0.457613      17.789404        0.506289
# 17          17.461347         0.482721      17.806950        0.524189
# 18          17.488224         0.488461      17.810227        0.536226
# 19          17.192036         0.413819      17.721379        0.458485
# 20          17.345931         0.465860      17.756246        0.509263
# 21          17.226414         0.436346      17.706125        0.484151
# 22          17.303915         0.460144      17.722203        0.506772
# 23          17.326907         0.470741      17.724394        0.525862
# 24          17.359236         0.475088      17.727261        0.522925
# 25          17.435591         0.492103      17.732481        0.534612
# 26          17.354519         0.477629      17.713074        0.522914
# 27          17.282051         0.463304      17.695093        0.507959
# 28          17.211955         0.448341      17.677724        0.509514
# 29          17.332507         0.484119      17.676126        0.524845
# ...               ...              ...            ...             ...
# 16990       14.102154         0.502158      14.343513        0.542358
# 16991       14.060984         0.498504      14.335529        0.544484
# 16992       14.101059         0.502704      14.339008        0.542291
# 16993       14.101427         0.502781      14.338931        0.542286
# 16994       14.095372         0.502012      14.337684        0.542382
# 16995       14.057657         0.498317      14.333862        0.535874
# 16996       14.098681         0.502746      14.336372        0.542286
# 16997       14.094820         0.502206      14.335813        0.542343
# 16998       14.092823         0.502107      14.334466        0.542360
# 16999       14.101125         0.503969      14.332411        0.542321
# 17000       14.085972         0.502867      14.322906        0.542272
# 17001       14.080974         0.502579      14.319558        0.542286
# 17002       14.083587         0.503926      14.315006        0.542307
# 17003       14.074341         0.502760      14.311828        0.542269
# 17004       14.069893         0.502973      14.306146        0.542257
# 17005       14.067388         0.503335      14.301620        0.542250
# 17006       14.066006         0.503797      14.297946        0.542282
# 17007       14.054298         0.502810      14.291397        0.542252
# 17008       14.057319         0.504098      14.287885        0.542319
# 17009       14.045791         0.503069      14.281375        0.542237
# 17010       13.998835         0.497635      14.275508        0.535453
# 17011       14.052740         0.505220      14.278128        0.542463
# 17012       14.034657         0.503342      14.268704        0.542230
# 17013       14.022705         0.504105      14.253114        0.542304
# 17014       13.966075         0.499494      14.228323        0.543384
# 17015       13.950569         0.504337      14.179708        0.542306
# 17016       13.891439         0.497096      14.168362        0.535100
# 17017       13.878061         0.501719      14.120804        0.542230
# 17018       13.856805         0.504777      14.083649        0.542328
# 17019       13.776387         0.506142      13.998623        0.542730
#
#        mulog10JBnb_inf  siglog10JBnb_inf     ...      \
# 0            19.024586          0.518707     ...
# 1            18.121999          0.472598     ...
# 2            18.062358          0.510589     ...
# 3            17.956908          0.513503     ...
# 4            17.894252          0.514669     ...
# 5            17.977139          0.538211     ...
# 6            17.801281          0.515753     ...
# 7            17.355914          0.473114     ...
# 8            17.388858          0.492113     ...
# 9            17.389723          0.498558     ...
# 10           17.402363          0.502807     ...
# 11           17.130018          0.459306     ...
# 12           17.560292          0.538610     ...
# 13           17.086706          0.459873     ...
# 14           17.366813          0.520689     ...
# 15           17.268390          0.509168     ...
# 16           17.136701          0.498729     ...
# 17           17.255744          0.521391     ...
# 18           17.288064          0.526364     ...
# 19           16.927965          0.455128     ...
# 20           17.124920          0.506341     ...
# 21           16.980214          0.478268     ...
# 22           17.077860          0.501083     ...
# 23           17.110271          0.510768     ...
# 24           17.146586          0.514660     ...
# 25           17.238943          0.529480     ...
# 26           17.144175          0.516916     ...
# 27           17.058774          0.504000     ...
# 28           16.975741          0.489960     ...
# 29           17.128221          0.522609     ...
# ...                ...               ...     ...
# 16990        13.915585          0.537917     ...
# 16991        13.870793          0.534870     ...
# 16992        13.915037          0.538370     ...
# 16993        13.915482          0.538434     ...
# 16994        13.908657          0.537796     ...
# 16995        13.867283          0.534713     ...
# 16996        13.912701          0.538405     ...
# 16997        13.908300          0.537957     ...
# 16998        13.906204          0.537875     ...
# 16999        13.916377          0.539417     ...
# 17000        13.900115          0.538505     ...
# 17001        13.894830          0.538266     ...
# 17002        13.898797          0.539380     ...
# 17003        13.888379          0.538416     ...
# 17004        13.884144          0.538592     ...
# 17005        13.882005          0.538892     ...
# 17006        13.881089          0.539274     ...
# 17007        13.868388          0.538457     ...
# 17008        13.872706          0.539522     ...
# 17009        13.860142          0.538672     ...
# 17010        13.807803          0.534140     ...
# 17011        13.869297          0.540443     ...
# 17012        13.849285          0.538897     ...
# 17013        13.838103          0.539528     ...
# 17014        13.776878          0.535696     ...
# 17015        13.766211          0.539718     ...
# 17016        13.699903          0.533684     ...
# 17017        13.691086          0.537550     ...
# 17018        13.672915          0.540079     ...
# 17019        13.593911          0.541198     ...
#
#                                                   3FGL 2  \
# 0      ['3FGL J0048.0+3950' '3FGL J0040.3+4049' '3FGL...
# 1      ['3FGL J1223.2+1215' '3FGL J1230.9+1224' '3FGL...
# 2                                  ['3FGL J1326.2-4651']
# 3              ['3FGL J0047.5-2516' '3FGL J0054.8-2455']
# 4      ['3FGL J0254.2+5903' '3FGL J0248.5+6022' '3FGL...
# 5                                  ['3FGL J1949.5-1454']
# 6                                  ['3FGL J0955.4+6940']
# 7                                                     []
# 8                                  ['3FGL J0336.9-3622']
# 9                                                     []
# 10                                 ['3FGL J1239.1-1158']
# 11             ['3FGL J1630.3-6126' '3FGL J1603.7-6011']
# 12                                 ['3FGL J0108.7+0134']
# 13             ['3FGL J0316.6+4119' '3FGL J0319.8+4130']
# 14                                                    []
# 15                                                    []
# 16                                 ['3FGL J0336.9-3622']
# 17                                 ['3FGL J1335.4-2949']
# 18                                                    []
# 19                                                    []
# 20                                 ['3FGL J1230.3+2519']
# 21                                 ['3FGL J1037.5-2821']
# 22                                                    []
# 23                                 ['3FGL J1049.8+1425']
# 24                                 ['3FGL J1331.8+4718']
# 25     ['3FGL J1412.3-6635' '3FGL J1413.2-6518' '3FGL...
# 26                                                    []
# 27                                 ['3FGL J0242.7-0001']
# 28             ['3FGL J1222.4+0414' '3FGL J1226.8+0638']
# 29             ['3FGL J1258.4+2123' '3FGL J1254.5+2210']
# ...                                                  ...
# 16990                              ['3FGL J1032.5+6623']
# 16991                                                 []
# 16992                              ['3FGL J1249.1-2808']
# 16993                                                 []
# 16994          ['3FGL J1502.2+5553' '3FGL J1509.7+5556']
# 16995                                                 []
# 16996                                                 []
# 16997          ['3FGL J1436.8+5639' '3FGL J1422.8+5801']
# 16998                              ['3FGL J0039.1-0939']
# 16999          ['3FGL J0217.8+0143' '3FGL J0216.0+0300']
# 17000                                                 []
# 17001  ['3FGL J1153.4+4033' '3FGL J1209.4+4119' '3FGL...
# 17002  ['3FGL J1035.2+5545' '3FGL J1016.1+5555' '3FGL...
# 17003                              ['3FGL J2227.8+0040']
# 17004          ['3FGL J1729.0+6049' '3FGL J1722.7+6104']
# 17005                                                 []
# 17006          ['3FGL J1050.4+0435' '3FGL J1040.4+0615']
# 17007                              ['3FGL J1531.0+5737']
# 17008          ['3FGL J0903.1+4649' '3FGL J0850.0+4855']
# 17009                              ['3FGL J1616.4+4631']
# 17010                                                 []
# 17011                              ['3FGL J0915.0+5844']
# 17012  ['3FGL J1104.4+3812' '3FGL J1100.5+4020' '3FGL...
# 17013                                                 []
# 17014                              ['3FGL J0122.8+3423']
# 17015                                                 []
# 17016                              ['3FGL J1112.1+1034']
# 17017          ['3FGL J0757.0+0956' '3FGL J0802.0+1005']
# 17018                                                 []
# 17019                                                 []
#
#                                                   3FGL 5  \
# 0      ['3FGL J0041.9+3639' '3FGL J0032.5+3912' '3FGL...
# 1      ['3FGL J1223.3+0818' '3FGL J1223.2+1215' '3FGL...
# 2      ['3FGL J1305.4-4926' '3FGL J1328.5-4728' '3FGL...
# 3      ['3FGL J0032.3-2852' '3FGL J0047.5-2516' '3FGL...
# 4      ['3FGL J0250.6+5630' '3FGL J0235.7+5647' '3FGL...
# 5      ['3FGL J2001.0-1750' '3FGL J1955.0-1605' '3FGL...
# 6      ['3FGL J0958.6+6534' '3FGL J0919.4+6604' '3FGL...
# 7      ['3FGL J1238.3-4543' '3FGL J1254.9-4423' '3FGL...
# 8      ['3FGL J0334.3-4008' '3FGL J0334.3-3726' '3FGL...
# 9      ['3FGL J0333.9+6538' '3FGL J0419.1+6636' '3FGL...
# 10     ['3FGL J1241.6-1456' '3FGL J1231.2-1411' '3FGL...
# 11     ['3FGL J1558.9-6432' '3FGL J1630.3-6126' '3FGL...
# 12     ['3FGL J0059.2-0152' '3FGL J0108.5-0035' '3FGL...
# 13     ['3FGL J0310.8+3814' '3FGL J0342.2+3857' '3FGL...
# 14     ['3FGL J1256.9+3649' '3FGL J1249.7+3705' '3FGL...
# 15     ['3FGL J1132.8+1015' '3FGL J1112.1+1034' '3FGL...
# 16     ['3FGL J0334.3-4008' '3FGL J0334.3-3726' '3FGL...
# 17     ['3FGL J1345.9-3357' '3FGL J1346.9-2958' '3FGL...
# 18     ['3FGL J0333.9+6538' '3FGL J0419.1+6636' '3FGL...
# 19     ['3FGL J1303.0+2435' '3FGL J1310.6+2446' '3FGL...
# 20     ['3FGL J1224.5+2436' '3FGL J1230.3+2519' '3FGL...
# 21     ['3FGL J1037.0-2934' '3FGL J1045.7-2926' '3FGL...
# 22     ['3FGL J0420.4-6013' '3FGL J0434.0-5726' '3FGL...
# 23     ['3FGL J1052.0+0816' '3FGL J1103.1+1155' '3FGL...
# 24     ['3FGL J1340.6+4412' '3FGL J1330.0+4437' '3FGL...
# 25     ['3FGL J1342.4-6904' '3FGL J1424.6-6807' '3FGL...
# 26     ['3FGL J1224.6+4332' '3FGL J1231.6+4825' '3FGL...
# 27     ['3FGL J0240.0-0253' '3FGL J0253.0-0125' '3FGL...
# 28     ['3FGL J1229.1+0202' '3FGL J1205.4+0412' '3FGL...
# 29     ['3FGL J1258.4+2123' '3FGL J1254.5+2210' '3FGL...
# ...                                                  ...
# 16990  ['3FGL J1033.8+6051' '3FGL J1027.7+6316' '3FGL...
# 16991  ['3FGL J0724.1+2857' '3FGL J0719.3+3307' '3FGL...
# 16992  ['3FGL J1259.5-3231' '3FGL J1249.1-2808' '3FGL...
# 16993  ['3FGL J1351.4+1115' '3FGL J1403.1+1304' '3FGL...
# 16994  ['3FGL J1454.5+5124' '3FGL J1450.9+5200' '3FGL...
# 16995          ['3FGL J0958.6-2447' '3FGL J1006.7-2159']
# 16996                              ['3FGL J0339.5-0146']
# 16997  ['3FGL J1412.0+5249' '3FGL J1419.9+5425' '3FGL...
# 16998  ['3FGL J0043.7-1117' '3FGL J0039.1-0939' '3FGL...
# 16999  ['3FGL J0203.1-0227' '3FGL J0158.6+0102' '3FGL...
# 17000  ['3FGL J1546.0+0818' '3FGL J1541.8+1105' '3FGL...
# 17001  ['3FGL J1203.2+3847' '3FGL J1146.8+3958' '3FGL...
# 17002  ['3FGL J0957.6+5523' '3FGL J1035.2+5545' '3FGL...
# 17003  ['3FGL J2225.8-0454' '3FGL J2247.2-0004' '3FGL...
# 17004  ['3FGL J1725.3+5853' '3FGL J1732.7+5914' '3FGL...
# 17005  ['3FGL J1051.8+0105' '3FGL J1058.5+0133' '3FGL...
# 17006  ['3FGL J1051.8+0105' '3FGL J1058.5+0133' '3FGL...
# 17007  ['3FGL J1534.4+5323' '3FGL J1553.1+5437' '3FGL...
# 17008  ['3FGL J0854.2+4408' '3FGL J0903.1+4649' '3FGL...
# 17009  ['3FGL J1616.8+4111' '3FGL J1625.9+4125' '3FGL...
# 17010  ['3FGL J0905.8-2127' '3FGL J0912.9-2104' '3FGL...
# 17011  ['3FGL J0926.3+5409' '3FGL J0851.8+5531' '3FGL...
# 17012  ['3FGL J1112.4+3449' '3FGL J1109.6+3734' '3FGL...
# 17013  ['3FGL J2327.7+0941' '3FGL J2330.5+1104' '3FGL...
# 17014  ['3FGL J0112.8+3207' '3FGL J0122.8+3423' '3FGL...
# 17015  ['3FGL J1341.0+3955' '3FGL J1309.3+4304' '3FGL...
# 17016  ['3FGL J1112.1+0500' '3FGL J1120.6+0713' '3FGL...
# 17017  ['3FGL J0804.4+0418' '3FGL J0747.4+0904' '3FGL...
# 17018  ['3FGL J0401.8-3144' '3FGL J0351.0-2816' '3FGL...
# 17019  ['3FGL J1303.0+2435' '3FGL J1310.6+2446' '3FGL...
#
#                                                  3FGL 10  N3FGL 5   ang_ext  \
# 0      ['3FGL J0058.3+3315' '3FGL J0043.8+3425' '3FGL...        9  5.135987
# 1      ['3FGL J1222.4+0414' '3FGL J1239.5+0443' '3FGL...        7  2.311796
# 2      ['3FGL J1325.2-5411' '3FGL J1315.1-5329' '3FGL...       13  1.755233
# 3      ['3FGL J0058.0-3233' '3FGL J0032.3-2852' '3FGL...        9  1.534425
# 4      ['3FGL J0253.8+5104' '3FGL J0248.4+5130' '3FGL...       14  1.426288
# 5      ['3FGL J2006.0-2311' '3FGL J2010.0-2120' '3FGL...        7  1.545158
# 6      ['3FGL J0925.6+5959' '3FGL J1031.6+6021' '3FGL...        6  1.272105
# 7      ['3FGL J1244.3-4955' '3FGL J1251.0-4943' '3FGL...        7  0.955250
# 8      ['3FGL J0335.3-4459' '3FGL J0334.3-4008' '3FGL...        6  0.894083
# 9      ['3FGL J0358.8+6002' '3FGL J0348.4+6039' '3FGL...        5  0.863237
# 10     ['3FGL J1238.2-1958' '3FGL J1258.6-1800' '3FGL...        5  0.855684
# 11     ['3FGL J1557.4-7040' '3FGL J1610.8-6649' '3FGL...        8  0.785398
# 12     ['3FGL J0051.0-0649' '3FGL J0125.2-0627' '3FGL...        7  0.958842
# 13     ['3FGL J0336.5+3210' '3FGL J0325.2+3410' '3FGL...        7  0.745394
# 14     ['3FGL J1310.6+3222' '3FGL J1258.1+3233' '3FGL...        6  0.757171
# 15     ['3FGL J1112.1+0500' '3FGL J1120.6+0713' '3FGL...        5  0.709330
# 16     ['3FGL J0335.3-4459' '3FGL J0334.3-4008' '3FGL...        6  0.644809
# 17     ['3FGL J1323.2-3901' '3FGL J1330.0-3818' '3FGL...        6  0.664980
# 18     ['3FGL J0327.4+5828c' '3FGL J0358.8+6002' '3FG...        4  0.683014
# 19     ['3FGL J1258.4+2123' '3FGL J1254.5+2210' '3FGL...        4  0.633206
# 20     ['3FGL J1244.1+1615' '3FGL J1232.3+1701' '3FGL...        5  0.610114
# 21     ['3FGL J1007.4-3334' '3FGL J1024.1-3232' '3FGL...        8  0.603607
# 22     ['3FGL J0343.3-6443' '3FGL J0516.7-6207' '3FGL...        5  0.594820
# 23     ['3FGL J1050.4+0435' '3FGL J1112.1+0500' '3FGL...        5  0.586436
# 24     ['3FGL J1341.0+3955' '3FGL J1309.3+4304' '3FGL...        7  0.603731
# 25     ['3FGL J1348.5-7150' '3FGL J1444.0-7033' '3FGL...       15  0.644293
# 26     ['3FGL J1203.2+3847' '3FGL J1236.6+3901' '3FGL...        7  0.593810
# 27     ['3FGL J0234.2-0629' '3FGL J0242.1-0534' '3FGL...        5  0.572504
# 28     ['3FGL J1228.4-0317' '3FGL J1219.7-0314' '3FGL...        5  0.562920
# 29     ['3FGL J1304.6+1200' '3FGL J1232.8+1332' '3FGL...        5  0.572362
# ...                                                  ...      ...       ...
# 16990  ['3FGL J1035.2+5545' '3FGL J1058.6+5627' '3FGL...        6  0.014571
# 16991  ['3FGL J0723.7+2050' '3FGL J0708.9+2239' '3FGL...        3  0.013697
# 16992  ['3FGL J1259.8-3749' '3FGL J1232.5-3720' '3FGL...        3  0.014594
# 16993  ['3FGL J1351.1+0030' '3FGL J1357.5+0125' '3FGL...        3  0.014606
# 16994  ['3FGL J1531.8+4704' '3FGL J1500.6+4750' '3FGL...        8  0.014448
# 16995  ['3FGL J1008.9-2910' '3FGL J1002.0-2837' '3FGL...        2  0.013638
# 16996  ['3FGL J0324.5-1315' '3FGL J0405.5-1307' '3FGL...        1  0.014558
# 16997  ['3FGL J1415.2+4832' '3FGL J1440.1+4955' '3FGL...        6  0.014454
# 16998  ['3FGL J0033.6-1921' '3FGL J0022.1-1855' '3FGL...        5  0.014414
# 16999  ['3FGL J0217.1-0833' '3FGL J0211.2-0649' '3FGL...        6  0.014707
# 17000  ['3FGL J1534.5+0128' '3FGL J1549.4+0237' '3FGL...        4  0.014358
# 17001  ['3FGL J1205.9+3315' '3FGL J1136.4+3405' '3FGL...        7  0.014256
# 17002  ['3FGL J0954.2+4913' '3FGL J1015.0+4925' '3FGL...        8  0.014413
# 17003  ['3FGL J2229.7-0833' '3FGL J2225.8-0454' '3FGL...        5  0.014162
# 17004  ['3FGL J1740.4+5347' '3FGL J1731.9+5428' '3FGL...       10  0.014106
# 17005  ['3FGL J1125.8-0745' '3FGL J1115.0-0701' '3FGL...        5  0.014099
# 17006  ['3FGL J1028.5-0235' '3FGL J1022.8-0113' '3FGL...        7  0.014117
# 17007  ['3FGL J1531.8+4704' '3FGL J1544.0+4938' '3FGL...       10  0.013846
# 17008  ['3FGL J0910.7+3858' '3FGL J0928.5+4048' '3FGL...        5  0.014003
# 17009  ['3FGL J1626.1+3512' '3FGL J1630.2+3733' '3FGL...        7  0.013734
# 17010  ['3FGL J0846.8-2638' '3FGL J0846.9-2336' '3FGL...        3  0.012737
# 17011  ['3FGL J0850.0+4855' '3FGL J0954.2+4913' '3FGL...        5  0.014130
# 17012  ['3FGL J1136.4+3405' '3FGL J1112.4+3449' '3FGL...        8  0.013586
# 17013  ['3FGL J2344.4+0549' '3FGL J2346.7+0705' '3FGL...        7  0.013463
# 17014  ['3FGL J0115.8+2519' '3FGL J0127.9+2551' '3FGL...        3  0.012345
# 17015  ['3FGL J1330.5+3023' '3FGL J1310.6+3222' '3FGL...        4  0.012424
# 17016  ['3FGL J1132.7+0034' '3FGL J1051.8+0105' '3FGL...        5  0.011270
# 17017  ['3FGL J0805.2-0112' '3FGL J0739.4+0137' '3FGL...        7  0.011277
# 17018  ['3FGL J0353.0-3622' '3FGL J0403.9-3604' '3FGL...        7  0.011226
# 17019  ['3FGL J1258.4+2123' '3FGL J1254.5+2210' '3FGL...        3  0.010388
#
#        theta_vir  log10M200_inf          ra        dec          dA
# 0      28.262611      12.373503   11.102555  41.063681    0.749999
# 1       7.355798      14.567979  187.705935  12.391097   15.760002
# 2       8.628832      12.878869  199.624611 -45.529967    3.630004
# 3       7.847010      12.705191   11.885476 -25.208151    3.490001
# 4       7.415162      12.620733   39.905069  59.608401    3.460004
# 5      11.686972      10.650543  296.237312 -14.800367    0.480004
# 6       6.712719      12.561222  149.071762  69.216095    3.650005
# 7       3.056262      14.536811  191.984798 -41.220439   36.959993
# 8       3.502262      13.789868   54.318357 -35.389692   18.090007
# 9       3.645938      13.497669   60.297553  69.775669   13.860004
# 10      3.806401      13.290526  190.360654 -11.494487   11.310010
# 11      2.201042      15.011464  243.765304 -60.907172   73.990596
# 12      7.306475      10.602738   16.199159   2.117699    0.740000
# 13      2.100041      14.990772   49.951166  41.511588   76.296565
# 14      4.289759      12.232489  192.236737  41.363663    4.430001
# 15      3.422675      12.953364  169.884334  13.130944    9.690002
# 16      2.729278      13.485856   54.615768 -35.452772   18.339995
# 17      3.807021      12.181818  204.253781 -29.860148    4.799999
# 18      4.220214      11.802070   57.588567  67.967516    3.229999
# 19      1.708564      15.139735  195.033512  27.976967  105.037926
# 20      2.837921      13.106165  188.681077  25.918858   13.149994
# 21      2.035584      14.337423  159.086467 -27.562851   47.490002
# 22      2.590622      13.371901   64.371775 -55.781093   17.689996
# 23      2.890306      12.863110  162.115664  12.581576   10.700008
# 24      3.138885      12.615834  202.483704  47.222512    8.139996
# 25      4.185810      11.537499  213.291207 -65.338867    2.655259
# 26      3.185329      12.486827  184.417112  47.169910    7.259999
# 27      2.585161      13.227171   40.669406   0.090571   15.849997
# 28      2.152559      13.874240  184.897374   5.894650   31.389997
# 29      3.337313      12.092383  194.182766  21.681504    5.109998
# ...          ...            ...         ...        ...         ...
# 16990   0.109840      10.617336  160.244213  65.515150   49.598882
# 16991   0.097796      10.930336  109.174294  30.263444   70.789994
# 16992   0.110925      10.567502  192.020836 -28.309108   47.271712
# 16993   0.111144      10.560525  211.611294   9.359096   46.926684
# 16994   0.108670      10.630299  226.726506  55.538355   50.632190
# 16995   0.097110      10.945290  150.385118 -20.382800   72.110000
# 16996   0.110720      10.563517   54.690512  -5.645046   47.214212
# 16997   0.109039      10.612358  216.687830  56.677618   49.771142
# 16998   0.108570      10.621330    7.919830  -9.576287   50.330871
# 16999   0.113973      10.447892   34.121938   1.256044   41.973826
# 17000   0.109404      10.551566  232.737811  11.285415   47.343584
# 17001   0.108152      10.577484  179.906206  41.750905   48.852225
# 17002   0.111622      10.450893  155.948985  56.816356   42.953985
# 17003   0.107735      10.560545  337.323954  -0.521227   48.406951
# 17004   0.107665      10.540614  261.876846  62.457973   47.702902
# 17005   0.108213      10.505726  166.420972  -0.100246   46.207657
# 17006   0.109119      10.461869  160.696084   4.531108   44.308013
# 17007   0.105420      10.554580  234.686845  56.713997   49.239952
# 17008   0.108737      10.432969  135.017448  48.627952   43.487078
# 17009   0.104983      10.529666  245.707867  45.071352   48.507507
# 17010   0.089812      10.994201  135.742607 -18.029836   80.910004
# 17011   0.111712      10.303320  138.569243  57.044266   38.322262
# 17012   0.104286      10.502759  165.541865  39.312299   47.832238
# 17013   0.104563      10.430003  351.527878  14.264073   45.114173
# 17014   0.089453      10.838742   22.202881  34.345695   72.110000
# 17015   0.096858      10.402140  201.846988  40.367735   47.659788
# 17016   0.078877      11.024256  168.064318   8.628773   94.189997
# 17017   0.084490      10.638469  120.196146   8.638977   65.460000
# 17018   0.088146      10.346361   62.707502 -27.499882   50.158666
# 17019   0.083360      10.193839  194.922106  27.837325   47.171086
#
# [17020 rows x 38 columns]

# %%
4e-27/3e-27
# Out:
# 1.3333333333333333

# %%
plot_data_sigmaconc0p24 = LimitPlot(data_dir='/tigress/nrodd/DM-Catalog-Scan/Scan-Small-ROI/data/Tully_sigmaconc0p24/////',
                        elephant=False, 
                        nmc=1,
                        bcut=20,
                        nonoverlap=False,
                        nonoverlapradius=2.,
                        cut_0p5=False,
                        xsecslim=10,
                        TS100=9,
                        TS1000=9,
                        halos_ran=350, 
                        halos_to_keep=350,
                        data_type="data",
                        file_prefix='LL2_TSmx_lim_b_emin4_emax30_o',
                        catalog_file="/tigress/nrodd/DM-Catalog-Scan/DataFiles/Catalogs/2MRSLocalTully_ALL_DATAPAPER_Planck15_0p24cvirerr_v7.csv",
                             skip_halos=[0,419]   )

# %%
data_ary_sigmaconc0p24, _, _ = plot_data_sigmaconc0p24.return_limits()

# %%
fig,ax = plt.subplots(1,figsize=(10/1.2,8/1.2))

# plt.plot(m_arr,data_lim,color='k',label=r'Galaxy groups (this work)',linewidth=2,linestyle='solid')
# plt.plot(m_arr,data_lim_nb,color='black',label=r'Galaxy groups (no boost)',linewidth=1,linestyle='dashed')

# fudge=1.0 
# plt.fill_between(m_arr,fudge*rot_q2p5,fudge*rot_q97p5,color='yellow',label=r'95\% containment',alpha=0.6)
# plt.fill_between(m_arr,fudge*rot_q16,fudge*rot_q84,color='limegreen',label=r'68\% containment',alpha=0.7)

# plt.plot(plot_data.marr,10**np.percentile(data_ary[-1], 2.5, axis=1), alpha=1, color='k',label=r'Baseline')
# plt.plot(plot_data.marr,10**np.percentile(data_ary_useboost[-1], 2.5, axis=1), alpha=1, color='k',label=r'$\rho_\mathrm{NFW}$-boosted profile',ls='--')
# plt.plot(plot_data.marr,10**np.percentile(data_ary_Burkert[-1], 2.5, axis=1), alpha=1, color='k',label=r'Burkert profile',ls='-.')
# plt.plot(plot_data.marr,10**np.percentile(data_ary_diemerconc[-1], 2.5, axis=1), alpha=1, color='k',label=r'Diemer concentration',ls=':')
plt.plot(plot_data.marr,10**np.percentile(data_ary_sigmaconc0p24[-1], 2.5, axis=1), alpha=1, color='k',label=r'Small errors concentration',ls=':')






plt.plot(thermal[::,0],thermal[::,1],linestyle='dotted',color='dimgrey',linewidth=1)
plt.text(380, 3.e-26, r'\emph{Thermal relic cross section}',fontsize=19.,color='dimgrey')
# plt.text(7000, 1.0e-27, r'$b \bar b$',fontsize=20,color='black')

# set the alpha value of the legend: it will be translucent
# leg.get_frame().set_alpha(0.1)

plt.xscale('log')
plt.yscale('log')
plt.xticks(fontsize=23);
plt.yticks(fontsize=23);
plt.xlabel(r"$m_\chi$ [GeV]",fontsize=23)
plt.ylabel(r"$\langle \sigma v \rangle$ [cm$^3$ s$^{-1}$]",fontsize=23)
#plt.legend(fontsize=18,loc = 2)

plt.xlim([1e1,1e4])
plt.ylim([8e-28,2e-22])

plt.text(200, 3.5e-27, r'\textbf{Stacked Galaxy Groups}',fontsize=22,color='black')
plt.text(70.3, 1.5e-27, r'Halo profile and concentration variations',fontsize=20,color='black')

plt.legend(ncol=1,fancybox=True,facecolor='none',frameon=False)

plt.tight_layout()

# plt.savefig(plots_dir + 'systematics_profile_conc.pdf',bbox_inches='tight')

# %%
plot_data_diemerconc = LimitPlot(data_dir='/tigress/nrodd/DM-Catalog-Scan/Scan-Small-ROI/data/Tully_diemerconc///',
                        elephant=False, 
                        nmc=1,
                        bcut=20,
                        nonoverlap=True,
                        nonoverlapradius=2.,
                        cut_0p5=False,
                        xsecslim=10,
                        TS100=9,
                        TS1000=9,
                        halos_ran=1000, 
                        halos_to_keep=1000,
                        data_type="data",
                        file_prefix='LL2_TSmx_lim_b_emin4_emax30_o',
                        catalog_file="/tigress/nrodd/DM-Catalog-Scan/DataFiles/Catalogs/2MRSLocalTully_ALL_DATAPAPER_Planck15_diemerconc_v7.csv"
                                )

# %%
data_ary_diemerconc, _,_ = plot_data_diemerconc.return_limits()

# %%
plot_data_gaoboost = LimitPlot(data_dir='/tigress/nrodd/DM-Catalog-Scan/Scan-Small-ROI/data/Tully_gaoboost////',
                        elephant=False, 
                        nmc=1,
                        bcut=20,
                        nonoverlap=True,
                        nonoverlapradius=2.,
                        cut_0p5=False,
                        xsecslim=10,
                        TS100=9,
                        TS1000=9,
                        halos_ran=1000, 
                        halos_to_keep=1000,
                        data_type="data",
                        file_prefix='LL2_TSmx_lim_b_emin4_emax30_o',
                        catalog_file="/tigress/nrodd/DM-Catalog-Scan/DataFiles/Catalogs/2MRSLocalTully_ALL_DATAPAPER_Planck15_gaoboost_v7.csv"
                                )

# %%
data_ary_gaoboost, _,_ = plot_data_gaoboost.return_limits()

# %%
plot_data_mmin1e4 = LimitPlot(data_dir='/tigress/nrodd/DM-Catalog-Scan/Scan-Small-ROI/data/Tully_mmin1e4////',
                        elephant=False, 
                        nmc=1,
                        bcut=20,
                        nonoverlap=True,
                        nonoverlapradius=2.,
                        cut_0p5=False,
                        xsecslim=10,
                        TS100=9,
                        TS1000=9,
                        halos_ran=1000, 
                        halos_to_keep=1000,
                        data_type="data",
                        file_prefix='LL2_TSmx_lim_b_emin4_emax30_o',
                        catalog_file="/tigress/nrodd/DM-Catalog-Scan/DataFiles/Catalogs/2MRSLocalTully_ALL_DATAPAPER_Planck15_mmin1e4_v7.csv"
                                )

# %%
data_ary_mmin1e4, _,_ = plot_data_mmin1e4.return_limits()

# %%
plot_data_sanchezboost = LimitPlot(data_dir='/tigress/nrodd/DM-Catalog-Scan/Scan-Small-ROI/data/Tully_sanchezboost/////',
                        elephant=False, 
                        nmc=1,
                        bcut=20,
                        nonoverlap=True,
                        nonoverlapradius=2.,
                        cut_0p5=False,
                        xsecslim=10,
                        TS100=9,
                        TS1000=9,
                        halos_ran=1000, 
                        halos_to_keep=1000,
                        data_type="data",
                        file_prefix='LL2_TSmx_lim_b_emin4_emax30_o',
                        catalog_file="/tigress/nrodd/DM-Catalog-Scan/DataFiles/Catalogs/2MRSLocalTully_ALL_DATAPAPER_Planck15_sanchezboost_v7.csv"
                                )

# %%
data_ary_sanchezboost, _,_ = plot_data_sanchezboost.return_limits()

# %%
plot_data_alpha20 = LimitPlot(data_dir='/tigress/nrodd/DM-Catalog-Scan/Scan-Small-ROI/data/Tully_sanchezboost/////',
                        elephant=False, 
                        nmc=1,
                        bcut=20,
                        nonoverlap=True,
                        nonoverlapradius=2.,
                        cut_0p5=False,
                        xsecslim=10,
                        TS100=9,
                        TS1000=9,
                        halos_ran=1000, 
                        halos_to_keep=1000,
                        data_type="data",
                        file_prefix='LL2_TSmx_lim_b_emin4_emax30_o',
                        catalog_file="/tigress/nrodd/DM-Catalog-Scan/DataFiles/Catalogs/2MRSLocalTully_ALL_DATAPAPER_Planck15_alpha20_v7.csv"
                                )

# %%
data_ary_alpha20, _,_ = plot_data_alpha20.return_limits()

# %%
fig,ax = plt.subplots(1,figsize=(10/1.2,8/1.2))

# plt.plot(m_arr,data_lim,color='k',label=r'Galaxy groups (this work)',linewidth=2,linestyle='solid')
# plt.plot(m_arr,data_lim_nb,color='black',label=r'Galaxy groups (no boost)',linewidth=1,linestyle='dashed')

# fudge=1.0 
# plt.fill_between(m_arr,fudge*rot_q2p5,fudge*rot_q97p5,color='yellow',label=r'95\% containment',alpha=0.6)
# plt.fill_between(m_arr,fudge*rot_q16,fudge*rot_q84,color='limegreen',label=r'68\% containment',alpha=0.7)

plt.plot(plot_data.marr,10**np.percentile(data_ary[-1], 2.5, axis=1), alpha=1, color='k',label=r'Baseline (Tully catalogs)', lw=2.5)
plt.plot(plot_data.marr,10**np.percentile(data_ary_Lu[-1], 2.5, axis=1), alpha=1, color='k',label=r'Lu group catalog',ls='--')



plt.plot(thermal[::,0],thermal[::,1],linestyle='dotted',color='dimgrey',linewidth=1)
plt.text(380, 3.e-26, r'\emph{Thermal relic cross section}',fontsize=19.,color='dimgrey')
# plt.text(7000, 1.0e-27, r'$b \bar b$',fontsize=20,color='black')

# set the alpha value of the legend: it will be translucent
# leg.get_frame().set_alpha(0.1)

plt.xscale('log')
plt.yscale('log')
plt.xticks(fontsize=23);
plt.yticks(fontsize=23);
plt.xlabel(r"$m_\chi$ [GeV]",fontsize=23)
plt.ylabel(r"$\langle \sigma v \rangle$ [cm$^3$ s$^{-1}$]",fontsize=23)
#plt.legend(fontsize=18,loc = 2)

plt.xlim([1e1,1e4])
plt.ylim([8e-28,2e-22])

plt.text(200, 3.5e-27, r'\textbf{Stacked Galaxy Groups}',fontsize=22,color='black')
plt.text(1100.3, 1.5e-27, r'Lu group catalog',fontsize=20,color='black')

plt.legend(ncol=1,fancybox=True,facecolor='none',frameon=False)

plt.tight_layout()

plt.savefig(plots_dir + 'systematics_lu.pdf',bbox_inches='tight')

# %%
fig,ax = plt.subplots(1,figsize=(10/1.2,8/1.2))

for midx in [11]:
    plt.plot(np.arange(len(data_ary[:,midx,:])) + 1,10**np.percentile(data_ary[:,midx,:],[50],axis=1)[0], color='k', ls='-', label="Baseline (Tully catalogs)", lw=2.5)
    plt.plot(np.arange(len(data_ary_Lu[:,midx,:])) + 1,10**np.percentile(data_ary_Lu[:,midx,:],[50],axis=1)[0], color='k', ls='--', label="Lu group catalog")


#     plt.title("$M_\chi$ = " + str(int(plot_data_skylocs.marr[midx])) + " GeV")
    
    plt.xlabel("$N_h$",fontsize=23)
    plt.ylabel("$\langle \sigma v \\rangle$ [cm$^3$s$^{-1}$]",fontsize=23)
    
    plt.xscale("log")
    plt.yscale("log")
    
    plt.xticks(fontsize=23);
    plt.yticks(fontsize=23);

    plt.legend(ncol=1,fancybox=True,facecolor='none',frameon=False)
    plt.text(15.3, 1.5e-26, r'\textbf{Stacked Galaxy Groups}',fontsize=22,color='black')
    plt.text(60.3, 0.9e-26, r'Lu group catalog',fontsize=20,color='black')


    plt.ylim(5e-27,5e-24)
    plt.xlim(min(np.arange(len(data_ary_Lu[:,midx,:]))),max(np.arange(len(data_ary_Lu[:,midx,:]))))
    plt.tight_layout()


    plt.savefig(plots_dir + "systematics_lu_elephant.pdf")
    plt.show()

# %%
fig,ax = plt.subplots(1,figsize=(10/1.2,8/1.2))

# plt.plot(m_arr,data_lim,color='k',label=r'Galaxy groups (this work)',linewidth=2,linestyle='solid')
# plt.plot(m_arr,data_lim_nb,color='black',label=r'Galaxy groups (no boost)',linewidth=1,linestyle='dashed')

# fudge=1.0 
# plt.fill_between(m_arr,fudge*rot_q2p5,fudge*rot_q97p5,color='yellow',label=r'95\% containment',alpha=0.6)
# plt.fill_between(m_arr,fudge*rot_q16,fudge*rot_q84,color='limegreen',label=r'68\% containment',alpha=0.7)

plt.plot(plot_data.marr,10**np.percentile(data_ary[-1], 2.5, axis=1), alpha=1, color='k',label=r'Baseline', lw=2.5)
plt.plot(plot_data.marr,10**np.percentile(data_ary_p7[-1], 2.5, axis=1), alpha=1, color='k',label=r'\texttt{p7v6} diffuse model',ls='--')
plt.plot(plot_data.marr,10**np.percentile(data_ary_UCV3[-1], 2.5, axis=1), alpha=1, color='k',label=r'Top PSF quartile',ls='-.')




plt.plot(thermal[::,0],thermal[::,1],linestyle='dotted',color='dimgrey',linewidth=1)
plt.text(380, 3.e-26, r'\emph{Thermal relic cross section}',fontsize=19.,color='dimgrey')
# plt.text(7000, 1.0e-27, r'$b \bar b$',fontsize=20,color='black')

# set the alpha value of the legend: it will be translucent
# leg.get_frame().set_alpha(0.1)

plt.xscale('log')
plt.yscale('log')
plt.xticks(fontsize=23);
plt.yticks(fontsize=23);
plt.xlabel(r"$m_\chi$ [GeV]",fontsize=23)
plt.ylabel(r"$\langle \sigma v \rangle$ [cm$^3$ s$^{-1}$]",fontsize=23)
#plt.legend(fontsize=18,loc = 2)

plt.xlim([1e1,1e4])
plt.ylim([8e-28,2e-22])

plt.text(200, 3.5e-27, r'\textbf{Stacked Galaxy Groups}',fontsize=22,color='black')
plt.text(63., 1.5e-27, r'Data set and foreground model variations',fontsize=20,color='black')

plt.legend(ncol=1,fancybox=True,facecolor='none',frameon=False)

plt.tight_layout()

plt.savefig(plots_dir + 'systematics_dataset.pdf',bbox_inches='tight')

# %%
fig,ax = plt.subplots(1,figsize=(10/1.2,8/1.2))

# plt.plot(m_arr,data_lim,color='k',label=r'Galaxy groups (this work)',linewidth=2,linestyle='solid')
# plt.plot(m_arr,data_lim_nb,color='black',label=r'Galaxy groups (no boost)',linewidth=1,linestyle='dashed')

# fudge=1.0 
# plt.fill_between(m_arr,fudge*rot_q2p5,fudge*rot_q97p5,color='yellow',label=r'95\% containment',alpha=0.6)
# plt.fill_between(m_arr,fudge*rot_q16,fudge*rot_q84,color='limegreen',label=r'68\% containment',alpha=0.7)

plt.plot(plot_data.marr,10**np.percentile(data_ary[-1], 2.5, axis=1), alpha=1, color='k',label=r'Baseline', lw=2.5)
plt.plot(plot_data.marr,10**np.percentile(data_ary_useboost[-1], 2.5, axis=1), alpha=1, color='k',label=r'$\rho_\mathrm{NFW}$-boosted profile',ls='--')
plt.plot(plot_data.marr,10**np.percentile(data_ary_Burkert[-1], 2.5, axis=1), alpha=1, color='k',label=r'Burkert profile',ls='-.')
plt.plot(plot_data.marr,10**np.percentile(data_ary_diemerconc[-1], 2.5, axis=1), alpha=1, color='k',label=r'Diemer concentration',ls=':')
# plt.plot(plot_data.marr,10**np.percentile(data_ary_sigmaconc0p24[-1], 2.5, axis=1), alpha=1, color='k',label=r'Small errors concentration',ls=':')






plt.plot(thermal[::,0],thermal[::,1],linestyle='dotted',color='dimgrey',linewidth=1)
plt.text(380, 3.e-26, r'\emph{Thermal relic cross section}',fontsize=19.,color='dimgrey')
# plt.text(7000, 1.0e-27, r'$b \bar b$',fontsize=20,color='black')

# set the alpha value of the legend: it will be translucent
# leg.get_frame().set_alpha(0.1)

plt.xscale('log')
plt.yscale('log')
plt.xticks(fontsize=23);
plt.yticks(fontsize=23);
plt.xlabel(r"$m_\chi$ [GeV]",fontsize=23)
plt.ylabel(r"$\langle \sigma v \rangle$ [cm$^3$ s$^{-1}$]",fontsize=23)
#plt.legend(fontsize=18,loc = 2)

plt.xlim([1e1,1e4])
plt.ylim([8e-28,2e-22])

plt.text(200, 3.5e-27, r'\textbf{Stacked Galaxy Groups}',fontsize=22,color='black')
plt.text(70.3, 1.5e-27, r'Halo profile and concentration variations',fontsize=20,color='black')

plt.legend(ncol=1,fancybox=True,facecolor='none',frameon=False)

plt.tight_layout()

plt.savefig(plots_dir + 'systematics_profile_conc.pdf',bbox_inches='tight')

# %%
fig,ax = plt.subplots(1,figsize=(10/1.2,8/1.2))

# plt.plot(m_arr,data_lim,color='k',label=r'Galaxy groups (this work)',linewidth=2,linestyle='solid')
# plt.plot(m_arr,data_lim_nb,color='black',label=r'Galaxy groups (no boost)',linewidth=1,linestyle='dashed')

# fudge=1.0 
# plt.fill_between(m_arr,fudge*rot_q2p5,fudge*rot_q97p5,color='yellow',label=r'95\% containment',alpha=0.6)
# plt.fill_between(m_arr,fudge*rot_q16,fudge*rot_q84,color='limegreen',label=r'68\% containment',alpha=0.7)

plt.plot(plot_data.marr,10**np.percentile(data_ary[-1], 2.5, axis=1), alpha=1, color='k',label=r'Baseline (Bartels)', lw=2.5)
plt.plot(plot_data.marr,10**np.percentile(data_ary_mmin1e4[-1], 2.5, axis=1), alpha=1, color='k',label=r'Bartels $M_\mathrm{min} = 10^{4}M_\odot$',ls='-.')
plt.plot(plot_data.marr,10**np.percentile(data_ary_alpha20[-1], 2.5, axis=1), alpha=1, color='k',label=r'Bartels $\alpha = 2.0$',ls='--')
plt.plot(plot_data.marr,10**np.percentile(data_ary_sanchezboost[-1], 2.5, axis=1), alpha=1, color='k',label=r"{Molin\'{e}}",ls=':')
plt.plot(plot_data.marr,10**np.percentile(data_ary_gaoboost[-1], 2.5, axis=1), alpha=1, color='grey',label=r'Gao',ls='--')







plt.plot(thermal[::,0],thermal[::,1],linestyle='dotted',color='dimgrey',linewidth=1)
plt.text(380, 3.e-26, r'\emph{Thermal relic cross section}',fontsize=19.,color='dimgrey')
# plt.text(7000, 1.0e-27, r'$b \bar b$',fontsize=20,color='black')

# set the alpha value of the legend: it will be translucent
# leg.get_frame().set_alpha(0.1)

plt.xscale('log')
plt.yscale('log')
plt.xticks(fontsize=23);
plt.yticks(fontsize=23);
plt.xlabel(r"$m_\chi$ [GeV]",fontsize=23)
plt.ylabel(r"$\langle \sigma v \rangle$ [cm$^3$ s$^{-1}$]",fontsize=23)
#plt.legend(fontsize=18,loc = 2)

plt.xlim([1e1,1e4])
plt.ylim([8e-28,2e-22])

plt.text(200, 3.5e-27, r'\textbf{Stacked Galaxy Groups}',fontsize=22,color='black')
plt.text(540.3, 1.5e-27, r'Boost model variations',fontsize=20,color='black')

plt.legend(ncol=1,fancybox=True,facecolor='none',frameon=False)

plt.tight_layout()

plt.savefig(plots_dir + 'systematics_boost.pdf',bbox_inches='tight')

# %% [markdown]
# # Individual halos

# %%
plot_data.passed_halos[:10]
# Out:
# [1, 3, 6, 7, 8, 10, 12, 14, 20, 21]

# %%
plot_single_mcs = []
plot_single_datas = []

maxts_single_mcs = []
maxts_single_datas = []


for i in tqdm_notebook(plot_data.passed_halos[:10]):
    plot_single_mc, _, maxts_single_mc  = plot_data_skylocs.return_limits_single(i)
    plot_single_data, _, maxts_single_data= plot_data.return_limits_single(i)
    
    plot_single_mcs.append(plot_single_mc)
    plot_single_datas.append(plot_single_data)
    
    maxts_single_mcs.append(maxts_single_mc)
    maxts_single_datas.append(maxts_single_data)

# %%
# plot_single_datas_lu = []

# for i in tqdm_notebook(range(10)):
#     plot_single_data_lu, _, _= plot_data_Lu.return_limits_single(i)

#     plot_single_datas_lu.append(plot_single_data_lu)

# %%
plot_data.passed_halos[:10]
# Out:
# [1, 3, 6, 7, 8, 10, 12, 14, 20, 21]

# %%
save_dir = '/tigress/bsafdi/github/NPTF-working/NPTF-ID-Catalog/runs_sid/notebooks/DataArrays/'

oFig1 = plt.figure(1,figsize=(15,20))

# for sidx in [0]:
for idx, i in enumerate(tqdm_notebook(plot_data.passed_halos[:10])):

    

    oFig1.add_subplot(5,2,idx+1)
    plt.fill_between(plot_data.marr,10**np.percentile(plot_single_mcs[idx], 2.5, axis=1),10**np.percentile(plot_single_mcs[idx], 97.5, axis=1), alpha=0.6, color='yellow')
    plt.fill_between(plot_data.marr,10**np.percentile(plot_single_mcs[idx], 16, axis=1),10**np.percentile(plot_single_mcs[idx], 84, axis=1), alpha=0.7, color='limegreen')
    plt.plot(plot_data.marr,10**np.percentile(plot_single_datas[idx], 2.5, axis=1), alpha=1., color='k',ls='-')
#     plt.plot(plot_data.marr, np.load("../data/Tully/LL2_TSmx_lim_b_o" + str(i) + "_data.npz")['lim'])
    plt.yscale("log")
    plt.xscale("log")
    plt.xlim(10,10000)
    plt.ylim(10**-27,10**-20)
    plt.plot(thermal[::,0],thermal[::,1],linestyle='dotted',color='dimgrey',linewidth=1)
    plt.text(1500, 3.5e-26, r'\emph{Thermal relic}',fontsize=19.,color='dimgrey')

    plt.xticks(fontsize=23);
    plt.yticks(fontsize=23);
    plt.xlabel(r"$m_\chi$ [GeV]",fontsize=23)

    if idx % 2 == 0: plt.ylabel("$\langle \sigma v \\rangle$ [cm$^3$\,s$^{-1}$]",fontsize=23)
    if i in plot_data.passed_halos:
        plt.text(10**1.1,10**-20.85, r'\textbf{Object '+str(i)+'} / ' + catalog['paperName'].values[i].replace("_", ""), fontsize=19, color='k')
    else:
        plt.text(10**1.1,10**-20.85, r'\textbf{Object '+str(i)+'} / ' + catalog['paperName'].values[i].replace("_", ""), fontsize=19, color='red')
    plt.text(10**1.1,10**-21.8, '$\log_{10}J='+str(catalog['mulog10J_inf'].values[i])[:5] + "$", fontsize=19, color='k')#/(GeV$^2$ cm$^{-5}$)

    plt.legend(loc = 'upper right')
    plt.tight_layout()
plt.savefig(plots_dir + "data_individual_lims.pdf")

# %%
save_dir = '/tigress/bsafdi/github/NPTF-working/NPTF-ID-Catalog/runs_sid/notebooks/DataArrays/'

oFig1 = plt.figure(1,figsize=(15,20))

for idx, i in enumerate(tqdm_notebook(plot_data.passed_halos[:10])):
    oFig1.add_subplot(5,2,idx+1)
    plt.fill_between(plot_data.marr,np.percentile(maxts_single_mcs[idx], 2.5, axis=1),np.percentile(maxts_single_mcs[idx], 97.5, axis=1), alpha=0.6, color='yellow')
    plt.fill_between(plot_data.marr,np.percentile(maxts_single_mcs[idx], 16, axis=1),np.percentile(maxts_single_mcs[idx], 84, axis=1), alpha=0.7, color='limegreen')
    plt.plot(plot_data.marr,np.percentile(maxts_single_datas[idx], 2.5, axis=1), alpha=1., color='k',ls='-')

    plt.xscale("log")
    plt.xlim(10,10000)
    plt.ylim(0, 30)

    plt.xticks(fontsize=23);
    plt.yticks(fontsize=23);

    if idx % 2 == 0: plt.ylabel("TS$_\mathrm{max}$",fontsize=23)
    if i in plot_data.passed_halos:
        plt.text(10**2.7,25, r'\textbf{Object '+str(i)+'} / ' + catalog['paperName'].values[i].replace("_", ""), fontsize=19, color='k')
    else:
        plt.text(10**2.7,25, r'\textbf{Object '+str(i)+'} / ' + catalog['paperName'].values[i].replace("_", ""), fontsize=19, color='red')
    plt.text(10**2.7,21, '$\log_{10}J='+str(catalog['mulog10J_inf'].values[i])[:5] + "$", fontsize=19, color='k')#/(GeV$^2$ cm$^{-5}$)

plt.tight_layout()
plt.savefig(plots_dir + "data_individual_maxts.pdf")

# %%
plot_single_mcs_obj5 = []
plot_single_datas_obj5 = []

maxts_single_mcs_obj5 = []
maxts_single_datas_obj5 = []


for i in [5]:
    plot_single_mc_obj5, _, maxts_single_mc_obj5  = plot_data_skylocs.return_limits_single(i)
    plot_single_data_obj5, _, maxts_single_data_obj5= plot_data.return_limits_single(i)
    
    plot_single_mcs_obj5.append(plot_single_mc_obj5)
    plot_single_datas_obj5.append(plot_single_data_obj5)
    
    maxts_single_mcs_obj5.append(maxts_single_mc_obj5)
    maxts_single_datas_obj5.append(maxts_single_data_obj5)

# %%
save_dir = '/tigress/bsafdi/github/NPTF-working/NPTF-ID-Catalog/runs_sid/notebooks/DataArrays/'

oFig1 = plt.figure(1,figsize=(15,4))

for idx, i in enumerate(tqdm_notebook(plot_data.passed_halos[:2])):
    if idx == 0:
        oFig1.add_subplot(1,2,idx+1)
        idx = 0
        i = 5
        plt.fill_between(plot_data.marr,np.percentile(maxts_single_mcs_obj5[idx], 2.5, axis=1),np.percentile(maxts_single_mcs_obj5[idx], 97.5, axis=1), alpha=0.6, color='yellow')
        plt.fill_between(plot_data.marr,np.percentile(maxts_single_mcs_obj5[idx], 16, axis=1),np.percentile(maxts_single_mcs_obj5[idx], 84, axis=1), alpha=0.7, color='limegreen')
        plt.plot(plot_data.marr,np.percentile(maxts_single_datas_obj5[idx], 2.5, axis=1), alpha=1., color='k',ls='-')

        plt.xscale("log")
        plt.xlim(10,10000)
        plt.ylim(0, 50)

        plt.xticks(fontsize=23);
        plt.yticks(fontsize=23);

        if idx % 2 == 0: plt.ylabel("TS$_\mathrm{max}$",fontsize=23)
        if i in plot_data.passed_halos:
            plt.text(10**1.1,45, r'\textbf{Object '+str(i)+'} / ' + catalog['paperName'].values[i].replace("_", "").replace(" ", ""), fontsize=19, color='k')
        else:
            plt.text(10**1.1,45, r'\textbf{Object '+str(i)+'} / ' + catalog['paperName'].values[i].replace("_", "").replace(" ", ""), fontsize=19, color='red')
        plt.text(10**1.1,38, '$\log_{10}J='+str(catalog['mulog10J_inf'].values[i])[:5] + "$", fontsize=19, color='k')#/(GeV$^2$ cm$^{-5}$)

    else:
        oFig1.add_subplot(1,2,idx+1)
        idx = 0
        i = 5
        plt.fill_between(plot_data.marr,10**np.percentile(plot_single_mcs_obj5[idx], 2.5, axis=1),10**np.percentile(plot_single_mcs_obj5[idx], 97.5, axis=1), alpha=0.6, color='yellow')
        plt.fill_between(plot_data.marr,10**np.percentile(plot_single_mcs_obj5[idx], 16, axis=1),10**np.percentile(plot_single_mcs_obj5[idx], 84, axis=1), alpha=0.7, color='limegreen')
        plt.plot(plot_data.marr,10**np.percentile(plot_single_datas_obj5[idx], 2.5, axis=1), alpha=1., color='k',ls='-')
    #     plt.plot(plot_data.marr, np.load("../data/Tully/LL2_TSmx_lim_b_o" + str(i) + "_data.npz")['lim'])
        plt.yscale("log")
        plt.xscale("log")
        plt.xlim(10,10000)
        plt.ylim(10**-27,10**-20)
        plt.plot(thermal[::,0],thermal[::,1],linestyle='dotted',color='dimgrey',linewidth=1)
        plt.text(1500, 3.5e-26, r'\emph{Thermal relic}',fontsize=19.,color='dimgrey')

        plt.xticks(fontsize=23);
        plt.yticks(fontsize=23);
        plt.xlabel(r"$m_\chi$ [GeV]",fontsize=23)

        if idx % 2 == 0: plt.ylabel("$\langle \sigma v \\rangle$ [cm$^3$\,s$^{-1}$]",fontsize=23)
        if i in plot_data.passed_halos:
            plt.text(10**1.1,10**-20.85, r'\textbf{Object '+str(i)+'} / ' + catalog['paperName'].values[i].replace("_", "").replace(" ", ""), fontsize=19, color='k')
        else:
            plt.text(10**1.1,10**-20.85, r'\textbf{Object '+str(i)+'} / ' + catalog['paperName'].values[i].replace("_", "").replace(" ", ""), fontsize=19, color='red')
        plt.text(10**1.1,10**-21.8, '$\log_{10}J='+str(catalog['mulog10J_inf'].values[i])[:5] + "$", fontsize=19, color='k')#/(GeV$^2$ cm$^{-5}$)

        plt.legend(loc = 'upper right')


plt.tight_layout()
plt.savefig(plots_dir + "object5_maxts_lim.pdf")

# %%
en_bins = 2*np.logspace(-1,3,41)
bin_centers = [10**((np.log10(en_bins[i])+np.log10(en_bins[i+1]))/2.) for i in range(40)]

en_stacked = np.vstack((en_bins,en_bins)).reshape((-1,),order='F')[1:-1]

# %%
fig, axes2d = plt.subplots(nrows=5, ncols=2,
                           figsize=(15,20))

data_dir = "../data/Tully/"
sim_dir = "../data/Tully_randlocs"
for l, row in tqdm_notebook(enumerate(axes2d)):
    for j, cell in enumerate(row):
        ihalo = plot_data.passed_halos[l*2 + j] # l*2 + j
        halo = plot_data.passed_halos[l*2 + j]
        d_ivals = np.load(data_dir + 'LL_inten_o'+str(halo)+'_data.npz')['intens']
        d_lvals = np.load(data_dir + 'LL_inten_o'+str(halo)+'_data.npz')['LL']
        
        rep_angext = np.array([0.02785567,0.12069876,0.21354185,0.30638494,0.39922802,0.49207111,0.5849142,0.67775728,0.77060037,0.86344346,0.95628654,1.04912963,1.14197272,1.2348158,1.32765889,1.42050198,1.51334507,1.60618815,1.69903124,1.79187433])
        obj_angext = 2*catalog[u'rs'].values[ihalo] / \
                     (Planck15.angular_diameter_distance(catalog[u'z'].values[ihalo]).value*1000) \
                     * 180./np.pi
        rep_index = (np.abs(rep_angext-obj_angext)).argmin()
        
        s_ivals = np.load(sim_dir + '0/LL_inten_o'+str(rep_index)+'_data.npz')['intens'] # intensity the same for all MC

        nsim = 200
        sim_arr_all = np.zeros(shape=(nsim,40,200))

        limit_total = np.zeros((nsim, 40 ))

        for i in (range(nsim)):
            sim_arr_all[i] = np.load(sim_dir + str(i) + '/LL_inten_o'+str(rep_index)+'_data.npz')['LL']

        for i in (range(40)):
            tmp_TS = np.zeros(shape=(nsim,200))
            for j in range(nsim):
                tmp_TS[j] = 2*(sim_arr_all[j,i,:]-sim_arr_all[j,i,0])
                max_arg= np.argmax(tmp_TS[j])
                max_val = tmp_TS[j][max_arg]
                for xi in range(max_arg,len(s_ivals[i])):
                    val = tmp_TS[j][xi]-max_val
                    if val < -2.71:
                        limit_total[j, i] = s_ivals[i][xi]
                        break



        limit_data = np.zeros(40)
        for en in range(40):
            TS_data = 2*(d_lvals[en]-d_lvals[en,0])
            max_arg= np.argmax(TS_data)
            max_val = TS_data[max_arg]
            for xi in range(max_arg,len(d_ivals[en])):
                val = TS_data[xi]-max_val
                if val < -2.71:
                    limit_data[en] = d_ivals[en][xi]
                    break

        lims = np.transpose([corner.quantile(np.transpose(limit_total)[i],[.025,0.14,.68,0.975]) for i in range(40)])

        fluxlim_stacked = np.vstack((limit_data,limit_data)).reshape((-1,),order='F')[:]
        fluxlim_stacked_sim2p5 = np.vstack((lims[0],lims[0])).reshape((-1,),order='F')[:]
        fluxlim_stacked_sim16 = np.vstack((lims[1],lims[1])).reshape((-1,),order='F')[:]
        fluxlim_stacked_sim68 = np.vstack((lims[2],lims[2])).reshape((-1,),order='F')[:]
        fluxlim_stacked_sim97p5 = np.vstack((lims[3],lims[3])).reshape((-1,),order='F')[:]

        cell.fill_between(np.log10(en_stacked[4:]), np.log10(fluxlim_stacked_sim2p5[4:]),np.log10(fluxlim_stacked_sim97p5[4:]), color='yellow',alpha=0.6)
        cell.fill_between(np.log10(en_stacked[4:]), np.log10(fluxlim_stacked_sim16[4:]),np.log10(fluxlim_stacked_sim68[4:]), color='limegreen',alpha=0.7)
        
        cell.set_xlabel("$E$ [GeV]")
        
        if ihalo == 4:
            cell.set_ylabel("Flux [cm$^{-2}$ s$^{-1}$]")


        cell.set_xlim(np.log10(.5),np.log10(250))
        cell.set_ylim(-12,-8)
        
        cell.set_yticks([-12,-10,-8])
        cell.set_yticklabels(["$10^{-12}$","$10^{-10}$","$10^{-8}$"], fontsize=23)
    

        cell.set_xticks([0,1,2])
        cell.set_xticklabels(["$10^{0}$","$10^{1}$","$10^{2}$"], fontsize=23)


        for i in range(4,len(bin_centers)):
            cell.arrow(np.log10(bin_centers[i]), np.log10(limit_data[i]), 0, -.3, length_includes_head=True,head_width=.06, head_length=.1, fc='k', ec='k')

        cell.errorbar(np.log10(bin_centers[4:]), np.log10(limit_data[4:]), marker='_',markersize= 6.,color='k',ls='none')

        cell.text(2.3,-8.8, r'\textbf{Object '+str(halo)+'} / ' + catalog['paperName'].values[halo].replace("_", ""), fontsize=20, color='k',horizontalalignment='right')

plt.tight_layout()
plt.savefig(plots_dir + "FluxUL.pdf")

# %% [markdown]
# # max TS

# %%
maxTS_skylocs_ary = np.load("../notebooks/maxTS_skylocs_ary_ecut4_emax30_200.npy")

# %%
fig, ax = plt.subplots(1, figsize=(plot_h, plot_w))

plt.plot(plot_data.marr,np.percentile(maxTS_ary[-1], 2.5, axis=1), alpha=1, color='k',label=r'Data',lw=2.5)

plt.fill_between(plot_data.marr,np.percentile(maxTS_skylocs_ary[-1], 2.5, axis=1),np.percentile(maxTS_skylocs_ary[-1], 97.5, axis=1),color='yellow',label=r'95\% containment',alpha=0.6,lw=2)
plt.fill_between(plot_data.marr,np.percentile(maxTS_skylocs_ary[-1], 16, axis=1),np.percentile(maxTS_skylocs_ary[-1], 84, axis=1),color='limegreen',label=r'68\% containment',alpha=0.7,lw=2)

m3, = plt.plot([], [], c='limegreen' , marker='s', markersize=20,
              fillstyle='left', linestyle='none',alpha=0.6)

m4, = plt.plot([], [], c='yellow' , marker='s', markersize=20,
              fillstyle='right', linestyle='none',alpha=0.6)



plt.xscale("log")
# plt.yscale("log")

plt.xticks(fontsize=23);
plt.yticks(fontsize=23);
plt.xlabel(r"$m_\chi$ [GeV]",fontsize=23)
plt.ylabel(r"TS$_\mathrm{max}$",fontsize=23)

plt.xlim([1e1,1e4])
# plt.ylim([8e-28,2e-22])
# plt.yscale("log")
# plt.text(15.3, 100, r'\textbf{Stacked Galaxy Groups}',fontsize=22,color='black')

handles,labels = ax.get_legend_handles_labels()
handles = [handles[0],(m3,m4)] #, handles[2]]
# labels = [labels[0], handles[1],labels[4],labels[3],labels[2]] #, labels[2]]

labels = [u'Data',
 u'$68/95\%$ containment']

# leg = plt.legend(handles,labels,loc=2,fontsize=17,fancybox=True,facecolor='none',frameon=False)



plt.legend(handles,labels, ncol=1,fancybox=True,facecolor='none',frameon=False, loc='upper left', fontsize=23)


plt.ylim(-0.1,60)
plt.tight_layout()

plt.savefig(plots_dir + 'global_maxts.pdf',bbox_inches='tight')

# %%
plot_data_test = LimitPlot(data_dir='/tigress/nrodd/DM-Catalog-Scan/Scan-Small-ROI/data/Tully//',
                        elephant=False, 
                        nmc=1,
                        bcut=20,
                        nonoverlap=True,
                        nonoverlapradius=2.,
                        cut_0p5=False,
                        xsecslim=10,
                        TS100=400000,
                        TS1000=9,
                        halos_ran=100, 
                        halos_to_keep=100,
                        data_type="data",
                        catalog_file="/tigress/nrodd/DM-Catalog-Scan/DataFiles/Catalogs/2MRSLocalTully_ALL_DATAPAPER_Planck15_v7.csv")

data_ary_test, _, maxTS_ary_test = plot_data_test.return_limits()

# %%
save_dir = '/tigress/bsafdi/github/NPTF-working/NPTF-ID-Catalog/runs_sid/notebooks/DataArrays/'

oFig1 = plt.figure(1,figsize=(15,40))

for idx,i in tqdm_notebook(enumerate(range(20))):

    oFig1.add_subplot(10,2,idx+1)
#     plt.fill_between(plot_data.marr,np.percentile(maxTS_skylocs_ary[i], 2.5, axis=1),np.percentile(maxTS_skylocs_ary[i], 97.5, axis=1), alpha=0.6, color='yellow')
#     plt.fill_between(plot_data.marr,np.percentile(maxTS_skylocs_ary[i], 16, axis=1),np.percentile(maxTS_skylocs_ary[i], 84, axis=1), alpha=0.7, color='limegreen')
    plt.plot(plot_data.marr,np.percentile(maxTS_ary_test[i], 2.5, axis=1), alpha=1., color='k',ls='-')

    plt.xscale("log")
    plt.xlim(10,10000)
#     plt.ylim(0, 50)
    
#     plt.yscale("log")
    plt.xticks(fontsize=23);
    plt.yticks(fontsize=23);

    if i % 2 == 0: plt.ylabel("TS$_\mathrm{max}$",fontsize=23)
#     if i in plot_data.passed_halos:
#         plt.text(10**1.1,45, r'\textbf{Object '+str(i)+'} / ' + catalog['paperName'].values[i].replace("_", ""), fontsize=19, color='k')
#     else:
#         plt.text(10**1.1,45, r'\textbf{Object '+str(i)+'} / ' + catalog['paperName'].values[i].replace("_", ""), fontsize=19, color='red')
#     plt.text(10**1.1,38, '$\log_{10}J='+str(catalog['mulog10J_inf'].values[i])[:5] + "$ GeV$^2$ cm$^{-5}$ sr", fontsize=19, color='k')#/(GeV$^2$ cm$^{-5}$)

plt.tight_layout()
# plt.savefig(plots_dir + "data_individual_maxts.pdf")

# %% [markdown]
# # TS and xsec cuts

# %%
plot_data_TS16 = LimitPlot(data_dir='/tigress/nrodd/DM-Catalog-Scan/Scan-Small-ROI/data/Tully//',
                        elephant=False, 
                        nmc=1,
                        bcut=20,
                        nonoverlap=True,
                        nonoverlapradius=2.,
                        cut_0p5=False,
                        xsecslim=10,
                        TS100=16,
                        TS1000=16,
                        halos_ran=1000, 
                        halos_to_keep=1000,
                        data_type="data",
                        file_prefix='LL2_TSmx_lim_b_emin4_emax30_o',
                        catalog_file="/tigress/nrodd/DM-Catalog-Scan/DataFiles/Catalogs/2MRSLocalTully_ALL_DATAPAPER_Planck15_v7.csv")

# %%
plot_data_TS4 = LimitPlot(data_dir='/tigress/nrodd/DM-Catalog-Scan/Scan-Small-ROI/data/Tully//',
                        elephant=False, 
                        nmc=1,
                        bcut=20,
                        nonoverlap=True,
                        nonoverlapradius=2.,
                        cut_0p5=False,
                        xsecslim=10,
                        TS100=4,
                        TS1000=4,
                        halos_ran=1000, 
                        halos_to_keep=1000,
                        data_type="data",
                                                file_prefix='LL2_TSmx_lim_b_emin4_emax30_o',
                        catalog_file="/tigress/nrodd/DM-Catalog-Scan/DataFiles/Catalogs/2MRSLocalTully_ALL_DATAPAPER_Planck15_v7.csv")

plot_data_xsec20 = LimitPlot(data_dir='/tigress/nrodd/DM-Catalog-Scan/Scan-Small-ROI/data/Tully//',
                        elephant=False, 
                        nmc=1,
                        bcut=20,
                        nonoverlap=True,
                        nonoverlapradius=2.,
                        cut_0p5=False,
                        xsecslim=20,
                        TS100=9,
                        TS1000=9,
                        halos_ran=1000, 
                        halos_to_keep=1000,
                        data_type="data",
                                file_prefix='LL2_TSmx_lim_b_emin4_emax30_o',
                        catalog_file="/tigress/nrodd/DM-Catalog-Scan/DataFiles/Catalogs/2MRSLocalTully_ALL_DATAPAPER_Planck15_v7.csv")

plot_data_nocut = LimitPlot(data_dir='/tigress/nrodd/DM-Catalog-Scan/Scan-Small-ROI/data/Tully//',
                        elephant=False, 
                        nmc=1,
                        bcut=20,
                        nonoverlap=True,
                        nonoverlapradius=2.,
                        cut_0p5=False,
                        xsecslim=10000000000,
                        TS100=9,
                        TS1000=9,
                        halos_ran=1000, 
                        halos_to_keep=1000,
                        data_type="data",
                                                    file_prefix='LL2_TSmx_lim_b_emin4_emax30_o',
                        catalog_file="/tigress/nrodd/DM-Catalog-Scan/DataFiles/Catalogs/2MRSLocalTully_ALL_DATAPAPER_Planck15_v7.csv")


plot_data_noverlap5 = LimitPlot(data_dir='/tigress/nrodd/DM-Catalog-Scan/Scan-Small-ROI/data/Tully//',
                        elephant=False, 
                        nmc=1,
                        bcut=20,
                        nonoverlap=True,
                        nonoverlapradius=5.,
                        cut_0p5=False,
                        xsecslim=10,
                        TS100=9,
                        TS1000=9,
                        halos_ran=1000, 
                        halos_to_keep=1000,
                        data_type="data",
                                                        file_prefix='LL2_TSmx_lim_b_emin4_emax30_o',
                        catalog_file="/tigress/nrodd/DM-Catalog-Scan/DataFiles/Catalogs/2MRSLocalTully_ALL_DATAPAPER_Planck15_v7.csv")


plot_data_bcut15 = LimitPlot(data_dir='/tigress/nrodd/DM-Catalog-Scan/Scan-Small-ROI/data/Tully//',
                        elephant=False, 
                        nmc=1,
                        bcut=15,
                        nonoverlap=True,
                        nonoverlapradius=2.,
                        cut_0p5=False,
                        xsecslim=10,
                        TS100=9,
                        TS1000=9,
                        halos_ran=1000, 
                        halos_to_keep=1000,
                        data_type="data",
                                                     file_prefix='LL2_TSmx_lim_b_emin4_emax30_o',
                        catalog_file="/tigress/nrodd/DM-Catalog-Scan/DataFiles/Catalogs/2MRSLocalTully_ALL_DATAPAPER_Planck15_v7.csv")

# %%
data_ary_TS16, _, _ = plot_data_TS16.return_limits()

# %%
data_ary_TS4, _, _ = plot_data_TS4.return_limits()
data_ary_xsec20, _, _ = plot_data_xsec20.return_limits()
data_ary_nocut, _, _ = plot_data_nocut.return_limits()
data_ary_noverlap5, _, _ = plot_data_noverlap5.return_limits()
data_ary_bcut15, _, _ = plot_data_bcut15.return_limits()

# %%
plot_data_10k = LimitPlot(data_dir='/tigress/nrodd/DM-Catalog-Scan/Scan-Small-ROI/data/Tully//',
                        elephant=False, 
                        nmc=1,
                        bcut=20,
                        nonoverlap=True,
                        nonoverlapradius=2.,
                        cut_0p5=False,
                        xsecslim=10,
                        TS100=9,
                        TS1000=9,
                        halos_ran=5000, 
                        halos_to_keep=5000,
                        data_type="data",
                                                     file_prefix='LL2_TSmx_lim_b_emin4_emax30_o',
                        catalog_file="/tigress/nrodd/DM-Catalog-Scan/DataFiles/Catalogs/2MRSLocalTully_ALL_DATAPAPER_Planck15_v7.csv",
                               skip_halos=[0])

# %%
plot_data_Andromeda = LimitPlot(data_dir='/tigress/nrodd/DM-Catalog-Scan/Scan-Small-ROI/data/Tully//',
                        elephant=False, 
                        nmc=1,
                        bcut=20,
                        nonoverlap=True,
                        nonoverlapradius=2.,
                        cut_0p5=False,
                        xsecslim=10,
                        TS100=9,
                        TS1000=9,
                        halos_ran=1000, 
                        halos_to_keep=1000,
                        data_type="data",
                                                     file_prefix='LL2_TSmx_lim_b_emin4_emax30_o',
                        catalog_file="/tigress/nrodd/DM-Catalog-Scan/DataFiles/Catalogs/2MRSLocalTully_ALL_DATAPAPER_Planck15_v7.csv",
                               skip_halos=[])

# %%
plot_data_NoVirgo = LimitPlot(data_dir='/tigress/nrodd/DM-Catalog-Scan/Scan-Small-ROI/data/Tully//',
                        elephant=False, 
                        nmc=1,
                        bcut=20,
                        nonoverlap=True,
                        nonoverlapradius=2.,
                        cut_0p5=False,
                        xsecslim=10,
                        TS100=9,
                        TS1000=9,
                        halos_ran=1000, 
                        halos_to_keep=1000,
                        data_type="data",
                                                     file_prefix='LL2_TSmx_lim_b_emin4_emax30_o',
                        catalog_file="/tigress/nrodd/DM-Catalog-Scan/DataFiles/Catalogs/2MRSLocalTully_ALL_DATAPAPER_Planck15_v7.csv",
                               skip_halos=[0,1])

# %%
data_ary_10k, _, _ = plot_data_10k.return_limits()

# %%
data_ary_Andromeda, _, _ = plot_data_Andromeda.return_limits()
data_ary_NoVirgo, _, _ = plot_data_NoVirgo.return_limits()

# %%
fig,ax = plt.subplots(1,figsize=(10/1.2,8/1.2))

# plt.plot(m_arr,data_lim,color='k',label=r'Galaxy groups (this work)',linewidth=2,linestyle='solid')
# plt.plot(m_arr,data_lim_nb,color='black',label=r'Galaxy groups (no boost)',linewidth=1,linestyle='dashed')

# fudge=1.0 
# plt.fill_between(m_arr,fudge*rot_q2p5,fudge*rot_q97p5,color='yellow',label=r'95\% containment',alpha=0.6)
# plt.fill_between(m_arr,fudge*rot_q16,fudge*rot_q84,color='limegreen',label=r'68\% containment',alpha=0.7)

plt.plot(plot_data.marr,10**np.percentile(data_ary[-1], 2.5, axis=1), alpha=1, color='k',label=r'Baseline', lw=2.5)
plt.plot(plot_data.marr,10**np.percentile(data_ary_xsec20[-1], 2.5, axis=1), alpha=1, color='k',label=r'$\widehat{\langle\sigma v\rangle} > 20 \times \langle\sigma v\rangle^*_\mathrm{lim}(m_\chi)$',ls='--')
plt.plot(plot_data.marr,10**np.percentile(data_ary_TS4[-1], 2.5, axis=1), alpha=1, color='k',label=r'TS$_\mathrm{max} = 4$',ls='-.')
plt.plot(plot_data.marr,10**np.percentile(data_ary_nocut[-1], 2.5, axis=1), alpha=1, color='k',label=r'No cuts',ls=':')




plt.plot(thermal[::,0],thermal[::,1],linestyle='dotted',color='dimgrey',linewidth=1)
plt.text(380, 3.e-26, r'\emph{Thermal relic cross section}',fontsize=19.,color='dimgrey')
# plt.text(7000, 1.0e-27, r'$b \bar b$',fontsize=20,color='black')

# set the alpha value of the legend: it will be translucent
# leg.get_frame().set_alpha(0.1)

plt.xscale('log')
plt.yscale('log')
plt.xticks(fontsize=23);
plt.yticks(fontsize=23);
plt.xlabel(r"$m_\chi$ [GeV]",fontsize=23)
plt.ylabel(r"$\langle \sigma v \rangle$ [cm$^3$ s$^{-1}$]",fontsize=23)
#plt.legend(fontsize=18,loc = 2)

plt.xlim([1e1,1e4])
plt.ylim([8e-28,2e-22])

plt.text(200, 3.5e-27, r'\textbf{Stacked Galaxy Groups}',fontsize=22,color='black')
plt.text(240., 1.5e-27, r'Effect of TS$_\mathrm{max}$ and $\widehat{\langle\sigma v \rangle}$ cuts',fontsize=20,color='black')

plt.legend(ncol=1,fancybox=True,facecolor='none',frameon=False, loc="upper left")

plt.tight_layout()

plt.savefig(plots_dir + 'systematics_cuts.pdf',bbox_inches='tight')

# %%
data_skylocs_nocut_ary = np.load("data_skylocs_ary_ecut4_emax30_nocuts_nocustom_200.npy")

# %%
fig,ax = plt.subplots(1,figsize=(10/1.2,8/1.2))

# plt.plot(m_arr,data_lim,color='k',label=r'Galaxy groups (this work)',linewidth=2,linestyle='solid')
# plt.plot(m_arr,data_lim_nb,color='black',label=r'Galaxy groups (no boost)',linewidth=1,linestyle='dashed')

# fudge=1.0 
# plt.fill_between(m_arr,fudge*rot_q2p5,fudge*rot_q97p5,color='yellow',label=r'95\% containment',alpha=0.6)
# plt.fill_between(m_arr,fudge*rot_q16,fudge*rot_q84,color='limegreen',label=r'68\% containment',alpha=0.7)

plt.fill_between(plot_data.marr,10**np.percentile(data_skylocs_nocut_ary[len(data_ary)], 2.5, axis=1),10**np.percentile(data_skylocs_nocut_ary[len(data_ary)], 97.5, axis=1),color='cornflowerblue',label=r'95\% containment',alpha=0.6,lw=2)
plt.fill_between(plot_data.marr,10**np.percentile(data_skylocs_nocut_ary[len(data_ary)], 16, axis=1),10**np.percentile(data_skylocs_nocut_ary[len(data_ary)], 84, axis=1),color='tomato',label=r'68\% containment',alpha=0.7,lw=2)

plt.fill_between(plot_data.marr,10**np.percentile(data_skylocs_ary[len(data_ary)], 2.5, axis=1),10**np.percentile(data_skylocs_ary[len(data_ary)], 97.5, axis=1),color='yellow',label=r'95\% containment',alpha=0.6,lw=2)
plt.fill_between(plot_data.marr,10**np.percentile(data_skylocs_ary[len(data_ary)], 16, axis=1),10**np.percentile(data_skylocs_ary[len(data_ary)], 84, axis=1),color='limegreen',label=r'68\% containment',alpha=0.7,lw=2)


plt.plot(plot_data.marr,10**np.percentile(data_ary[-1], 2.5, axis=1), alpha=1, color='k',label=r'Baseline', lw=2.5)
# plt.plot(plot_data.marr,10**np.percentile(data_ary_xsec20[-1], 2.5, axis=1), alpha=1, color='k',label=r'$\widehat{\langle\sigma v\rangle} > 20 \times \langle\sigma v\rangle^*_\mathrm{lim}(m_\chi)$',ls='--')
# plt.plot(plot_data.marr,10**np.percentile(data_ary_TS4[-1], 2.5, axis=1), alpha=1, color='k',label=r'TS$_\mathrm{max} = 4$',ls='-.')
plt.plot(plot_data.marr,10**np.percentile(data_ary_nocut[-1], 2.5, axis=1), alpha=1, color='k',label=r'No cuts',ls=':')




plt.plot(thermal[::,0],thermal[::,1],linestyle='dotted',color='dimgrey',linewidth=1)
plt.text(380, 3.e-26, r'\emph{Thermal relic cross section}',fontsize=19.,color='dimgrey')
# plt.text(7000, 1.0e-27, r'$b \bar b$',fontsize=20,color='black')

# set the alpha value of the legend: it will be translucent
# leg.get_frame().set_alpha(0.1)

plt.xscale('log')
plt.yscale('log')
plt.xticks(fontsize=23);
plt.yticks(fontsize=23);
plt.xlabel(r"$m_\chi$ [GeV]",fontsize=23)
plt.ylabel(r"$\langle \sigma v \rangle$ [cm$^3$ s$^{-1}$]",fontsize=23)
#plt.legend(fontsize=18,loc = 2)

plt.xlim([1e1,1e4])
plt.ylim([8e-28,2e-22])

plt.text(200, 3.5e-27, r'\textbf{Stacked Galaxy Groups}',fontsize=22,color='black')
plt.text(670., 1.5e-27, r'No TS and $\langle\sigma v \rangle$ cuts',fontsize=20,color='black')

m1, = plt.plot([], [], c='tomato' , marker='s', markersize=20,
              fillstyle='left', linestyle='none',alpha=0.6)

m2, = plt.plot([], [], c='cornflowerblue' , marker='s', markersize=20,
              fillstyle='right', linestyle='none',alpha=0.6)

#---- Define Second Legend Entry ----

m3, = plt.plot([], [], c='limegreen' , marker='s', markersize=20,
              fillstyle='left', linestyle='none',alpha=0.6)

m4, = plt.plot([], [], c='yellow' , marker='s', markersize=20,
              fillstyle='right', linestyle='none',alpha=0.6)

m5, = plt.plot([], [], color='k')
m6, = plt.plot([], [], ls=':', color='k')

#---- Plot Legend ----

plt.legend(((m3, m4),(m2, m1),m5, m6,), ('68/95\% baseline cuts','68/95\% no cuts','Baseline','No cuts'), ncol=1,fancybox=True,facecolor='none',frameon=False, loc="upper left")


# plt.legend(ncol=2,fancybox=True,facecolor='none',frameon=False, loc="upper left")

plt.tight_layout()

plt.savefig(plots_dir + 'systematics_nots_cuts.pdf',bbox_inches='tight')

# %%
fig,ax = plt.subplots(1,figsize=(10/1.2,8/1.2))

# plt.plot(m_arr,data_lim,color='k',label=r'Galaxy groups (this work)',linewidth=2,linestyle='solid')
# plt.plot(m_arr,data_lim_nb,color='black',label=r'Galaxy groups (no boost)',linewidth=1,linestyle='dashed')

# fudge=1.0 
# plt.fill_between(m_arr,fudge*rot_q2p5,fudge*rot_q97p5,color='yellow',label=r'95\% containment',alpha=0.6)
# plt.fill_between(m_arr,fudge*rot_q16,fudge*rot_q84,color='limegreen',label=r'68\% containment',alpha=0.7)

plt.plot(plot_data.marr,10**np.percentile(data_ary[-1], 2.5, axis=1), alpha=1, color='k',label=r'Baseline', lw=2.5)
plt.plot(plot_data.marr,10**np.percentile(data_ary_noverlap5[-1], 2.5, axis=1), alpha=1, color='k',label=r'No overlap within 5$^\circ$',ls='--')
plt.plot(plot_data.marr,10**np.percentile(data_ary_bcut15[-1], 2.5, axis=1), alpha=1, color='k',label=r'$|b| \geq 15^\circ$',ls='-.')
plt.plot(plot_data.marr,10**np.percentile(data_ary_NoVirgo[-1], 2.5, axis=1), alpha=1, color='k',label=r'Excluding Virgo',ls='dotted', lw=2.2)
plt.plot(plot_data.marr,10**np.percentile(data_ary_Andromeda[-1], 2.5, axis=1), alpha=1, color='lightgrey',label=r'Including M31',ls='-', lw=2.2)


plt.plot(plot_data.marr,10**np.percentile(data_ary_10k[-1], 2.5, axis=1), alpha=1, color='red',label=r'10k halos',ls='-')




plt.plot(thermal[::,0],thermal[::,1],linestyle='dotted',color='dimgrey',linewidth=1)
plt.text(380, 3.e-26, r'\emph{Thermal relic cross section}',fontsize=19.,color='grey')
# plt.text(7000, 1.0e-27, r'$b \bar b$',fontsize=20,color='black')

# set the alpha value of the legend: it will be translucent
# leg.get_frame().set_alpha(0.1)

plt.xscale('log')
plt.yscale('log')
plt.xticks(fontsize=23);
plt.yticks(fontsize=23);
plt.xlabel(r"$m_\chi$ [GeV]",fontsize=23)
plt.ylabel(r"$\langle \sigma v \rangle$ [cm$^3$ s$^{-1}$]",fontsize=23)
#plt.legend(fontsize=18,loc = 2)

plt.xlim([1e1,1e4])
plt.ylim([8e-28,2e-22])

plt.text(200, 3.5e-27, r'\textbf{Stacked Galaxy Groups}',fontsize=22,color='black')
plt.text(650., 1.5e-27, r'Halo selection criteria',fontsize=20,color='black')

plt.legend(ncol=1,fancybox=True,facecolor='none',frameon=False)

plt.tight_layout()

plt.savefig(plots_dir + 'systematics_nh.pdf',bbox_inches='tight')

# %%
hp.mollview("/tigress/nrodd/DM-Catalog-Scan/DataFiles/MonteCarlo/MC_allhalos_p7")
