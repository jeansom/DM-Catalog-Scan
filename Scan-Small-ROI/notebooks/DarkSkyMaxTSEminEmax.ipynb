# %%
import sys
sys.path.append("../")

import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from tqdm import *
from plot_skylocs import LimitPlot

# %matplotlib inline
# %load_ext autoreload
# %autoreload 2

# %%
plots_dir = "/tigress/nrodd/DM-Catalog-Scan/Scan-Small-ROI/plots_darksky/"

# %%
nmc = 10

xsec_max_ary = np.zeros((5,nmc))
limit_ary = np.zeros((5,nmc))
maxts_ary = np.zeros((5,nmc))

plot_mc = LimitPlot(data_dir='/tigress/nrodd/DM-Catalog-Scan/Scan-Small-ROI/data/DarkSky_sid_loc1/',
                    elephant=False, 
                    nmc=nmc, 
                    halos_ran=1000, 
                    halos_to_keep=1000,
                    data_type="mc",
                    bcut=20,
                    nonoverlap=True,
                    nonoverlapradius=2.,
                    cut_0p5=False,
                    xsecslim=10,
                    TS100=9,
                    TS1000=9,
                    file_prefix='LL2_TSmx_lim_b_emin4_emax30_o',
                    elephantm = [0]) # 0 for 10 GeV
limit_ary_temp, xsec_max_ary_temp, maxts_ary_temp = plot_mc.return_limits()

# xsec_max_ary[idm] = xsec_max_ary_temp[-1,0,:]
# limit_ary[idm] = limit_ary_temp[-1,0,:]
# maxts_ary[idm] = maxts_ary_temp[-1,0,:]
    
# xsec_max = np.log10(np.percentile(xsec_max_ary, [16,50,84], axis=1))
# lims = np.log10(np.percentile(10**limit_ary, [16,50,84], axis=1))
# maxtss = np.percentile(10**maxts_ary, [16,50,84], axis=1)

# %%
nmc = 10

xsec_max_ary = np.zeros((5,nmc))
limit_ary = np.zeros((5,nmc))
maxts_ary = np.zeros((5,nmc))

plot_mc_emax31 = LimitPlot(data_dir='/tigress/nrodd/DM-Catalog-Scan/Scan-Small-ROI/data/DarkSky_sid_loc1/',
                    elephant=False, 
                    nmc=nmc, 
                    halos_ran=500, 
                    halos_to_keep=500,
                    data_type="mc",
                    bcut=20,
                    nonoverlap=True,
                    nonoverlapradius=2.,
                    cut_0p5=False,
                    xsecslim=10,
                    TS100=9,
                    TS1000=9,
                    file_prefix='LL2_TSmx_lim_b_emin4_emax31_o',
                    elephantm = [0]) # 0 for 10 GeV
limit_ary_temp_emax31, xsec_max_ary_temp_emax31, maxts_ary_temp_emax31 = plot_mc_emax31.return_limits()

# xsec_max_ary[idm] = xsec_max_ary_temp[-1,0,:]
# limit_ary[idm] = limit_ary_temp[-1,0,:]
# maxts_ary[idm] = maxts_ary_temp[-1,0,:]
    
# xsec_max = np.log10(np.percentile(xsec_max_ary, [16,50,84], axis=1))
# lims = np.log10(np.percentile(10**limit_ary, [16,50,84], axis=1))
# maxtss = np.percentile(10**maxts_ary, [16,50,84], axis=1)

# %%
nmc = 10

xsec_max_ary = np.zeros((5,nmc))
limit_ary = np.zeros((5,nmc))
maxts_ary = np.zeros((5,nmc))

plot_mc_emax32 = LimitPlot(data_dir='/tigress/nrodd/DM-Catalog-Scan/Scan-Small-ROI/data/DarkSky_sid_loc1/',
                    elephant=False, 
                    nmc=nmc, 
                    halos_ran=1000, 
                    halos_to_keep=1000,
                    data_type="mc",
                    bcut=20,
                    nonoverlap=True,
                    nonoverlapradius=2.,
                    cut_0p5=False,
                    xsecslim=10,
                    TS100=9,
                    TS1000=9,
                    file_prefix='LL2_TSmx_lim_b_emin4_emax32_o',
                    elephantm = [0]) # 0 for 10 GeV
limit_ary_temp_emax32, xsec_max_ary_temp_emax32, maxts_ary_temp_emax32 = plot_mc_emax32.return_limits()

# xsec_max_ary[idm] = xsec_max_ary_temp[-1,0,:]
# limit_ary[idm] = limit_ary_temp[-1,0,:]
# maxts_ary[idm] = maxts_ary_temp[-1,0,:]
    
# xsec_max = np.log10(np.percentile(xsec_max_ary, [16,50,84], axis=1))
# lims = np.log10(np.percentile(10**limit_ary, [16,50,84], axis=1))
# maxtss = np.percentile(10**maxts_ary, [16,50,84], axis=1)

# %%
nmc = 10

xsec_max_ary = np.zeros((5,nmc))
limit_ary = np.zeros((5,nmc))
maxts_ary = np.zeros((5,nmc))

plot_mc_emax33 = LimitPlot(data_dir='/tigress/nrodd/DM-Catalog-Scan/Scan-Small-ROI/data/DarkSky_sid_loc1/',
                    elephant=False, 
                    nmc=nmc, 
                    halos_ran=1000, 
                    halos_to_keep=1000,
                    data_type="mc",
                    bcut=20,
                    nonoverlap=True,
                    nonoverlapradius=2.,
                    cut_0p5=False,
                    xsecslim=10,
                    TS100=9,
                    TS1000=9,
                    file_prefix='LL2_TSmx_lim_b_emin4_emax33_o',
                    elephantm = [0]) # 0 for 10 GeV
limit_ary_temp_emax33, xsec_max_ary_temp_emax33, maxts_ary_temp_emax33 = plot_mc_emax33.return_limits()

# xsec_max_ary[idm] = xsec_max_ary_temp[-1,0,:]
# limit_ary[idm] = limit_ary_temp[-1,0,:]
# maxts_ary[idm] = maxts_ary_temp[-1,0,:]
    
# xsec_max = np.log10(np.percentile(xsec_max_ary, [16,50,84], axis=1))
# lims = np.log10(np.percentile(10**limit_ary, [16,50,84], axis=1))
# maxtss = np.percentile(10**maxts_ary, [16,50,84], axis=1)

# %%
nmc = 10

xsec_max_ary = np.zeros((5,nmc))
limit_ary = np.zeros((5,nmc))
maxts_ary = np.zeros((5,nmc))

plot_mc_emax34 = LimitPlot(data_dir='/tigress/nrodd/DM-Catalog-Scan/Scan-Small-ROI/data/DarkSky_sid_loc1/',
                    elephant=False, 
                    nmc=nmc, 
                    halos_ran=1000, 
                    halos_to_keep=1000,
                    data_type="mc",
                    bcut=20,
                    nonoverlap=True,
                    nonoverlapradius=2.,
                    cut_0p5=False,
                    xsecslim=10,
                    TS100=9,
                    TS1000=9,
                    file_prefix='LL2_TSmx_lim_b_emin4_emax34_o',
                    elephantm = [0]) # 0 for 10 GeV
limit_ary_temp_emax34, xsec_max_ary_temp_emax34, maxts_ary_temp_emax34 = plot_mc_emax34.return_limits()

# xsec_max_ary[idm] = xsec_max_ary_temp[-1,0,:]
# limit_ary[idm] = limit_ary_temp[-1,0,:]
# maxts_ary[idm] = maxts_ary_temp[-1,0,:]
    
# xsec_max = np.log10(np.percentile(xsec_max_ary, [16,50,84], axis=1))
# lims = np.log10(np.percentile(10**limit_ary, [16,50,84], axis=1))
# maxtss = np.percentile(10**maxts_ary, [16,50,84], axis=1)

# %%
nmc = 10

xsec_max_ary = np.zeros((5,nmc))
limit_ary = np.zeros((5,nmc))
maxts_ary = np.zeros((5,nmc))

plot_mc_emax35 = LimitPlot(data_dir='/tigress/nrodd/DM-Catalog-Scan/Scan-Small-ROI/data/DarkSky_sid_loc1/',
                    elephant=False, 
                    nmc=nmc, 
                    halos_ran=1000, 
                    halos_to_keep=1000,
                    data_type="mc",
                    bcut=20,
                    nonoverlap=True,
                    nonoverlapradius=2.,
                    cut_0p5=False,
                    xsecslim=10,
                    TS100=9,
                    TS1000=9,
                    file_prefix='LL2_TSmx_lim_b_emin4_emax35_o',
                    elephantm = [0]) # 0 for 10 GeV
limit_ary_temp_emax35, xsec_max_ary_temp_emax35, maxts_ary_temp_emax35 = plot_mc_emax35.return_limits()

# xsec_max_ary[idm] = xsec_max_ary_temp[-1,0,:]
# limit_ary[idm] = limit_ary_temp[-1,0,:]
# maxts_ary[idm] = maxts_ary_temp[-1,0,:]
    
# xsec_max = np.log10(np.percentile(xsec_max_ary, [16,50,84], axis=1))
# lims = np.log10(np.percentile(10**limit_ary, [16,50,84], axis=1))
# maxtss = np.percentile(10**maxts_ary, [16,50,84], axis=1)

# %%
ebins = 2*np.logspace(-1,3, 41)

# %%
np.percentile(maxts_ary_temp[-1], 16, axis=1)[0],np.percentile(maxts_ary_temp[-1], 84, axis=1)[0]
# Out:
# (6.556510925292968e-09, 0.70252451613545375)

# %%
np.percentile(maxts_ary_temp[-1], 2.5, axis=1)[0],np.percentile(maxts_ary_temp[-1], 97.5, axis=1)[0]
# Out:
# (0.0, 2.335385691188276)

# %%
plot_h = 10/1.2
plot_w = 8/1.2


fig, ax = plt.subplots(1, figsize=(plot_h, plot_w))

# plt.plot(plot_mc.marr,np.percentile(maxTS_ary[-1], 2.5, axis=1), alpha=1, color='k',label=r'Data',lw=2.5)

plt.fill_between(plot_mc.marr,np.percentile(maxts_ary_temp[-1], 2.5, axis=1),np.percentile(maxts_ary_temp[-1], 97.5, axis=1),color='yellow',label=r'95\% containment',alpha=0.6,lw=2)
plt.fill_between(plot_mc.marr,np.percentile(maxts_ary_temp[-1], 16, axis=1),np.percentile(maxts_ary_temp[-1], 84, axis=1),color='limegreen',label=r'68\% containment',alpha=0.7,lw=2)

# m3, = plt.plot([], [], c='limegreen' , marker='s', markersize=20,
#               fillstyle='left', linestyle='none',alpha=0.6)

# m4, = plt.plot([], [], c='yellow' , marker='s', markersize=20,
#               fillstyle='right', linestyle='none',alpha=0.6)


# plt.text(700,50,"$\mathbf{E_\mathrm{max}=}$ \\textbf{" + str(ebins[31])[:3] +" GeV}", fontsize=23)

plt.xscale("log")
# plt.yscale("log")

plt.xticks(fontsize=23);
plt.yticks(fontsize=23);
plt.xlabel(r"$m_\chi$ [GeV]",fontsize=23)
plt.ylabel(r"TS$_\mathrm{max}$",fontsize=23)

plt.xlim([1e1,1e4])
# plt.ylim([8e-28,2e-22])
# plt.yscale("log")
# plt.text(15.3, 100, r'\textbf{Stacked Galaxy Groups}',fontsize=22,color='black')

# handles,labels = ax.get_legend_handles_labels()
# handles = [handles[0],(m3,m4)] #, handles[2]]
# labels = [labels[0], handles[1],labels[4],labels[3],labels[2]] #, labels[2]]

labels = [u'Data',
 u'$68/95\%$ containment']

# leg = plt.legend(handles,labels,loc=2,fontsize=17,fancybox=True,facecolor='none',frameon=False)



# plt.legend(handles,labels, ncol=1,fancybox=True,facecolor='none',frameon=False, loc='upper left', fontsize=23)

plt.xlim(10,20)
plt.ylim(-0.1,10)
plt.tight_layout()

# plt.savefig(plots_dir + 'global_e251.pdf',bbox_inches='tight')

# %%
plot_h = 10/1.2
plot_w = 8/1.2


fig, ax = plt.subplots(1, figsize=(plot_h, plot_w))

# plt.plot(plot_mc.marr,np.percentile(maxTS_ary[-1], 2.5, axis=1), alpha=1, color='k',label=r'Data',lw=2.5)

plt.fill_between(plot_mc.marr,np.percentile(maxts_ary_temp[-1], 2.5, axis=1),np.percentile(maxts_ary_temp[-1], 97.5, axis=1),color='yellow',label=r'95\% containment',alpha=0.6,lw=2)
plt.fill_between(plot_mc.marr,np.percentile(maxts_ary_temp[-1], 16, axis=1),np.percentile(maxts_ary_temp[-1], 84, axis=1),color='limegreen',label=r'68\% containment',alpha=0.7,lw=2)

# m3, = plt.plot([], [], c='limegreen' , marker='s', markersize=20,
#               fillstyle='left', linestyle='none',alpha=0.6)

# m4, = plt.plot([], [], c='yellow' , marker='s', markersize=20,
#               fillstyle='right', linestyle='none',alpha=0.6)


plt.text(700,50,"$\mathbf{E_\mathrm{max}=}$ \\textbf{" + str(ebins[31])[:3] +" GeV}", fontsize=23)

plt.xscale("log")
# plt.yscale("log")

plt.xticks(fontsize=23);
plt.yticks(fontsize=23);
plt.xlabel(r"$m_\chi$ [GeV]",fontsize=23)
plt.ylabel(r"TS$_\mathrm{max}$",fontsize=23)

plt.xlim([1e1,1e4])
# plt.ylim([8e-28,2e-22])
# plt.yscale("log")
# plt.text(15.3, 100, r'\textbf{Stacked Galaxy Groups}',fontsize=22,color='black')

# handles,labels = ax.get_legend_handles_labels()
# handles = [handles[0],(m3,m4)] #, handles[2]]
# labels = [labels[0], handles[1],labels[4],labels[3],labels[2]] #, labels[2]]

labels = [u'Data',
 u'$68/95\%$ containment']

# leg = plt.legend(handles,labels,loc=2,fontsize=17,fancybox=True,facecolor='none',frameon=False)



# plt.legend(handles,labels, ncol=1,fancybox=True,facecolor='none',frameon=False, loc='upper left', fontsize=23)

# plt.xlim(10,20)
plt.ylim(-0.1,60)
plt.tight_layout()

# plt.savefig(plots_dir + 'global_e251.pdf',bbox_inches='tight')

# %%
plot_h = 10/1.2
plot_w = 8/1.2


fig, ax = plt.subplots(1, figsize=(plot_h, plot_w))

# plt.plot(plot_mc.marr,np.percentile(maxTS_ary[-1], 2.5, axis=1), alpha=1, color='k',label=r'Data',lw=2.5)

plt.fill_between(plot_mc_emax31.marr,np.percentile(maxts_ary_temp_emax31[-1], 2.5, axis=1),np.percentile(maxts_ary_temp_emax31[-1], 97.5, axis=1),color='yellow',label=r'95\% containment',alpha=0.6,lw=2)
plt.fill_between(plot_mc_emax31.marr,np.percentile(maxts_ary_temp_emax31[-1], 16, axis=1),np.percentile(maxts_ary_temp_emax31[-1], 84, axis=1),color='limegreen',label=r'68\% containment',alpha=0.7,lw=2)

# m3, = plt.plot([], [], c='limegreen' , marker='s', markersize=20,
#               fillstyle='left', linestyle='none',alpha=0.6)

# m4, = plt.plot([], [], c='yellow' , marker='s', markersize=20,
#               fillstyle='right', linestyle='none',alpha=0.6)




plt.xscale("log")
# plt.yscale("log")

plt.xticks(fontsize=23);
plt.yticks(fontsize=23);
plt.xlabel(r"$m_\chi$ [GeV]",fontsize=23)
plt.ylabel(r"TS$_\mathrm{max}$",fontsize=23)

plt.xlim([1e1,1e4])
# plt.ylim([8e-28,2e-22])
# plt.yscale("log")a
# plt.text(15.3, 100, r'\textbf{Stacked Galaxy Groups}',fontsize=22,color='black')

# handles,labels = ax.get_legend_handles_labels()
# handles = [handles[0],(m3,m4)] #, handles[2]]
# labels = [labels[0], handles[1],labels[4],labels[3],labels[2]] #, labels[2]]

labels = [u'Data',
 u'$68/95\%$ containment']

# leg = plt.legend(handles,labels,loc=2,fontsize=17,fancybox=True,facecolor='none',frameon=False)



# plt.legend(handles,labels, ncol=1,fancybox=True,facecolor='none',frameon=False, loc='upper left', fontsize=23)

plt.title("$E_\mathrm{max}=$" + str(ebins[32])[:4] +" GeV")


plt.ylim(-0.1,60)
plt.tight_layout()

# plt.savefig(plots_dir + 'global_maxts.pdf',bbox_inches='tight')

# %%
plot_h = 10/1.2
plot_w = 8/1.2


fig, ax = plt.subplots(1, figsize=(plot_h, plot_w))

# plt.plot(plot_mc.marr,np.percentile(maxTS_ary[-1], 2.5, axis=1), alpha=1, color='k',label=r'Data',lw=2.5)

plt.fill_between(plot_mc_emax32.marr,np.percentile(maxts_ary_temp_emax32[-1], 2.5, axis=1),np.percentile(maxts_ary_temp_emax32[-1], 97.5, axis=1),color='yellow',label=r'95\% containment',alpha=0.6,lw=2)
plt.fill_between(plot_mc_emax32.marr,np.percentile(maxts_ary_temp_emax32[-1], 16, axis=1),np.percentile(maxts_ary_temp_emax32[-1], 84, axis=1),color='limegreen',label=r'68\% containment',alpha=0.7,lw=2)

# m3, = plt.plot([], [], c='limegreen' , marker='s', markersize=20,
#               fillstyle='left', linestyle='none',alpha=0.6)

# m4, = plt.plot([], [], c='yellow' , marker='s', markersize=20,
#               fillstyle='right', linestyle='none',alpha=0.6)




plt.xscale("log")
# plt.yscale("log")

plt.xticks(fontsize=23);
plt.yticks(fontsize=23);
plt.xlabel(r"$m_\chi$ [GeV]",fontsize=23)
plt.ylabel(r"TS$_\mathrm{max}$",fontsize=23)

plt.xlim([1e1,1e4])
# plt.ylim([8e-28,2e-22])
# plt.yscale("log")a
# plt.text(15.3, 100, r'\textbf{Stacked Galaxy Groups}',fontsize=22,color='black')

# handles,labels = ax.get_legend_handles_labels()
# handles = [handles[0],(m3,m4)] #, handles[2]]
# labels = [labels[0], handles[1],labels[4],labels[3],labels[2]] #, labels[2]]

labels = [u'Data',
 u'$68/95\%$ containment']

# leg = plt.legend(handles,labels,loc=2,fontsize=17,fancybox=True,facecolor='none',frameon=False)



# plt.legend(handles,labels, ncol=1,fancybox=True,facecolor='none',frameon=False, loc='upper left', fontsize=23)
plt.title("$E_\mathrm{max}=$" + str(ebins[33])[:4] +" GeV")



plt.ylim(-0.1,60)
plt.tight_layout()

# plt.savefig(plots_dir + 'global_maxts.pdf',bbox_inches='tight')

# %%
plot_h = 10/1.2
plot_w = 8/1.2


fig, ax = plt.subplots(1, figsize=(plot_h, plot_w))

# plt.plot(plot_mc.marr,np.percentile(maxTS_ary[-1], 2.5, axis=1), alpha=1, color='k',label=r'Data',lw=2.5)

plt.fill_between(plot_mc_emax33.marr,np.percentile(maxts_ary_temp_emax33[-1], 2.5, axis=1),np.percentile(maxts_ary_temp_emax33[-1], 97.5, axis=1),color='yellow',label=r'95\% containment',alpha=0.6,lw=2)
plt.fill_between(plot_mc_emax33.marr,np.percentile(maxts_ary_temp_emax33[-1], 16, axis=1),np.percentile(maxts_ary_temp_emax33[-1], 84, axis=1),color='limegreen',label=r'68\% containment',alpha=0.7,lw=2)

# m3, = plt.plot([], [], c='limegreen' , marker='s', markersize=20,
#               fillstyle='left', linestyle='none',alpha=0.6)

# m4, = plt.plot([], [], c='yellow' , marker='s', markersize=20,
#               fillstyle='right', linestyle='none',alpha=0.6)




plt.xscale("log")
# plt.yscale("log")

plt.xticks(fontsize=23);
plt.yticks(fontsize=23);
plt.xlabel(r"$m_\chi$ [GeV]",fontsize=23)
plt.ylabel(r"TS$_\mathrm{max}$",fontsize=23)

plt.xlim([1e1,1e4])
# plt.ylim([8e-28,2e-22])
# plt.yscale("log")a
# plt.text(15.3, 100, r'\textbf{Stacked Galaxy Groups}',fontsize=22,color='black')

# handles,labels = ax.get_legend_handles_labels()
# handles = [handles[0],(m3,m4)] #, handles[2]]
# labels = [labels[0], handles[1],labels[4],labels[3],labels[2]] #, labels[2]]

labels = [u'Data',
 u'$68/95\%$ containment']

# leg = plt.legend(handles,labels,loc=2,fontsize=17,fancybox=True,facecolor='none',frameon=False)



# plt.legend(handles,labels, ncol=1,fancybox=True,facecolor='none',frameon=False, loc='upper left', fontsize=23)


plt.title("$E_\mathrm{max}=$" + str(ebins[34])[:4] +" GeV")


plt.ylim(-0.1,60)
plt.tight_layout()

# plt.savefig(plots_dir + 'global_maxts.pdf',bbox_inches='tight')

# %%
plot_h = 10/1.2
plot_w = 8/1.2


fig, ax = plt.subplots(1, figsize=(plot_h, plot_w))

# plt.plot(plot_mc.marr,np.percentile(maxTS_ary[-1], 2.5, axis=1), alpha=1, color='k',label=r'Data',lw=2.5)

plt.fill_between(plot_mc_emax34.marr,np.percentile(maxts_ary_temp_emax34[-1], 2.5, axis=1),np.percentile(maxts_ary_temp_emax34[-1], 97.5, axis=1),color='yellow',label=r'95\% containment',alpha=0.6,lw=2)
plt.fill_between(plot_mc_emax34.marr,np.percentile(maxts_ary_temp_emax34[-1], 16, axis=1),np.percentile(maxts_ary_temp_emax34[-1], 84, axis=1),color='limegreen',label=r'68\% containment',alpha=0.7,lw=2)

# m3, = plt.plot([], [], c='limegreen' , marker='s', markersize=20,
#               fillstyle='left', linestyle='none',alpha=0.6)

# m4, = plt.plot([], [], c='yellow' , marker='s', markersize=20,
#               fillstyle='right', linestyle='none',alpha=0.6)




plt.xscale("log")
# plt.yscale("log")

plt.xticks(fontsize=23);
plt.yticks(fontsize=23);
plt.xlabel(r"$m_\chi$ [GeV]",fontsize=23)
plt.ylabel(r"TS$_\mathrm{max}$",fontsize=23)

plt.xlim([1e1,1e4])
# plt.ylim([8e-28,2e-22])
# plt.yscale("log")
# plt.text(15.3, 100, r'\textbf{Stacked Galaxy Groups}',fontsize=22,color='black')

# handles,labels = ax.get_legend_handles_labels()
# handles = [handles[0],(m3,m4)] #, handles[2]]
# labels = [labels[0], handles[1],labels[4],labels[3],labels[2]] #, labels[2]]

labels = [u'Data',
 u'$68/95\%$ containment']

# leg = plt.legend(handles,labels,loc=2,fontsize=17,fancybox=True,facecolor='none',frameon=False)




# plt.legend(handles,labels, ncol=1,fancybox=True,facecolor='none',frameon=False, loc='upper left', fontsize=23)


plt.ylim(-0.1,60)
plt.tight_layout()

# plt.title("$E_\mathrm{max}=$" + str(ebins[35])[:4] +" GeV")


# plt.savefig(plots_dir + 'global_maxts.pdf',bbox_inches='tight')

# %%
plot_h = 10/1.2
plot_w = 8/1.2


fig, ax = plt.subplots(1, figsize=(plot_h, plot_w))

# plt.plot(plot_mc.marr,np.percentile(maxTS_ary[-1], 2.5, axis=1), alpha=1, color='k',label=r'Data',lw=2.5)

plt.fill_between(plot_mc_emax35.marr,np.percentile(maxts_ary_temp_emax35[-1], 2.5, axis=1),np.percentile(maxts_ary_temp_emax35[-1], 97.5, axis=1),color='yellow',label=r'95\% containment',alpha=0.6,lw=2)
plt.fill_between(plot_mc_emax35.marr,np.percentile(maxts_ary_temp_emax35[-1], 16, axis=1),np.percentile(maxts_ary_temp_emax35[-1], 84, axis=1),color='limegreen',label=r'68\% containment',alpha=0.7,lw=2)

# m3, = plt.plot([], [], c='limegreen' , marker='s', markersize=20,
#               fillstyle='left', linestyle='none',alpha=0.6)

# m4, = plt.plot([], [], c='yellow' , marker='s', markersize=20,
#               fillstyle='right', linestyle='none',alpha=0.6)




plt.xscale("log")
# plt.yscale("log")

plt.xticks(fontsize=23);
plt.yticks(fontsize=23);
plt.xlabel(r"$m_\chi$ [GeV]",fontsize=23)
plt.ylabel(r"TS$_\mathrm{max}$",fontsize=23)

plt.xlim([1e1,1e4])
# plt.ylim([8e-28,2e-22])
# plt.yscale("log")
# plt.text(15.3, 100, r'\textbf{Stacked Galaxy Groups}',fontsize=22,color='black')

# handles,labels = ax.get_legend_handles_labels()
# handles = [handles[0],(m3,m4)] #, handles[2]]
# labels = [labels[0], handles[1],labels[4],labels[3],labels[2]] #, labels[2]]

labels = [u'Data',
 u'$68/95\%$ containment']

# leg = plt.legend(handles,labels,loc=2,fontsize=17,fancybox=True,facecolor='none',frameon=False)
plt.text(20,50,"$\mathbf{E_\mathrm{max}=}$ \\textbf{" + str(ebins[36])[:3] +" GeV}", fontsize=23)




# plt.legend(handles,labels, ncol=1,fancybox=True,facecolor='none',frameon=False, loc='upper left', fontsize=23)

# plt.title("$E_\mathrm{max}=$" + str(ebins[36])[:4] +" GeV")


plt.ylim(-0.1,60)
plt.tight_layout()

# plt.savefig(plots_dir + 'global_e796.pdf',bbox_inches='tight')

# %%
fig,ax = plt.subplots(1,figsize=(10/1.2,8/1.2))

# plt.plot(m_arr,data_lim,color='k',label=r'Galaxy groups (this work)',linewidth=2,linestyle='solid')
# plt.plot(m_arr,data_lim_nb,color='black',label=r'Galaxy groups (no boost)',linewidth=1,linestyle='dashed')

# fudge=1.0 
# plt.fill_between(m_arr,fudge*rot_q2p5,fudge*rot_q97p5,color='yellow',label=r'95\% containment',alpha=0.6)
# plt.fill_between(m_arr,fudge*rot_q16,fudge*rot_q84,color='limegreen',label=r'68\% containment',alpha=0.7)

plt.plot(plot_mc.marr,10**np.percentile(limit_ary_temp[-1], 50, axis=1), alpha=1, color='k',label=r'Baseline')
plt.plot(plot_mc.marr,10**np.percentile(limit_ary_temp_emax31[-1], 50, axis=1), alpha=1, color='k',label=r'Baseline')
plt.plot(plot_mc.marr,10**np.percentile(limit_ary_temp_emax32[-1], 50, axis=1), alpha=1, color='k',label=r'Baseline')
plt.plot(plot_mc.marr,10**np.percentile(limit_ary_temp_emax33[-1], 50, axis=1), alpha=1, color='k',label=r'Baseline')
plt.plot(plot_mc.marr,10**np.percentile(limit_ary_temp_emax34[-1], 50, axis=1), alpha=1, color='k',label=r'Baseline')



# plt.plot(plot_data.marr,10**np.percentile(data_ary_10k[-1], 2.5, axis=1), alpha=1, color='k',label=r'10k halos',ls=':')




# plt.plot(thermal[::,0],thermal[::,1],linestyle='dotted',color='dimgrey',linewidth=1)
plt.text(380, 3.e-26, r'\emph{Thermal relic cross section}',fontsize=19.,color='dimgrey')

plt.xscale('log')
plt.yscale('log')
plt.xticks(fontsize=23);
plt.yticks(fontsize=23);
plt.xlabel(r"$m_\chi$ [GeV]",fontsize=23)
plt.ylabel(r"$\langle \sigma v \rangle$ [cm$^3$ s$^{-1}$]",fontsize=23)

plt.xlim([1e1,1e4])
plt.ylim([8e-28,2e-22])

plt.text(200, 3.5e-27, r'\textbf{Stacked Galaxy Groups}',fontsize=22,color='black')
plt.text(75., 1.5e-27, r'Non-overlapping halos and halo number',fontsize=20,color='black')

# plt.legend(ncol=1,fancybox=True,facecolor='none',frameon=False)

plt.tight_layout()

# plt.savefig(plots_dir + 'systematics_nh.pdf',bbox_inches='tight')
