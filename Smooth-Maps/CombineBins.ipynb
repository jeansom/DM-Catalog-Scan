# %%
import numpy as np
import healpy as hp
import matplotlib.pyplot as plt
from tqdm import *
from math import log10, floor

# %matplotlib inline

# %%
rtn = lambda x, n: round(x, -int(floor(log10(x))) + (n - 1))

for loc in ["100,100,100","100,100,300","100,300,100","300,100,100","300,300,100","100,300,300","300,100,300", "300,300,300", "200,200,200"]:
    box_center = [float(coord) for coord in loc.split(',')]
    J_map=[]
    for ebin in range(40):
        J_file = "SmoothedMapsLocsCutBinned/Jfactor_DS_true_map_"+str(box_center[0])+"_"+str(box_center[1])+"_"+str(box_center[2])+"b1e+20_a2e+17_skyloccut_"+str(ebin)+".npy"
        J_map.append(np.load(J_file))
    np.save("SmoothedMapsLocsCut/Jfactor_DS_true_map_"+str(box_center[0])+"_"+str(box_center[1])+"_"+str(box_center[2])+"b1e+20_a2e+17_skyloccut.npy",J_map)

# %%
rtn = lambda x, n: round(x, -int(floor(log10(x))) + (n - 1))

for sys_str in ["ltom_cvir_correa","alpha2_ltom_cvir_dsmedian","mmin1e4_ltom_cvir_dsmedian","ltom_cvir_dsmedian","ltom_cvir_dsmedian","cvir_dsmedian"]:
    J_map=[]
    for ebin in range(40):
        J_file = "SmoothedMapsLocsSystematicsBinned/Jfactor_DS_inf_map_200.0_200.0_200.0b1e+20_a2e+17_" + sys_str +"_"+str(ebin)+".npy"
        J_map.append(np.load(J_file))
    np.save("SmoothedMapsLocsSystematics/Jfactor_DS_inf_map_200.0_200.0_200.0b1e+20_a2e+17_" + sys_str +".npy",J_map)

# %%
rtn = lambda x, n: round(x, -int(floor(log10(x))) + (n - 1))

for jcutup in np.logspace(13,18.5,15):
    J_map=[]
    for ebin in range(40):
        J_file = "SmoothedMapsBinned/Jfactor_DS_true_map_200.0_200.0_200.0b"+str(rtn(jcutup,3))+"_a1e+13_final_" +str(ebin)+".npy"
        J_map.append(np.load(J_file))
    np.save("SmoothedMaps/Jfactor_DS_true_map_200.0_200.0_200.0b"+str(rtn(jcutup,3))+"_a1e+13_final_smoothed.npy",J_map)

# %%
for jcutdown in np.logspace(13,18.5,15):
    J_map=[]
    for ebin in range(40):
        J_file = "SmoothedMapsBinned/Jfactor_DS_true_map_200.0_200.0_200.0b1e+20_a"+str(rtn(jcutdown,3))+"_final_" +str(ebin)+".npy"
        J_map.append(np.load(J_file))
    np.save("SmoothedMaps/Jfactor_DS_true_map_200.0_200.0_200.0b1e+20_a"+str(rtn(jcutdown,3))+"_final_smoothed.npy",J_map)

# %%
for jcutdown in np.logspace(18,18.5,10):
    J_map=[]
    for ebin in range(40):
        J_file = "SmoothedMapsHighBinned//Jfactor_DS_true_map_200.0_200.0_200.0b1e+20_a"+str(rtn(jcutdown,3))+"_final_" +str(ebin)+".npy"
        J_map.append(np.load(J_file))
    np.save("SmoothedMapsHigh/Jfactor_DS_true_map_200.0_200.0_200.0b1e+20_a"+str(rtn(jcutdown,3))+"_final_smoothed.npy",J_map)

# %%
for jcutdown in np.logspace(13,18.5,15):
    J_map=[]
    J_file = "../GenerateJFactors/GenMaps/Jfactor_DS_true_ary_200.0_200.0_200.0b1e+20_a"+str(rtn(jcutdown,3))+"_final.npy"
    print len(np.load(J_file)), str(rtn(jcutdown,3)), '1e+20'
        #         J_map.append(np.load(J_file))
#     np.save("SmoothedMaps/Jfactor_DS_true_map_200.0_200.0_200.0b1e+20_a"+str(rtn(jcutdown,3))+"_final_smoothed.npy",J_map)
# Out:
# 164111 1e+13 1e+20
# 163499 2.47e+13 1e+20
# 159666 6.11e+13 1e+20
# 142414 1.51e+14 1e+20
# 103765 3.73e+14 1e+20
# 60198 9.21e+14 1e+20
# 28929 2.28e+15 1e+20
# 11962 5.62e+15 1e+20
# 4310 1.39e+16 1e+20
# 1434 3.43e+16 1e+20
# 428 8.48e+16 1e+20
# 121 2.1e+17 1e+20
# 30 5.18e+17 1e+20
# 5 1.28e+18 1e+20
# 1 3.16e+18 1e+20

# %%
for jcutdown in np.logspace(13,18.5,15):
    J_map=[]
    J_file = "../GenerateJFactors/GenMaps/Jfactor_DS_true_ary_200.0_200.0_200.0b1e+20_a"+str(rtn(jcutdown,3))+"_final.npy"
    print len(np.load(J_file)), str(rtn(jcutdown,3)), '1e+20'
        #         J_map.append(np.load(J_file))
#     np.save("SmoothedMaps/Jfactor_DS_true_map_200.0_200.0_200.0b1e+20_a"+str(rtn(jcutdown,3))+"_final_smoothed.npy",J_map)
# Out:
# 163143 1e+13 1e+20
# 162531 2.47e+13 1e+20
# 158698 6.11e+13 1e+20
# 141446 1.51e+14 1e+20
# 102797 3.73e+14 1e+20
# 59237 9.21e+14 1e+20
# 28192 2.28e+15 1e+20
# 11587 5.62e+15 1e+20
# 4163 1.39e+16 1e+20
# 1395 3.43e+16 1e+20
# 418 8.48e+16 1e+20
# 116 2.1e+17 1e+20
# 29 5.18e+17 1e+20
# 5 1.28e+18 1e+20
# 1 3.16e+18 1e+20

# %%
for jcutdown in np.logspace(18,18.5,10):
    J_map=[]
    J_file = "../GenerateJFactors/GenMaps//Jfactor_DS_true_ary_200.0_200.0_200.0b1e+20_a"+str(rtn(jcutdown,3))+"_final.npy"
    print len(np.load(J_file)), str(rtn(jcutdown,3)), '1e+20'
        #         J_map.append(np.load(J_file))
#     np.save("SmoothedMaps/Jfactor_DS_true_map_200.0_200.0_200.0b1e+20_a"+str(rtn(jcutdown,3))+"_final_smoothed.npy",J_map)
# Out:
# 9 1e+18 1e+20
# 7 1.14e+18 1e+20
# 5 1.29e+18 1e+20
# 4 1.47e+18 1e+20
# 3 1.67e+18 1e+20
# 2 1.9e+18 1e+20
# 2 2.15e+18 1e+20
# 2 2.45e+18 1e+20
# 2 2.78e+18 1e+20
# 1 3.16e+18 1e+20

# %%
rtn = lambda x, n: round(x, -int(floor(log10(x))) + (n - 1))

for jcutdown in np.logspace(18,18.5,10):
    J_map=[]
    J_file = "../GenerateJFactors/GenMaps/Jfactor_DS_true_map_200.0_200.0_200.0b1e+20_a"+str(rtn(jcutdown,3))+"_final.npy"
    print np.sum(np.load(J_file)),
    len(np.load(J_file)), str(rtn(jcutdown,3)), '1e+20'
    J_map.append(np.load(J_file))
    np.save("SmoothedMapsHigh/Jfactor_DS_true_map_200.0_200.0_200.0b1e+20_a"+str(rtn(jcutdown,3))+"_final_smoothed.npy",J_map)
# Out:
# 4.98116753347e-08 4.35470896719e-08 3.62706001911e-08 3.23611055725e-08 2.75838375219e-08 2.20871383057e-08 2.20871383057e-08 2.20871383057e-08 2.20871383057e-08 1.31359867329e-08

# %%
np.logspace(13,18.5,15)
# Out:
# array([  1.00000000e+13,   2.47091123e+13,   6.10540230e+13,
#          1.50859071e+14,   3.72759372e+14,   9.21055318e+14,
#          2.27584593e+15,   5.62341325e+15,   1.38949549e+16,
#          3.43332002e+16,   8.48342898e+16,   2.09617999e+17,
#          5.17947468e+17,   1.27980221e+18,   3.16227766e+18])

# %%
hp.mollview(np.load("SmoothedMapsHighBinned/Jfactor_DS_true_map_200.0_200.0_200.0b1e+20_a1.14e+18_final_0.npy"))

# %%
hp.mollview(np.load("SmoothedMapsHigh/Jfactor_DS_true_map_200.0_200.0_200.0b1e+20_a1.67e+18_final_smoothed.npy")[0])

# %%
hp.mollview(np.load("SmoothedMapsBinned/Jfactor_DS_true_map_200.0_200.0_200.0b1e+20_a3.16e+18_final_6.npy"))

# %%
hp.mollview(np.load("../GenerateJFactors/GenMaps/Jfactor_DS_true_map_200.0_200.0_200.0b3.16e+18_a1e+13_final.npy"))

# %%
for jcutdown in [10**13]:
    J_map=[]
    for ebin in range(40):
        J_file = "SmoothedMapsBinnedQ3//Jfactor_DS_true_map_200.0_200.0_200.0b1e+20_a"+str(rtn(jcutdown,3))+"_final_" +str(ebin)+".npy"
        J_map.append(np.load(J_file))
    np.save("SmoothedMapsQ3//Jfactor_DS_true_map_200.0_200.0_200.0b1e+20_a"+str(rtn(jcutdown,3))+"_final_smoothed.npy",J_map)

# %%
hp.mollview(np.load("SmoothedMapsQ3/Jfactor_DS_true_map_200.0_200.0_200.0b1e+20_a1e+13_final_smoothed.npy")[0])

# %%
for loc in ["100,100,100","100,100,300","100,300,100","300,100,100","300,300,100","100,300,300","300,100,300", "300,300,300", "200,200,200"]:
    J_map=[]
    box_center = [float(coord) for coord in loc.split(',')]
    for ebin in range(40):
        J_file = "SmoothedMapsLocsBinned///Jfactor_DS_true_map_"+str(box_center[0])+"_"+str(box_center[1])+"_"+str(box_center[2])+"b1e+20_a1e+13_final_"+str(ebin)+".npy"
        J_map.append(np.load(J_file))
    np.save("SmoothedMapsLocs//Jfactor_DS_true_map_"+str(box_center[0])+"_"+str(box_center[1])+"_"+str(box_center[2])+"b1e+20_a1e+13_final_smoothed.npy",J_map)

# %%
hp.mollview(np.load("SmoothedMapsLocs/Jfactor_DS_true_map_200.0_200.0_200.0b1e+20_a1e+13_final_smoothed.npy")[0])

# %%
hp.mollview(np.load("SmoothedMapsBinnedQ3//Jfactor_DS_true_map_100.0_300.0_100.0b1e+20_a1e+13_final_0.npy"))
